# %% [markdown]
# # Sparse Bottleneck Networks for Exploratory Analysis and Visualization of Neural Patch-seq Data

# %%
# Import packages
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib
import seaborn as sns
import sparseRRR
import matplotlib
import matplotlib.pyplot as plt
import importlib

import bottleneck_networks

import time
import pickle
import warnings

dtype = tf.float32

def sns_styleset():
    sns.set_style('ticks', {'axes.linewidth': .75, "xtick.major.size":4, "ytick.major.size":4})

# %% [markdown]
# # Loading data

# %%
scala = pickle.load(open('data/scala_2020/scala2020.pickle', 'rb'))
genes=scala['X']
ephys=scala['Y']
gene_names=scala['gene_names']
cell_types=scala['celltypes']
cell_id_to_cell_type=scala['map']
ephys_names=scala['ephys_features']
colors=scala['colors']

# %% [markdown]
# Let us find K-mean clusters to perform pre-training. One could also pre-train on celltype classification. This has actually improved performance even more but could be argued to be biasing the results too much. K-means allows for an unsupervised more general setting.

# %%
# You can cluster according to amounts of classes or amounts of celltypes. Change the argument of n_clusters accordingly.
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=20, random_state=17, n_init=1000).fit(ephys)

# %%
clusters = kmeans.labels_

# %%
amount_of_cells_in_clusters = {cluster_id: sum(clusters==cluster_id) for cluster_id in np.unique(clusters)}
for_every_cell_number_of_cells_of_their_cluster = np.array([amount_of_cells_in_clusters[cell] for cell in clusters])
ind_pre_training_clusters = for_every_cell_number_of_cells_of_their_cluster >= 10

# %% [markdown]
# # Keras initialisations

# %%
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import metrics
from tensorflow.keras.losses import CategoricalCrossentropy

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
import tensorflow.keras.backend as K

# %%
# # You should assume you get two TensorFlow variables as input
# y_actual = tf.placeholder(dtype = tf.float32)
# y_predicted = tf.placeholder(dtype = tf.float32)
# def tukey_tf(y_truth, y_pred):
#     c = tf.constant(4.6851, dtype = tf.float32)
#     residual = tf.add(y_truth, -y_pred, name='residual')
#     mask = tf.abs(residual) <= c
#     custom_loss = tf.ones_like(residual, name = 'custom_loss')*((c**2)/6)
#     custom_loss_temp = ((c**2)/6)*(1-(1-(residual/c)**2)**3)
#     custom_loss = tf.where(mask, custom_loss_temp, custom_loss)
#     return tf.reduce_mean(tf.reduce_sum(custom_loss, axis = 1))
#     #return custom_loss
# tukey_tf_result = tukey_tf(y_actual, y_predicted)

# %%
# You should assume you get two TensorFlow variables as input
y_actual = tf.placeholder(dtype = tf.float32)
y_predicted = tf.placeholder(dtype = tf.float32)
def r2_score(y_truth, y_pred):
    residual = tf.add(y_truth, -y_pred, name='residual')
    return 1-tf.reduce_sum(tf.square(residual)) / tf.reduce_sum(tf.square(y_truth))
r2_score_result = r2_score(y_actual, y_predicted)

# %%
class ElasticNet(tf.keras.regularizers.Regularizer): 
    def __init__(self, l1=1e-8, l2=1.0): 
        self.l1 = l1
        self.l2 = l2

    def __call__(self, x): 
        return self.l2*tf.math.reduce_sum(tf.math.square(x)) + \
                             self.l1*tf.reduce_sum(tf.norm(x, ord = 2, axis = 1))

    def get_config(self): 
        return {'l1': float(self.l1), 'l2': float(self.l2)}

# %% [markdown]
# # Ridge only, test different models w.r.t. reduced-rank-regression

# %% [markdown]
# Running all the following models can take up time (~10minutes). One can also simpy load the trained models in the following section. You can jump right into the group losso + ridge setting in the next section.

# %% [markdown]
# Our ridge penalty only straight regression (no pre-training) model.

# %%
importlib.reload(bottleneck_networks)
# Out:
# <module 'bottleneck_networks' from '/gpfs01/berens/user/ybernaerts/EphysAnalysis/data/ephys/sBNN/bottleneck_networks.py'>

# %%
ephys.shape
# Out:
# (1213, 16)

# %%
genes.shape
# Out:
# (1213, 1000)

# %%
from bottleneck_networks import StraightRegression

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([0])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs

r2_straight_regr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_straight_regr_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_straight_regr_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
r2_straight_regr_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
MSE_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
MSE_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
train_ephys = []
test_ephys = []
train_ephys_predict = []
test_ephys_predict = []

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]


# CV folds
for cvfold in range(folds):
    print('CVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    train_ephys.append(y_train)
    test_ephys.append(y_test)
    
    input_dim = x_train.shape[1]
    output_dim = y_train.shape[1]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)
            BN_StraightRegression = StraightRegression(l1=l1, l2=l2, lr=lr, act=act, \
                                                       input_dim=input_dim, output_dim=output_dim)
            train_ephys_pred, test_ephys_pred, \
                r2_train, r2_test, train_hist, test_hist, \
                MSE_tr, MSE_test = BN_StraightRegression.train(x_train=x_train, y_train=y_train, \
                                                                                   x_test=x_test, y_test=y_test, \
                                                                                   epochs=epochs, bs=bs, patience=patience, \
                                                                                   cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                                   verbose=0)
            train_ephys_predict.append(train_ephys_pred)
            test_ephys_predict.append(test_ephys_pred)
            r2_straight_regr[cvfold, j, i] = r2_test
            r2_straight_regr_tr[cvfold, j, i] = r2_train
            r2_straight_regr_hist[cvfold, j, i] = test_hist
            r2_straight_regr_hist_tr[cvfold, j, i] = train_hist
            MSE_hist[cvfold, j, i] = MSE_test
            MSE_hist_tr[cvfold, j, i] = MSE_tr
            #print('Test R^2 score (straight regression, no pre-tr): ', r2_straight_regr[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# Train R^2:  0.4526631236076355
# Test R^2:  0.40562015771865845
# CVFOLD:  1
# [INFO] training network...
# Train R^2:  0.5019111633300781
# Test R^2:  0.39128899574279785
# CVFOLD:  2
# [INFO] training network...
# Train R^2:  0.43120813369750977
# Test R^2:  0.32329273223876953
# CVFOLD:  3
# [INFO] training network...
# Train R^2:  0.42269885540008545
# Test R^2:  0.3294333219528198
# CVFOLD:  4
# [INFO] training network...
# Train R^2:  0.46519190073013306
# Test R^2:  0.3524671792984009
# CVFOLD:  5
# [INFO] training network...
# Train R^2:  0.42557913064956665
# Test R^2:  0.3300928473472595
# CVFOLD:  6
# [INFO] training network...
# Train R^2:  0.49086594581604004
# Test R^2:  0.3631784915924072
# CVFOLD:  7
# [INFO] training network...
# Train R^2:  0.4636569619178772
# Test R^2:  0.3881339430809021
# CVFOLD:  8
# [INFO] training network...
# Train R^2:  0.4716581106185913
# Test R^2:  0.340606153011322
# CVFOLD:  9
# [INFO] training network...
# Train R^2:  0.44509387016296387
# Test R^2:  0.3761177062988281
# Time: 0.0h  2m  2s

# %%
# First visualisation of the data.
fig, axes = plt.subplots(2, folds, figsize=(2*folds, 4))
for i in range(folds):
    axes[0, i].scatter(train_ephys[i], train_ephys_predict[i], s=2)
    axes[0, i].annotate('r2={:.4f}'.format(r2_straight_regr_tr[i, 0, 0]), \
                    xy=(0.5*axes[0, i].get_xlim()[1], 0.8*axes[0, i].get_ylim()[1]))
    axes[0, i].set_title('fold: {}'.format(i))
    axes[1, i].scatter(test_ephys[i], test_ephys_predict[i], s=2)
    axes[1, i].annotate('r2={:.4f}'.format(r2_straight_regr[i, 0, 0]), \
                    xy=(0.5*axes[1, i].get_xlim()[1], 0.8*axes[1, i].get_ylim()[1]))
axes[0, 1].set_xlabel('true ephys, training')
axes[0, 0].set_ylabel('predicted ephys, training')
axes[1, 1].set_xlabel('true ephys, test')
axes[1, 0].set_ylabel('predicted ephys, test')
fig.suptitle('# epochs={}'.format(epochs), fontsize=15, y=1.05)
plt.tight_layout()

# %%
fig, axes = plt.subplots(2, folds, figsize=(2*folds, 4))
for i in range(folds):
    axes[0, i].hist((train_ephys[i]-train_ephys_predict[i])[:, 0]**2, bins=30, alpha=0.5, zorder=1, label='MSE')
    axes[0, i].hist(train_ephys[i][:, 0]**2, bins=30, zorder=0, label='denominator')
    axes[0, i].annotate('r2: {:.4f}'.format(r2_straight_regr_tr[i, 0, 0]), \
                        xy=(0.6*axes[0, i].get_xlim()[1], 0.8*axes[0, i].get_ylim()[1]))
    axes[0, i].set_title('fold: {}'.format(i))
    axes[1, i].hist((test_ephys[i]-test_ephys_predict[i])[:, 0]**2, bins=30, alpha=0.5, zorder=1, label='MSE')
    axes[1, i].hist(test_ephys[i][:, 0]**2, bins=30, zorder=0, label='denominator')
    axes[1, i].annotate('r2={:.4f}'.format(r2_straight_regr[i, 0, 0]), \
                        xy=(0.6*axes[1, i].get_xlim()[1], 0.8*axes[1, i].get_ylim()[1]))
fig.suptitle('# epochs={}'.format(epochs), fontsize=15, y=1.05)
axes[0, 2].legend(loc='right')
axes[0, 1].set_xlabel('MSE terms, train')
axes[1, 1].set_xlabel('MSE terms, test')
plt.tight_layout()

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_straight_regr.pickle', 'wb') as f:
    pickle.dump([r2_straight_regr, r2_straight_regr_tr, \
                 r2_straight_regr_hist, r2_straight_regr_hist_tr], f)

# %% [markdown]
# Our ridge penalty only classification pre-training model.

# %%
importlib.reload(bottleneck_networks)
# Out:
# <module 'bottleneck_networks' from '/gpfs01/berens/user/ybernaerts/EphysAnalysis/data/ephys/sBNN/bottleneck_networks.py'>

# %%
from bottleneck_networks import ClassificationPreTrain

# %%
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([0])

act='elu'
folds=10
seed=42
lr=0.0001
epochs=50
bs=32
patience=epochs


t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]
clusters_ = clusters[ind]
ind_pre_train = ind_pre_training_clusters[ind]

CE_loss = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
CE_loss_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
pre_tr_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
pre_tr_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    clusters_train = np.copy(clusters_[indtrain])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    clusters_test = np.copy(clusters_[indtest])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean

    # In our training set we now look for a 'pretraining' training and test data set that we can use
    # for pretraing a classification network, i.e. picking the best model will be done with a seperate val set in our
    # training set for regression.

    x_train_pre_tr = x_train[ind_pre_train[indtrain], :]
    clusters_train_pre_tr = clusters_train[ind_pre_train[indtrain]]
    
    pre_train_size = 0.6
    train_cnt = round(x_train_pre_tr.shape[0]*pre_train_size)
    x_train_pre_tr_ = x_train_pre_tr[:train_cnt, :]
    x_test_pre_tr_ = x_train_pre_tr[train_cnt:, :]
    clusters_train_pre_tr_ = clusters_train_pre_tr[:train_cnt]
    clusters_test_pre_tr_ = clusters_train_pre_tr[train_cnt:]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)


            input_dim = x_train.shape[1]
            output_dim = to_categorical(clusters_train_pre_tr).shape[1]
            BN_Classification = ClassificationPreTrain(l1=l1, l2=l2, lr=lr, act=act, input_dim=input_dim, \
                                                       output_dim=output_dim)
            CE_train, CE_test, train_hist, test_hist = BN_Classification.train(x_train=x_train_pre_tr_, \
                                                                               cluster_train=clusters_train_pre_tr_, \
                                                                               x_test=x_test_pre_tr_, \
                                                                               cluster_test=clusters_test_pre_tr_, \
                                                                               epochs=epochs, bs=bs, patience=patience, \
                                                                               cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                               verbose=0)
            CE_loss[cvfold, j, i] = CE_test
            CE_loss_tr[cvfold, j, i] = CE_train
            pre_tr_hist[cvfold, j, i] = test_hist
            pre_tr_hist_tr[cvfold, j, i] = train_hist
            #print('Test CE loss (pre-trainin): ', CE_loss[cvfold, j, i])
            
t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# 655/655 [==============================] - 0s 191us/sample - loss: 1.6082 - categorical_crossentropy: 1.6082
# 437/437 [==============================] - 0s 103us/sample - loss: 1.9881 - categorical_crossentropy: 1.9881
#
# CVFOLD:  1
# [INFO] training network...
# 655/655 [==============================] - 0s 230us/sample - loss: 1.6783 - categorical_crossentropy: 1.6783
# 437/437 [==============================] - 0s 105us/sample - loss: 2.1318 - categorical_crossentropy: 2.1318
#
# CVFOLD:  2
# [INFO] training network...
# 655/655 [==============================] - 0s 188us/sample - loss: 1.5328 - categorical_crossentropy: 1.5328
# 437/437 [==============================] - 0s 81us/sample - loss: 1.9304 - categorical_crossentropy: 1.9304
#
# CVFOLD:  3
# [INFO] training network...
# 655/655 [==============================] - 0s 213us/sample - loss: 1.6291 - categorical_crossentropy: 1.6291
# 437/437 [==============================] - 0s 103us/sample - loss: 1.9333 - categorical_crossentropy: 1.9333
#
# CVFOLD:  4
# [INFO] training network...
# 655/655 [==============================] - 0s 199us/sample - loss: 1.8139 - categorical_crossentropy: 1.8139
# 437/437 [==============================] - 0s 106us/sample - loss: 2.2000 - categorical_crossentropy: 2.2000
#
# CVFOLD:  5
# [INFO] training network...
# 655/655 [==============================] - 0s 177us/sample - loss: 1.5636 - categorical_crossentropy: 1.5636
# 437/437 [==============================] - 0s 101us/sample - loss: 1.9678 - categorical_crossentropy: 1.9678
#
# CVFOLD:  6
# [INFO] training network...
# 655/655 [==============================] - 0s 217us/sample - loss: 1.8355 - categorical_crossentropy: 1.8355
# 437/437 [==============================] - 0s 135us/sample - loss: 2.1704 - categorical_crossentropy: 2.1704
#
# CVFOLD:  7
# [INFO] training network...
# 655/655 [==============================] - 0s 191us/sample - loss: 1.6144 - categorical_crossentropy: 1.6144
# 437/437 [==============================] - 0s 103us/sample - loss: 2.0116 - categorical_crossentropy: 2.0116
#
# CVFOLD:  8
# [INFO] training network...
# 655/655 [==============================] - 0s 200us/sample - loss: 1.4718 - categorical_crossentropy: 1.4718
# 437/437 [==============================] - 0s 93us/sample - loss: 2.0025 - categorical_crossentropy: 2.0025
#
# CVFOLD:  9
# [INFO] training network...
# 655/655 [==============================] - 0s 208us/sample - loss: 1.6090 - categorical_crossentropy: 1.6090
# 437/437 [==============================] - 0s 90us/sample - loss: 2.0051 - categorical_crossentropy: 2.0051
# Time: 0.0h  1m 47s

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_pre_tr.pickle', 'wb') as f:
    pickle.dump([CE_loss, CE_loss_tr, pre_tr_hist, pre_tr_hist_tr], f)

# %% [markdown]
# Our ridge penalty only pre-train and regression model.

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([0])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs
pre_trained_weights=True

r2_pretr_straight_regr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_pretr_straight_regr_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_pretr_straight_regr_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
r2_pretr_straight_regr_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    input_dim = x_train.shape[1]
    output_dim = y_train.shape[1]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)
            
            pre_trained_weights_h5 = 'KerasSavedModels/Classification_weights_{}_{}_{}.h5'.format(cvfold, j, i)
            
            BN_PreTrStraightRegression = StraightRegression(l1=l1, l2=l2, lr=lr, act=act, \
                                            input_dim=input_dim, output_dim=output_dim, \
                                            pre_trained_weights=pre_trained_weights, \
                                            pre_trained_weights_h5=pre_trained_weights_h5)
            _, _, r2_train, r2_test, train_hist, test_hist, _, _ = BN_PreTrStraightRegression.train(x_train=x_train, y_train=y_train, \
                                                                                   x_test=x_test, y_test=y_test, \
                                                                                   epochs=epochs, bs=bs, patience=patience, \
                                                                                   cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                                   verbose=0)
            r2_pretr_straight_regr[cvfold, j, i] = r2_test
            r2_pretr_straight_regr_tr[cvfold, j, i] = r2_train
            r2_pretr_straight_regr_hist[cvfold, j, i] = test_hist
            r2_pretr_straight_regr_hist_tr[cvfold, j, i] = train_hist
            #print('Test R^2 score (regression, after pre-tr): ', r2_pretr_straight_regr[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# Train R^2:  0.4711594581604004
# Test R^2:  0.4040963649749756
#
# CVFOLD:  1
# [INFO] training network...
# Train R^2:  0.5154673159122467
# Test R^2:  0.4048902988433838
#
# CVFOLD:  2
# [INFO] training network...
# Train R^2:  0.4908905625343323
# Test R^2:  0.37497538328170776
#
# CVFOLD:  3
# [INFO] training network...
# Train R^2:  0.45307958126068115
# Test R^2:  0.3825858235359192
#
# CVFOLD:  4
# [INFO] training network...
# Train R^2:  0.5788673758506775
# Test R^2:  0.38342541456222534
#
# CVFOLD:  5
# [INFO] training network...
# Train R^2:  0.487598717212677
# Test R^2:  0.37408924102783203
#
# CVFOLD:  6
# [INFO] training network...
# Train R^2:  0.4824718236923218
# Test R^2:  0.3439205288887024
#
# CVFOLD:  7
# [INFO] training network...
# Train R^2:  0.5839717090129852
# Test R^2:  0.4261111617088318
#
# CVFOLD:  8
# [INFO] training network...
# Train R^2:  0.4924424886703491
# Test R^2:  0.3871426582336426
#
# CVFOLD:  9
# [INFO] training network...
# Train R^2:  0.5002471506595612
# Test R^2:  0.3673180341720581
# Time: 0.0h  2m  3s

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_pre_tr_and_straight_regr.pickle', 'wb') as f:
    pickle.dump([r2_pretr_straight_regr, r2_pretr_straight_regr_tr, \
                 r2_pretr_straight_regr_hist, r2_pretr_straight_regr_hist_tr], f)

# %% [markdown]
# Our ridge penalty only pre-train + freeze the first 2 layers + unfreeze model.

# %%
importlib.reload(bottleneck_networks)
# Out:
# <module 'bottleneck_networks' from '/gpfs01/berens/user/ybernaerts/EphysAnalysis/data/ephys/sBNN/bottleneck_networks.py'>

# %%
from bottleneck_networks import FreezeUnfreeze

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([0])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs
pre_trained_weights=True
unfreeze = [False, False, True, True, True, True] # last 4 layers can be trained only first


r2_before_unfreezing = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_before_unfreezing_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_freeze_unfreeze_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 2*epochs))
r2_freeze_unfreeze_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 2*epochs))

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    input_dim = x_train.shape[1]
    output_dim = y_train.shape[1]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)
            
            pre_trained_weights_h5 = 'KerasSavedModels/Classification_weights_{}_{}_{}.h5'.format(cvfold, j, i)
            input_dim = x_train.shape[1]
            output_dim = y_train.shape[1]
            BN_PreTrFreezeUnfreeze = FreezeUnfreeze(l1=l1, l2=l2, lr=lr, act=act, input_dim=input_dim, output_dim=output_dim, \
                                                       unfreeze = unfreeze, \
                                                       pre_trained_weights=pre_trained_weights, \
                                                       pre_trained_weights_h5=pre_trained_weights_h5)
            r2_before_unfreezing_train, r2_before_unfreezing_test, \
                r2_after_unfreezing_train, r2_after_unfreezing_test, \
                train_hist, test_hist = BN_PreTrFreezeUnfreeze.train(x_train=x_train, y_train=y_train, \
                                                                    x_test=x_test, y_test=y_test, \
                                                                    epochs=epochs, bs=bs, patience=patience, \
                                                                    cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                    verbose=0)
            r2_before_unfreezing[cvfold, j, i] = r2_before_unfreezing_test
            r2_before_unfreezing_tr[cvfold, j, i] = r2_before_unfreezing_train
            r2_after_unfreezing[cvfold, j, i] = r2_after_unfreezing_test
            r2_after_unfreezing_tr[cvfold, j, i] = r2_after_unfreezing_train
            r2_freeze_unfreeze_hist[cvfold, j, i] = test_hist
            r2_freeze_unfreeze_hist_tr[cvfold, j, i] = train_hist
            #print('Test R^2 score (before unfreezing): ', r2_before_unfreezing[cvfold, j, i])
            #print('Test R^2 score (after unfreezing): ', r2_after_unfreezing[cvfold, j, i])
            
t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.396157443523407
# Test R^2 before unfreezing:  0.4075890779495239
# Train R^2 after unfreezing:  0.48377519845962524
# Test R^2 after unfreezing:  0.4336063265800476
#
# CVFOLD:  1
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.4176151752471924
# Test R^2 before unfreezing:  0.37342172861099243
# Train R^2 after unfreezing:  0.5010496973991394
# Test R^2 after unfreezing:  0.39512091875076294
#
# CVFOLD:  2
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.4087764620780945
# Test R^2 before unfreezing:  0.3611149191856384
# Train R^2 after unfreezing:  0.5160910487174988
# Test R^2 after unfreezing:  0.38427281379699707
#
# CVFOLD:  3
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.42144864797592163
# Test R^2 before unfreezing:  0.4177473187446594
# Train R^2 after unfreezing:  0.4992491602897644
# Test R^2 after unfreezing:  0.43083417415618896
#
# CVFOLD:  4
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.39947861433029175
# Test R^2 before unfreezing:  0.3599761724472046
# Train R^2 after unfreezing:  0.500076413154602
# Test R^2 after unfreezing:  0.3894401788711548
#
# CVFOLD:  5
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.41106998920440674
# Test R^2 before unfreezing:  0.3697558045387268
# Train R^2 after unfreezing:  0.49670493602752686
# Test R^2 after unfreezing:  0.3961016535758972
#
# CVFOLD:  6
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.3945631980895996
# Test R^2 before unfreezing:  0.34441131353378296
# Train R^2 after unfreezing:  0.45625078678131104
# Test R^2 after unfreezing:  0.3597317337989807
#
# CVFOLD:  7
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.4067874550819397
# Test R^2 before unfreezing:  0.4184899926185608
# Train R^2 after unfreezing:  0.5000851452350616
# Test R^2 after unfreezing:  0.44851845502853394
#
# CVFOLD:  8
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.4053674340248108
# Test R^2 before unfreezing:  0.3520404100418091
# Train R^2 after unfreezing:  0.5075338184833527
# Test R^2 after unfreezing:  0.3963930606842041
#
# CVFOLD:  9
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.4027981758117676
# Test R^2 before unfreezing:  0.3496783971786499
# Train R^2 after unfreezing:  0.5217611193656921
# Test R^2 after unfreezing:  0.38408130407333374
# Time: 0.0h  3m 55s

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_pre_tr_and_freeze_unfreeze.pickle', 'wb') as f:
    pickle.dump([r2_before_unfreezing, r2_before_unfreezing_tr, \
                 r2_after_unfreezing, r2_after_unfreezing_tr, \
                 r2_freeze_unfreeze_hist, r2_freeze_unfreeze_hist_tr], f)

# %% [markdown]
# In the next section we perform reduced-rank regression cross validation (rank = 2 and full rank).

# %%
# CV sRRR rank = 2

lambdas = np.concatenate([np.arange(.1,2,.1), np.arange(2,8)])
alphas = np.array([0])

rank = 2
folds = 10
seed = 42

r2_sRRR_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_rank2_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank2_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
nonzero_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
corrs_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))
corrs_relaxed_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))

# Uncomment if one lambda only
train_ephys = []
test_ephys = []
train_ephys_predict = []
test_ephys_predict = []

t = time.time()

np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    x_train = x_train.astype('float64')
    y_train = y_train.astype('float64')
    x_test = x_test.astype('float64')
    y_test = y_test.astype('float64')
    
    train_ephys.append(y_train)
    test_ephys.append(y_test)
    for i,a in enumerate(lambdas):
        #print('Lambdau: ', a)
        for j, b in enumerate(alphas):
            #print('Alpha: ', b)
            vx,vy = sparseRRR.elastic_rrr(x_train, y_train, lambdau=a, alpha=b, rank=rank, sparsity='row-wise')

            nz = np.sum(np.abs(vx), axis=1) != 0
            if np.sum(nz) < rank:
                nonzero_rank2[cvfold, j, i] = np.nan
                continue

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank2[cvfold, j, i] = np.nan
                continue

            nonzero_rank2[cvfold, j, i] = np.sum(nz)
            r2_sRRR_rank2[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum((y_test-np.mean(y_test))**2)
            r2_sRRR_rank2_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum((y_train-np.mean(y_train, axis=0))**2)
            for r in range(rank):
                corrs_rank2[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]

            # Relaxation
            vx[nz,:],vy = sparseRRR.elastic_rrr(x_train[:,nz], y_train, lambdau=a, alpha=0, rank=rank, sparsity='row-wise')

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank2[cvfold, j, i] = np.nan
                continue

            r2_sRRR_relaxed_rank2[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum((y_test-np.mean(y_test))**2)
            r2_sRRR_relaxed_rank2_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum((y_train-np.mean(y_train, axis=0))**2)
            for r in range(rank):
                corrs_relaxed_rank2[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]
            
            train_ephys_predict.append(x_train@vx@vy.T)
            test_ephys_predict.append(x_test@vx@vy.T)
            #print(r2_sRRR_relaxed_rank2[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
#
# CVFOLD:  1
#
# CVFOLD:  2
#
# CVFOLD:  3
#
# CVFOLD:  4
#
# CVFOLD:  5
#
# CVFOLD:  6
#
# CVFOLD:  7
#
# CVFOLD:  8
#
# CVFOLD:  9
# Time: 0.0h  5m 10s

# %%
with open('KerasSavedModels/scala_2020/sRRR_vs_Bottleneck_rank2_CV.pickle', 'wb') as f:
    pickle.dump([r2_sRRR_rank2, r2_sRRR_relaxed_rank2, r2_sRRR_rank2_tr, r2_sRRR_relaxed_rank2_tr, \
                nonzero_rank2, corrs_rank2, corrs_relaxed_rank2], f)

# %%
# CV sRRR full rank

lambdas = np.concatenate([np.arange(.1,2,.1), np.arange(2,8)])
alphas = np.array([0])

rank = ephys.shape[1]
folds = 10
seed = 42

r2_sRRR_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_rank16_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank16_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
nonzero_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
corrs_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))
corrs_relaxed_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))


t = time.time()

np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    x_train = x_train.astype('float64')
    y_train = y_train.astype('float64')
    x_test = x_test.astype('float64')
    y_test = y_test.astype('float64')
    
    for i,a in enumerate(lambdas):
        #print('Labmdau: ', a)
        for j, b in enumerate(alphas):
            #print('Alpha: ', b)
            vx,vy = sparseRRR.elastic_rrr(x_train, y_train, lambdau=a, alpha=b, rank=rank, sparsity='row-wise')

            nz = np.sum(np.abs(vx), axis=1) != 0
            if np.sum(nz) < rank:
                nonzero_rank16[cvfold, j, i] = np.nan
                continue

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank16[cvfold, j, i] = np.nan
                continue

            nonzero_rank16[cvfold, j, i] = np.sum(nz)
            r2_sRRR_rank16[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum((y_test-np.mean(y_test))**2)
            r2_sRRR_rank16_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum((y_train-np.mean(y_train, axis=0))**2)
            for r in range(rank):
                corrs_rank16[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]

            # Relaxation
            vx[nz,:],vy = sparseRRR.elastic_rrr(x_train[:,nz], y_train, lambdau=a, alpha=0, rank=rank, sparsity='row-wise')

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank16[cvfold, j, i] = np.nan
                continue

            r2_sRRR_relaxed_rank16[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum((y_test-np.mean(y_test))**2)
            r2_sRRR_relaxed_rank16_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum((y_train-np.mean(y_train, axis=0))**2)
            for r in range(rank):
                corrs_relaxed_rank16[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]
            #print(r2_sRRR_relaxed_rank16_tr[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
#
# CVFOLD:  1
#
# CVFOLD:  2
#
# CVFOLD:  3
#
# CVFOLD:  4
#
# CVFOLD:  5
#
# CVFOLD:  6
#
# CVFOLD:  7
#
# CVFOLD:  8
#
# CVFOLD:  9
# Time: 0.0h  5m 22s

# %%
with open('KerasSavedModels/scala_2020/sRRR_vs_Bottleneck_rank16_CV.pickle', 'wb') as f:
    pickle.dump([r2_sRRR_rank16, r2_sRRR_relaxed_rank16, r2_sRRR_rank16_tr, r2_sRRR_relaxed_rank16_tr, \
                nonzero_rank16, corrs_rank16, corrs_relaxed_rank16], f)

# %% [markdown]
# We now have cross validated results for all the ridge penalty models we care about. Let us now analyse and compare the training curves.

# %%
lambdas = np.concatenate([np.arange(.1,2,.1), np.arange(2,10)])

# %%
with open('KerasSavedModels/scala_2020/sRRR_vs_Bottleneck_rank2_CV.pickle', 'rb') as f:
    r2_sRRR_rank2, r2_sRRR_relaxed_rank2, r2_sRRR_rank2_tr, r2_sRRR_relaxed_rank2_tr, \
                nonzero_rank2, corrs_rank2, corrs_relaxed_rank2 = pickle.load(f)

# %%
with open('KerasSavedModels/scala_2020/sRRR_vs_Bottleneck_rank16_CV.pickle', 'rb') as f:
    r2_sRRR_rank16, r2_sRRR_relaxed_rank16, r2_sRRR_rank16_tr, r2_sRRR_relaxed_rank16_tr, \
                nonzero_rank16, corrs_rank16, corrs_relaxed_rank16 = pickle.load(f)

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_pre_tr.pickle', 'rb') as f:
    CE_loss, CE_loss_tr, pre_tr_hist, pre_tr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_straight_regr.pickle', 'rb') as f:
    r2_straight_regr, r2_straight_regr_tr, \
                 r2_straight_regr_hist, r2_straight_regr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_pre_tr_and_straight_regr.pickle', 'rb') as f:
    r2_pretr_straight_regr, r2_pretr_straight_regr_tr, \
                 r2_pretr_straight_regr_hist, r2_pretr_straight_regr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_pre_tr_and_freeze_unfreeze.pickle', 'rb') as f:
    r2_before_unfreezing, r2_before_unfreezing_tr, \
                 r2_after_unfreezing, r2_after_unfreezing_tr, \
                 r2_freeze_unfreeze_hist, r2_freeze_unfreeze_hist_tr = pickle.load(f)

# %%
linewidth = 2
sns_styleset()

r2_sRRR_relaxed_rank2[r2_sRRR_relaxed_rank2==0]=np.nan
r2_sRRR_relaxed_rank2_ =  np.nanmean(r2_sRRR_relaxed_rank2, axis = 0)
r2_sRRR_relaxed_rank16[r2_sRRR_relaxed_rank16==0]=np.nan
r2_sRRR_relaxed_rank16_ =  np.nanmean(r2_sRRR_relaxed_rank16, axis = 0)


# All together in one plot for the paper
fig = plt.figure(figsize=(19, 4.5))
widths = [1, 1, 2]
heights = [1]
spec = fig.add_gridspec(ncols=3, nrows=1, width_ratios=widths,
                          height_ratios=heights)
ax1 = fig.add_subplot(spec[0, 0])
ax1.plot(lambdas[np.nonzero(r2_sRRR_relaxed_rank16_[0, :])], \
             r2_sRRR_relaxed_rank16_[0, :][np.nonzero(r2_sRRR_relaxed_rank16_[0, :])], '.-', \
             c = np.array([0, 0, 0]) / 256, linewidth = linewidth, \
             label = 'r=16')
ax1.plot(lambdas[np.nonzero(r2_sRRR_relaxed_rank2_[0, :])], \
             r2_sRRR_relaxed_rank2_[0, :][np.nonzero(r2_sRRR_relaxed_rank2_[0, :])], '.-', \
             c = np.array([0, 0, 0])/256, linewidth = linewidth, \
             label = 'r=2')
ax1.annotate('RRR, r=16', (5, np.max(r2_sRRR_relaxed_rank16_)+0.0002), fontsize=15)
ax1.annotate('RRR, r=2', (5, np.max(r2_sRRR_relaxed_rank2_)+0.0002), fontsize=15)
ax1.set_xlabel(r'Ridge regularization parameter $\lambda$', fontsize = 17)
ax1.set_ylabel(r'Cross validated test $R^2$', fontsize = 17)
ax1.set_title('Reduced-rank regression', fontsize = 19, y=1.02)
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.tick_params(axis='both', which='minor', labelsize=15)
ax1.set_ylim([0.1,0.7])

ax2 = fig.add_subplot(spec[0, 1])
ax2.plot(range(50), np.mean(pre_tr_hist_tr, axis=(0, 1, 2)), \
         '--', c = 'k', linewidth=linewidth)
ax2.plot(range(50), np.mean(pre_tr_hist, axis=(0, 1, 2)), \
         c = 'k', linewidth=linewidth)
ax2.set_title('Pretraining', fontsize = 19, y=1.02)
ax2.set_xlabel('Epoch', fontsize = 17)
ax2.set_ylabel('Cross entropy loss', fontsize = 17)
ax2.tick_params(axis='both', which='major', labelsize=15)
ax2.tick_params(axis='both', which='minor', labelsize=15)
ax2.set_ylim([0, ax2.get_ylim()[1]])
ax2.annotate('Training', (40, 0.22), fontsize=15)
ax2.annotate('Test', (40, 6.3), fontsize=15)
ax2.set_xticks(np.arange(0, 60, 10))

ax3 = fig.add_subplot(spec[0, 2])
ax3.plot(range(100), np.mean(r2_freeze_unfreeze_hist_tr, axis=(0, 1, 2)), \
         '--', c = '#1b9e77', linewidth=linewidth)
ax3.plot(range(100), np.mean(r2_freeze_unfreeze_hist, axis=(0, 1, 2)), \
         c = '#1b9e77', linewidth=linewidth, label='Pre-training + freezing + unfreezing')
ax3.plot(range(50), np.mean(r2_pretr_straight_regr_hist_tr, axis=(0, 1, 2)), \
         '--', c = '#d95f02', linewidth=linewidth)
ax3.plot(range(50), np.mean(r2_pretr_straight_regr_hist, axis=(0, 1, 2)), \
         c = '#d95f02', linewidth=linewidth, label='Pre-training + no freezing')
ax3.plot(range(50), np.mean(r2_straight_regr_hist_tr, axis=(0, 1, 2)), \
         '--', c = '#7570b3', linewidth=linewidth)
ax3.plot(range(50), np.mean(r2_straight_regr_hist, axis=(0, 1, 2)), \
         c = '#7570b3', linewidth=linewidth, label='No pre-training')
ax3.hlines(np.max(r2_sRRR_relaxed_rank2_), xmin = 0, xmax = 120, \
            colors = np.array([0,0,0])/256)
ax3.annotate('RRR, r=2', (85, np.max(r2_sRRR_relaxed_rank2_)+0.005), fontsize=15)
ax3.hlines(np.max(r2_sRRR_relaxed_rank16_), xmin = 0, xmax = 120, \
           colors = np.array([0,0,0])/256)
ax3.annotate('RRR, r=16', (85, np.max(r2_sRRR_relaxed_rank16_)+0.005), fontsize=15)
ax3.legend(loc = 'lower right', fontsize=15)
ax3.set_ylim([0.1,0.7])
ax3.set_xlim([0,100])
ax3.set_title('Bottleneck neural network', fontsize = 19, y=1.02)
ax3.set_xlabel('Epoch', fontsize = 17)
ax3.set_ylabel(r'$R^2$', fontsize = 17)
ax3.tick_params(axis='both', which='major', labelsize=15)
ax3.tick_params(axis='both', which='minor', labelsize=15)
ax3.set_xticks(np.arange(0, 110, 10))
ax3.vlines(50, ymin=0, ymax=ax3.get_ylim()[1], linestyle='dashed')

plt.text(-0.22, 1.04, 'a', transform = ax1.transAxes, fontsize=25, fontweight='bold')
plt.text(-0.16, 1.04, 'b', transform = ax2.transAxes, fontsize=25, fontweight='bold')
plt.text(-0.12, 1.04, 'c', transform = ax3.transAxes, fontsize=25, fontweight='bold')
sns.despine()
plt.savefig('figures/Ridge_training_curves.pdf', bbox_inches = 'tight',
    pad_inches = 0)
plt.savefig('figures/Ridge_training_curves.png', bbox_inches = 'tight',
    pad_inches = 0)

# %% [markdown]
# # Add lasso

# %% [markdown]
# It seems that pre-train - train 4 last layers - train all layers is a good bottleneck non-linear model. Let us add a lasso group penalty now and investigate which genes the model would select. After the usual training as above we also prune the bottleneck further. In essence we pick the 25 genes that correspond to highest L2 row norm for the first kernel/weight of the input layer and perform the same regression task but with this reduced new 25 nodes input layer. No lasso, just ridge for this pruned network. We investigate which genes are selected, visualise the latent space and compare to a well-known sparse reduced-rank model for this dataset. Again, one can skip the training and go direct to visualization for already trained models.

# %% [markdown]
# Our ridge + lasso penalty straight regression (no pre-training) model.

# %%
importlib.reload(bottleneck_networks)
# Out:
# <module 'bottleneck_networks' from '/gpfs01/berens/user/ybernaerts/EphysAnalysis/data/ephys/sBNN/bottleneck_networks.py'>

# %%
from bottleneck_networks import StraightRegression

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([1e-1])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
prune=True
patience=epochs

r2_straight_regr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_straight_regr_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_straight_regr_ap = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_straight_regr_ap_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_straight_regr_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))
r2_straight_regr_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

nodes_list=[512,128,2,128,512]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    input_dim = x_train.shape[1]
    output_dim = y_train.shape[1]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)
            BN_StraightRegression = StraightRegression(l1=l1, l2=l2, lr=lr, act=act, \
                                                       input_dim=input_dim, output_dim=output_dim, nodes_list=nodes_list)
            r2_train, r2_test, \
                r2_ap_train, r2_ap_test, \
                train_hist, test_hist = BN_StraightRegression.train(x_train=x_train, y_train=y_train, \
                                                                                   x_test=x_test, y_test=y_test, \
                                                                                   epochs=epochs, bs=bs, patience=patience, \
                                                                                   cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                                   prune=prune, geneNames=gene_names, \
                                                                                   verbose=0)
            r2_straight_regr[cvfold, j, i] = r2_test
            r2_straight_regr_tr[cvfold, j, i] = r2_train
            r2_straight_regr_ap[cvfold, j, i] = r2_ap_test
            r2_straight_regr_ap_tr[cvfold, j, i] = r2_ap_train
            r2_straight_regr_hist[cvfold, j, i] = test_hist
            r2_straight_regr_hist_tr[cvfold, j, i] = train_hist
            #print('Test R^2 score (straight regression, no pre-tr): ', r2_straight_regr[cvfold, j, i])
            #print('Test R^2 score after pruning (straight regression, no pre-tr): ', r2_straight_regr_ap[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# The 25 genes that make it:  ['6720468P15Rik' 'Gabra1' 'Slc6a1' 'Pde1a' 'Gm49948' 'Col24a1' 'Kcnip2'
#  'Rit2' 'Gm43670' 'Plch2' 'Gm11549' 'Enpp2' 'Grm7' 'Cplx1' 'Mybpc1'
#  'Galnt14' 'Htr3a' 'Atp1a3' 'Ndn' 'Lamp5' 'Erbb4' 'Tac2' 'Sst' 'Gad1'
#  'Pvalb']
# [INFO] training network...
# Train R^2 before pruning:  0.41570526361465454
# Test R^2 after pruning:  0.4180135726928711
# Train R^2 after pruning:  0.39661920070648193
# Test R^2 after pruning:  0.4073665142059326
#
# CVFOLD:  1
# [INFO] training network...
# The 25 genes that make it:  ['Unc13c' 'Gpm6b' 'Pde1a' 'Ptk2b' 'Chl1' 'Cck' 'Nrip3' 'Enpp2' 'Cdc42se2'
#  'Cplx1' 'Galnt14' 'Gm43670' 'Elfn1' 'Slc6a1' 'Erbb4' 'Htr3a' 'Ndn'
#  'Plch2' 'Gm49948' 'Lamp5' 'Atp1a3' 'Tac2' 'Gad1' 'Sst' 'Pvalb']
# [INFO] training network...
# Train R^2 before pruning:  0.409093976020813
# Test R^2 after pruning:  0.3808169960975647
# Train R^2 after pruning:  0.40867096185684204
# Test R^2 after pruning:  0.3771156072616577
#
# CVFOLD:  2
# [INFO] training network...
# The 25 genes that make it:  ['Col24a1' 'Cacna2d1' 'Unc13c' 'Enpp2' 'Nell1' 'Phactr1' 'Elfn1' 'Mybpc1'
#  'Ptk2b' 'Gabra1' 'Satb1' 'Cplx1' 'Mas1' 'Gm11549' 'Htr3a' 'Plch2'
#  'Galnt14' 'Sst' 'Atp1a3' 'Ndn' 'Lamp5' 'Tac2' 'Erbb4' 'Gad1' 'Pvalb']
# [INFO] training network...
# Train R^2 before pruning:  0.41975224018096924
# Test R^2 after pruning:  0.36399954557418823
# Train R^2 after pruning:  0.40865933895111084
# Test R^2 after pruning:  0.3653857707977295
#
# CVFOLD:  3
# [INFO] training network...
# The 25 genes that make it:  ['Kcnv1' 'Tafa1' 'Kcnc2' 'Kcnip2' 'Gm49948' 'Afap1' 'Gabra1' 'Sema3c'
#  'Elmo1' 'Grm7' 'Tac1' 'Ndn' 'Cacna1e' 'Cplx1' 'Mas1' 'Tac2' 'Lamp5'
#  'Galnt14' 'Mybpc1' 'Plch2' 'Erbb4' 'Htr3a' 'Sst' 'Gad1' 'Pvalb']
# [INFO] training network...
# Train R^2 before pruning:  0.4211997389793396
# Test R^2 after pruning:  0.36298179626464844
# Train R^2 after pruning:  0.406345009803772
# Test R^2 after pruning:  0.36840367317199707
#
# CVFOLD:  4
# [INFO] training network...
# The 25 genes that make it:  ['Gabra1' 'Kcnip2' 'Unc13c' 'Gas7' 'Slc6a1' 'Dusp14' 'Cacna1e' 'Ptk2b'
#  'Nell2' 'Atp1a3' 'Grm7' 'Plch2' 'Mybpc1' 'Galnt14' 'Phactr1' 'Elfn1'
#  'Tac2' 'Erbb4' 'Gm49948' 'Lamp5' 'Ndn' 'Htr3a' 'Gad1' 'Sst' 'Pvalb']
# [INFO] training network...
# Train R^2 before pruning:  0.41548484563827515
# Test R^2 after pruning:  0.36844396591186523
# Train R^2 after pruning:  0.4162555932998657
# Test R^2 after pruning:  0.36746740341186523
#
# CVFOLD:  5
# [INFO] training network...
# The 25 genes that make it:  ['Npy1r' 'Enpp2' 'Cbln2' 'Kcnip2' 'Elmo1' 'Grm7' 'Chrnb3' 'Atp1a3' 'Elfn1'
#  'Gm49948' 'Galnt14' 'Cacna1e' 'Cplx1' 'Mybpc1' 'Erbb4' 'Nell1' 'Ndn'
#  'Slc6a1' 'Plch2' 'Lamp5' 'Htr3a' 'Tac2' 'Gad1' 'Sst' 'Pvalb']
# [INFO] training network...
# Train R^2 before pruning:  0.41276872158050537
# Test R^2 after pruning:  0.3574713468551636
# Train R^2 after pruning:  0.4078674912452698
# Test R^2 after pruning:  0.3545805811882019
#
# CVFOLD:  6
# [INFO] training network...
# The 25 genes that make it:  ['Tiam2' 'Dusp14' 'Gabra1' 'Unc13c' 'Elmo1' 'Mybpc1' 'Enpp2' 'Gm11549'
#  'Tac1' 'Elfn1' 'Cplx1' 'Afap1' 'Gabrd' 'Gm43670' 'Galnt14' 'Erbb4' 'Ndn'
#  'Gm49948' 'Atp1a3' 'Tac2' 'Htr3a' 'Lamp5' 'Gad1' 'Sst' 'Pvalb']
# [INFO] training network...
# Train R^2 before pruning:  0.4102100729942322
# Test R^2 after pruning:  0.37939149141311646
# Train R^2 after pruning:  0.40801310539245605
# Test R^2 after pruning:  0.3882436752319336
#
# CVFOLD:  7
# [INFO] training network...
# The 25 genes that make it:  ['Mical2' 'Elmo1' 'Kcnip2' 'Gabra1' 'Foxred1' 'Cacna1e' 'Cplx1' 'Satb1'
#  'Enpp2' 'Phactr1' 'Mybpc1' 'Plch2' 'Npy1r' 'Galnt14' 'Slc6a1' 'Erbb4'
#  'Gm49948' 'Ndn' 'Atp1a3' 'Htr3a' 'Lamp5' 'Tac2' 'Sst' 'Gad1' 'Pvalb']
# [INFO] training network...
# Train R^2 before pruning:  0.40541136264801025
# Test R^2 after pruning:  0.40891629457473755
# Train R^2 after pruning:  0.407467782497406
# Test R^2 after pruning:  0.41348791122436523
#
# CVFOLD:  8
# [INFO] training network...
# The 25 genes that make it:  ['Nell1' 'Afap1' 'Elfn1' 'Thsd7a' 'Enpp2' 'Mybpc1' 'Ptk2b' 'Grm7' 'Elmo1'
#  'Cplx1' 'Gabrd' 'Plch2' 'Erbb4' 'Tac2' 'Cacna1e' 'Galnt14' 'Gabra1'
#  'Gm49948' 'Lamp5' 'Htr3a' 'Atp1a3' 'Ndn' 'Sst' 'Pvalb' 'Gad1']
# [INFO] training network...
# Train R^2 before pruning:  0.42230290174484253
# Test R^2 after pruning:  0.35962235927581787
# Train R^2 after pruning:  0.41576290130615234
# Test R^2 after pruning:  0.3551616072654724
#
# CVFOLD:  9
# [INFO] training network...
# The 25 genes that make it:  ['Nell1' 'Cacna1e' 'Gm11549' 'Grip1' 'Tiam2' 'Enpp2' 'Grm7' 'Ube3a'
#  'Phactr1' 'Gabrd' 'Gm49948' 'Plch2' 'Cplx1' 'Gabra1' 'Galnt14' 'Elfn1'
#  'Atp1a3' 'Tac2' 'Lamp5' 'Erbb4' 'Ndn' 'Htr3a' 'Gad1' 'Sst' 'Pvalb']
# [INFO] training network...
# Train R^2 before pruning:  0.39044398069381714
# Test R^2 after pruning:  0.38938063383102417
# Train R^2 after pruning:  0.41285914182662964
# Test R^2 after pruning:  0.39695703983306885
# Time: 0.0h  6m 40s

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_straight_regr_lasso.pickle', 'wb') as f:
    pickle.dump([r2_straight_regr, r2_straight_regr_tr, \
                 r2_straight_regr_ap, r2_straight_regr_ap_tr, \
                 r2_straight_regr_hist, r2_straight_regr_hist_tr], f)

# %% [markdown]
# Our ridge + lasso penalty classification pre-training model.

# %%
from bottleneck_networks import ClassificationPreTrain

# %%
# Immediately for different penalties, but we'll be only interested in the 1e-1 penalty (for now), i.e. see extensions later
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([1e-4, 1e-2, 1e-1, 1])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs


t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]
clusters_ = clusters[ind]
ind_pre_train = ind_pre_training_clusters[ind]

CE_loss = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
CE_loss_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
pre_tr_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
pre_tr_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))

nodes_list=[512,128,2,128,512]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    clusters_train = np.copy(clusters_[indtrain])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    clusters_test = np.copy(clusters_[indtest])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean

    # In our training set we now look for a 'pretraining' training and test data set that we can use
    # for pretraing a classification network, i.e. picking the best model will be dones with a seperate val set in our
    # training set for regression.

    x_train_pre_tr = x_train[ind_pre_train[indtrain], :]
    clusters_train_pre_tr = clusters_train[ind_pre_train[indtrain]]
    
    pre_train_size = 0.6
    train_cnt = round(x_train_pre_tr.shape[0]*pre_train_size)
    x_train_pre_tr_ = x_train_pre_tr[:train_cnt, :]
    x_test_pre_tr_ = x_train_pre_tr[train_cnt:, :]
    clusters_train_pre_tr_ = clusters_train_pre_tr[:train_cnt]
    clusters_test_pre_tr_ = clusters_train_pre_tr[train_cnt:]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)


            input_dim = x_train.shape[1]
            output_dim = to_categorical(clusters_train_pre_tr).shape[1]
            BN_Classification = ClassificationPreTrain(l1=l1, l2=l2, lr=lr, act=act, input_dim=input_dim, \
                                                       output_dim=output_dim, nodes_list=nodes_list)
            CE_train, CE_test, train_hist, test_hist = BN_Classification.train(x_train=x_train_pre_tr_, \
                                                                               cluster_train=clusters_train_pre_tr_, \
                                                                               x_test=x_test_pre_tr_, \
                                                                               cluster_test=clusters_test_pre_tr_, \
                                                                               epochs=epochs, bs=bs, patience=patience, \
                                                                               cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                               verbose=0)
            CE_loss[cvfold, j, i] = CE_test
            CE_loss_tr[cvfold, j, i] = CE_train
            pre_tr_hist[cvfold, j, i] = test_hist
            pre_tr_hist_tr[cvfold, j, i] = train_hist
            #print('Test CE loss (pre-trainin): ', CE_loss[cvfold, j, i])
            
t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# 655/655 [==============================] - 0s 177us/sample - loss: 1.7369 - categorical_crossentropy: 1.6545
# 437/437 [==============================] - 0s 78us/sample - loss: 2.2468 - categorical_crossentropy: 2.1645
# [INFO] training network...
# 655/655 [==============================] - 0s 180us/sample - loss: 9.1548 - categorical_crossentropy: 1.7743
# 437/437 [==============================] - 0s 84us/sample - loss: 9.4330 - categorical_crossentropy: 2.0526
# [INFO] training network...
# 655/655 [==============================] - 0s 231us/sample - loss: 51.5533 - categorical_crossentropy: 1.6625
# 437/437 [==============================] - 0s 101us/sample - loss: 51.8908 - categorical_crossentropy: 2.0000
# [INFO] training network...
# 655/655 [==============================] - 0s 191us/sample - loss: 3.4591 - categorical_crossentropy: 2.0715
# 437/437 [==============================] - 0s 92us/sample - loss: 3.4690 - categorical_crossentropy: 2.0813
#
# CVFOLD:  1
# [INFO] training network...
# 655/655 [==============================] - 0s 244us/sample - loss: 1.7659 - categorical_crossentropy: 1.6835
# 437/437 [==============================] - 0s 99us/sample - loss: 2.1202 - categorical_crossentropy: 2.0378
# [INFO] training network...
# 655/655 [==============================] - 0s 216us/sample - loss: 8.7989 - categorical_crossentropy: 1.5394
# 437/437 [==============================] - 0s 99us/sample - loss: 9.2114 - categorical_crossentropy: 1.9519
# [INFO] training network...
# 655/655 [==============================] - 0s 187us/sample - loss: 48.1282 - categorical_crossentropy: 1.5475
# 437/437 [==============================] - 0s 88us/sample - loss: 48.5344 - categorical_crossentropy: 1.9537
# [INFO] training network...
# 655/655 [==============================] - 0s 177us/sample - loss: 3.5290 - categorical_crossentropy: 2.0135
# 437/437 [==============================] - 0s 97us/sample - loss: 3.5493 - categorical_crossentropy: 2.0338
#
# CVFOLD:  2
# [INFO] training network...
# 655/655 [==============================] - 0s 194us/sample - loss: 1.8251 - categorical_crossentropy: 1.7429
# 437/437 [==============================] - 0s 96us/sample - loss: 2.1332 - categorical_crossentropy: 2.0510
# [INFO] training network...
# 655/655 [==============================] - 0s 180us/sample - loss: 8.9067 - categorical_crossentropy: 1.6353
# 437/437 [==============================] - 0s 89us/sample - loss: 9.2451 - categorical_crossentropy: 1.9737
# [INFO] training network...
# 655/655 [==============================] - 0s 192us/sample - loss: 48.2258 - categorical_crossentropy: 1.5399
# 437/437 [==============================] - 0s 86us/sample - loss: 48.7135 - categorical_crossentropy: 2.0275
# [INFO] training network...
# 655/655 [==============================] - 0s 183us/sample - loss: 3.4678 - categorical_crossentropy: 1.8941
# 437/437 [==============================] - 0s 83us/sample - loss: 3.5160 - categorical_crossentropy: 1.9422
#
# CVFOLD:  3
# [INFO] training network...
# 655/655 [==============================] - 0s 202us/sample - loss: 1.8506 - categorical_crossentropy: 1.7682
# 437/437 [==============================] - 0s 93us/sample - loss: 2.1921 - categorical_crossentropy: 2.1098
# [INFO] training network...
# 655/655 [==============================] - 0s 181us/sample - loss: 9.1519 - categorical_crossentropy: 1.7106
# 437/437 [==============================] - 0s 96us/sample - loss: 9.4688 - categorical_crossentropy: 2.0274
# [INFO] training network...
# 655/655 [==============================] - 0s 269us/sample - loss: 51.4315 - categorical_crossentropy: 1.6174
# 437/437 [==============================] - 0s 103us/sample - loss: 51.7888 - categorical_crossentropy: 1.9747
# [INFO] training network...
# 655/655 [==============================] - 0s 200us/sample - loss: 61.8697 - categorical_crossentropy: 1.6835
# 437/437 [==============================] - 0s 100us/sample - loss: 62.1641 - categorical_crossentropy: 1.9779
#
# CVFOLD:  4
# [INFO] training network...
# 655/655 [==============================] - 0s 217us/sample - loss: 1.5428 - categorical_crossentropy: 1.4603
# 437/437 [==============================] - 0s 110us/sample - loss: 2.0122 - categorical_crossentropy: 1.9298
# [INFO] training network...
# 655/655 [==============================] - 0s 235us/sample - loss: 9.2870 - categorical_crossentropy: 1.8110
# 437/437 [==============================] - 0s 112us/sample - loss: 9.6402 - categorical_crossentropy: 2.1642
# [INFO] training network...
# 655/655 [==============================] - 0s 217us/sample - loss: 47.8580 - categorical_crossentropy: 1.5955
# 437/437 [==============================] - 0s 111us/sample - loss: 48.2340 - categorical_crossentropy: 1.9715
# [INFO] training network...
# 655/655 [==============================] - 0s 198us/sample - loss: 3.4289 - categorical_crossentropy: 1.9546
# 437/437 [==============================] - 0s 96us/sample - loss: 3.4777 - categorical_crossentropy: 2.0034
#
# CVFOLD:  5
# [INFO] training network...
# 655/655 [==============================] - 0s 192us/sample - loss: 1.6306 - categorical_crossentropy: 1.5482
# 437/437 [==============================] - 0s 89us/sample - loss: 2.0262 - categorical_crossentropy: 1.9439
# [INFO] training network...
# 655/655 [==============================] - 0s 223us/sample - loss: 9.2605 - categorical_crossentropy: 1.8290
# 437/437 [==============================] - 0s 107us/sample - loss: 9.5020 - categorical_crossentropy: 2.0705
# [INFO] training network...
# 655/655 [==============================] - 0s 179us/sample - loss: 48.2740 - categorical_crossentropy: 1.5489
# 437/437 [==============================] - 0s 84us/sample - loss: 48.6992 - categorical_crossentropy: 1.9741
# [INFO] training network...
# 655/655 [==============================] - 0s 185us/sample - loss: 86.9648 - categorical_crossentropy: 1.6226
# 437/437 [==============================] - 0s 86us/sample - loss: 87.2890 - categorical_crossentropy: 1.9468
#
# CVFOLD:  6
# [INFO] training network...
# 655/655 [==============================] - 0s 176us/sample - loss: 1.7780 - categorical_crossentropy: 1.6956
# 437/437 [==============================] - 0s 87us/sample - loss: 2.1566 - categorical_crossentropy: 2.0743
# [INFO] training network...
# 655/655 [==============================] - 0s 180us/sample - loss: 8.8056 - categorical_crossentropy: 1.5973
# 437/437 [==============================] - 0s 83us/sample - loss: 9.3801 - categorical_crossentropy: 2.1718
# [INFO] training network...
# 655/655 [==============================] - 0s 197us/sample - loss: 51.6188 - categorical_crossentropy: 1.5839
# 437/437 [==============================] - 0s 86us/sample - loss: 52.0460 - categorical_crossentropy: 2.0110
# [INFO] training network...
# 655/655 [==============================] - 0s 182us/sample - loss: 38.3806 - categorical_crossentropy: 1.7110
# 437/437 [==============================] - 0s 86us/sample - loss: 38.6433 - categorical_crossentropy: 1.9737
#
# CVFOLD:  7
# [INFO] training network...
# 655/655 [==============================] - 0s 187us/sample - loss: 1.7324 - categorical_crossentropy: 1.6500
# 437/437 [==============================] - 0s 92us/sample - loss: 2.2545 - categorical_crossentropy: 2.1721
# [INFO] training network...
# 655/655 [==============================] - 0s 180us/sample - loss: 9.3705 - categorical_crossentropy: 1.9670
# 437/437 [==============================] - 0s 97us/sample - loss: 9.8639 - categorical_crossentropy: 2.4604
# [INFO] training network...
# 655/655 [==============================] - 0s 190us/sample - loss: 48.3102 - categorical_crossentropy: 1.6344
# 437/437 [==============================] - 0s 101us/sample - loss: 48.8627 - categorical_crossentropy: 2.1869
# [INFO] training network...
# 655/655 [==============================] - 0s 206us/sample - loss: 62.0466 - categorical_crossentropy: 1.6569
# 437/437 [==============================] - 0s 100us/sample - loss: 62.3794 - categorical_crossentropy: 1.9897
#
# CVFOLD:  8
# [INFO] training network...
# 655/655 [==============================] - 0s 282us/sample - loss: 1.6284 - categorical_crossentropy: 1.5459
# 437/437 [==============================] - 0s 105us/sample - loss: 2.0820 - categorical_crossentropy: 1.9996
# [INFO] training network...
# 655/655 [==============================] - 0s 225us/sample - loss: 8.7700 - categorical_crossentropy: 1.5716
# 437/437 [==============================] - 0s 97us/sample - loss: 9.4245 - categorical_crossentropy: 2.2261
# [INFO] training network...
# 655/655 [==============================] - 0s 209us/sample - loss: 55.0447 - categorical_crossentropy: 1.6187
# 437/437 [==============================] - 0s 98us/sample - loss: 55.3755 - categorical_crossentropy: 1.9495
# [INFO] training network...
# 655/655 [==============================] - 0s 194us/sample - loss: 3.4111 - categorical_crossentropy: 2.0757
# 437/437 [==============================] - 0s 94us/sample - loss: 3.4439 - categorical_crossentropy: 2.1085
#
# CVFOLD:  9
# [INFO] training network...
# 655/655 [==============================] - 0s 189us/sample - loss: 1.7840 - categorical_crossentropy: 1.7016
# 437/437 [==============================] - 0s 89us/sample - loss: 2.2730 - categorical_crossentropy: 2.1906
# [INFO] training network...
# 655/655 [==============================] - 0s 181us/sample - loss: 8.7362 - categorical_crossentropy: 1.6696
# 437/437 [==============================] - 0s 87us/sample - loss: 9.1438 - categorical_crossentropy: 2.0772
# [INFO] training network...
# 655/655 [==============================] - 0s 189us/sample - loss: 51.4237 - categorical_crossentropy: 1.6019
# 437/437 [==============================] - 0s 97us/sample - loss: 51.7803 - categorical_crossentropy: 1.9586
# [INFO] training network...
# 655/655 [==============================] - 0s 180us/sample - loss: 140.3867 - categorical_crossentropy: 1.6379
# 437/437 [==============================] - 0s 90us/sample - loss: 140.6926 - categorical_crossentropy: 1.9438
# Time: 0.0h  7m  9s

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_pre_tr_lasso.pickle', 'wb') as f:
    pickle.dump([CE_loss, CE_loss_tr, pre_tr_hist, pre_tr_hist_tr], f)

# %% [markdown]
# Our lasso + ridge penalty pre-train and regression model.

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([1e-1])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs
pre_trained_weights=True
prune=True

r2_pretr_straight_regr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_pretr_straight_regr_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_pretr_straight_regr_ap = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_pretr_straight_regr_ap_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_pretr_straight_regr_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))
r2_pretr_straight_regr_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

nodes_list=[512,128,2,128,512]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    input_dim = x_train.shape[1]
    output_dim = y_train.shape[1]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)
            
            pre_trained_weights_h5 = 'KerasSavedModels/Classification_last_weights_{}_{}_{}.h5'.format(cvfold, 2, i)
            
            BN_PreTrStraightRegression = StraightRegression(l1=l1, l2=l2, lr=lr, act=act, \
                                            input_dim=input_dim, output_dim=output_dim, \
                                            pre_trained_weights=pre_trained_weights, \
                                            pre_trained_weights_h5=pre_trained_weights_h5, nodes_list=nodes_list)
            r2_train, r2_test, \
                r2_train_ap, r2_test_ap, \
                train_hist, test_hist = BN_PreTrStraightRegression.train(x_train=x_train, y_train=y_train, \
                                                                                   x_test=x_test, y_test=y_test, \
                                                                                   epochs=epochs, bs=bs, patience=patience, \
                                                                                   cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                                   prune=prune, geneNames=gene_names, \
                                                                                   verbose=0)
            r2_pretr_straight_regr[cvfold, j, i] = r2_test
            r2_pretr_straight_regr_tr[cvfold, j, i] = r2_train
            r2_pretr_straight_regr_ap[cvfold, j, i] = r2_test_ap
            r2_pretr_straight_regr_ap_tr[cvfold, j, i] = r2_train_ap            
            r2_pretr_straight_regr_hist[cvfold, j, i] = test_hist
            r2_pretr_straight_regr_hist_tr[cvfold, j, i] = train_hist
            #print('Test R^2 score (regression, after pre-tr): ', r2_pretr_straight_regr[cvfold, j, i])
            #print('Test R^2 score (regression, after pre-tr), after pruning: ', r2_pretr_straight_regr_ap[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# The 25 genes that make it:  ['Nell2' 'Gm11549' 'Afap1' 'Elfn1' 'Brinp1' 'Plch2' 'Grm7' 'Unc13c'
#  'Ndst3' 'Atp1a3' 'Chat' 'Enpp2' 'Col24a1' 'Htr3a' 'Cplx1' 'Galnt14'
#  'Kcnip2' 'Gm49948' 'Ndn' 'Vip' 'Lamp5' 'Tac2' 'Gad1' 'Pvalb' 'Sst']
# [INFO] training network...
# Train R^2 before pruning:  0.44345253705978394
# Test R^2 after pruning:  0.44732236862182617
# Train R^2 after pruning:  0.4236641526222229
# Test R^2 after pruning:  0.44430726766586304
#
# CVFOLD:  1
# [INFO] training network...
# The 25 genes that make it:  ['Ighm' 'Cdc42se2' 'Elfn1' 'Gm11549' 'Gm43670' 'Grm7' 'Chl1' 'Kcnc2'
#  'Kcnip2' 'Unc13c' 'Vip' 'Cck' 'Chat' 'Enpp2' 'Galnt14' 'Ndn' 'Htr3a'
#  'Plch2' 'Gm49948' 'Atp1a3' 'Lamp5' 'Tac2' 'Gad1' 'Pvalb' 'Sst']
# [INFO] training network...
# Train R^2 before pruning:  0.45086514949798584
# Test R^2 after pruning:  0.4176298975944519
# Train R^2 after pruning:  0.4255531430244446
# Test R^2 after pruning:  0.4035070538520813
#
# CVFOLD:  2
# [INFO] training network...
# The 25 genes that make it:  ['Grm7' 'Ptk2b' 'Sparcl1' 'Phactr1' 'Gm49948' 'Gabra1' 'Kcnip2' 'Enpp2'
#  'Atp1a3' 'Gm11549' 'Mas1' 'Htr3a' 'Elfn1' 'Ndst3' 'Plch2' 'Unc13c' 'Chat'
#  'Galnt14' 'Vip' 'Ndn' 'Tac2' 'Lamp5' 'Gad1' 'Pvalb' 'Sst']
# [INFO] training network...
# Train R^2 before pruning:  0.44741111993789673
# Test R^2 after pruning:  0.395305871963501
# Train R^2 after pruning:  0.43002164363861084
# Test R^2 after pruning:  0.38785696029663086
#
# CVFOLD:  3
# [INFO] training network...
# The 25 genes that make it:  ['Afap1' 'Mical2' 'Grip1' 'Unc13c' 'Foxred1' 'Sema3c' 'Grm7' 'Cacna1e'
#  'Mgst1' 'Kcnc2' 'Gabrd' 'Kcnip2' 'Mas1' 'Plch2' 'Galnt14' 'Chat' 'Ndn'
#  'Ndst3' 'Gm49948' 'Tac2' 'Lamp5' 'Htr3a' 'Gad1' 'Pvalb' 'Sst']
# [INFO] training network...
# Train R^2 before pruning:  0.44490450620651245
# Test R^2 after pruning:  0.4113273024559021
# Train R^2 after pruning:  0.4281201958656311
# Test R^2 after pruning:  0.3971365690231323
#
# CVFOLD:  4
# [INFO] training network...
# The 25 genes that make it:  ['Arpp19' 'Chat' 'Sparcl1' 'Dusp14' 'Cacna1e' 'Phactr1' 'Col24a1' 'Mas1'
#  'Grm7' 'Plch2' 'Kcnip2' 'Elfn1' 'Nell2' 'Galnt14' 'Unc13c' 'Gm49948'
#  'Ndst3' 'Tac2' 'Htr3a' 'Ndn' 'Gad1' 'Lamp5' 'Vip' 'Pvalb' 'Sst']
# [INFO] training network...
# Train R^2 before pruning:  0.4583510160446167
# Test R^2 after pruning:  0.39109063148498535
# Train R^2 after pruning:  0.4306224584579468
# Test R^2 after pruning:  0.3865792751312256
#
# CVFOLD:  5
# [INFO] training network...
# The 25 genes that make it:  ['Mas1' 'Slc6a1' 'Elmo1' 'Chrnb3' 'Cxcl14' 'Nell1' 'Grip1' 'Cplx1'
#  'Cacna1e' 'Grm7' 'Unc13c' 'Gm49948' 'Kcnip2' 'Plch2' 'Chat' 'Galnt14'
#  'Htr3a' 'Ndst3' 'Ndn' 'Tac2' 'Lamp5' 'Gad1' 'Vip' 'Sst' 'Pvalb']
# [INFO] training network...
# Train R^2 before pruning:  0.4566476345062256
# Test R^2 after pruning:  0.3970375061035156
# Train R^2 after pruning:  0.429040789604187
# Test R^2 after pruning:  0.3732869625091553
#
# CVFOLD:  6
# [INFO] training network...
# The 25 genes that make it:  ['Dlx6os1' 'Kcnip2' 'Pfkp' 'Phactr1' 'Nell1' 'Tiam2' 'Elfn1' 'Atp1a3'
#  'Enpp2' 'Chat' 'Vip' 'Gm11549' 'Gabrd' 'Afap1' 'Galnt14' 'Unc13c'
#  'Gm49948' 'Ndn' 'Ndst3' 'Htr3a' 'Gad1' 'Tac2' 'Lamp5' 'Pvalb' 'Sst']
# [INFO] training network...
# Train R^2 before pruning:  0.45127201080322266
# Test R^2 after pruning:  0.4125775694847107
# Train R^2 after pruning:  0.4244108200073242
# Test R^2 after pruning:  0.40557098388671875
#
# CVFOLD:  7
# [INFO] training network...
# The 25 genes that make it:  ['Enpp2' 'Npy1r' '6330403K07Rik' 'Unc13c' 'Phactr1' 'Chat' 'Kcnip2'
#  'Afap1' 'Nell2' 'Mical2' 'Satb1' 'Plch2' 'Grm7' 'Atp1a3' 'Gm49948'
#  'Htr3a' 'Ndst3' 'Galnt14' 'Ndn' 'Gad1' 'Tac2' 'Lamp5' 'Sst' 'Vip' 'Pvalb']
# [INFO] training network...
# Train R^2 before pruning:  0.4470069408416748
# Test R^2 after pruning:  0.444327712059021
# Train R^2 after pruning:  0.42270469665527344
# Test R^2 after pruning:  0.4335944652557373
#
# CVFOLD:  8
# [INFO] training network...
# The 25 genes that make it:  ['Cxcl14' 'Mas1' 'Elmo1' 'Cck' 'Unc13c' 'Vip' 'Ptk2b' 'Plch2' 'Gabrd'
#  'Ndst3' 'Cacna1e' 'Kcnip2' 'Afap1' 'Gabra1' 'Grm7' 'Atp1a3' 'Galnt14'
#  'Tac2' 'Gm49948' 'Htr3a' 'Ndn' 'Lamp5' 'Pvalb' 'Gad1' 'Sst']
# [INFO] training network...
# Train R^2 before pruning:  0.4584214687347412
# Test R^2 after pruning:  0.40038031339645386
# Train R^2 after pruning:  0.4328739047050476
# Test R^2 after pruning:  0.37454450130462646
#
# CVFOLD:  9
# [INFO] training network...
# The 25 genes that make it:  ['Ube3a' 'Enpp2' 'Gabrd' 'Cacna1e' 'Gm11549' 'Gabra1' 'Elfn1' 'Sema3c'
#  'Atp1a3' 'Plch2' 'Erbb4' 'Gm49948' 'Ndst3' 'Chat' 'Grm7' 'Tiam2'
#  'Galnt14' 'Tac2' 'Ndn' 'Htr3a' 'Lamp5' 'Vip' 'Gad1' 'Pvalb' 'Sst']
# [INFO] training network...
# Train R^2 before pruning:  0.43136489391326904
# Test R^2 after pruning:  0.4184696078300476
# Train R^2 after pruning:  0.42924052476882935
# Test R^2 after pruning:  0.3936580419540405
# Time: 0.0h  6m 26s

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_pre_tr_and_straight_regr_lasso.pickle', 'wb') as f:
    pickle.dump([r2_pretr_straight_regr, r2_pretr_straight_regr_tr, \
                 r2_pretr_straight_regr_ap, r2_pretr_straight_regr_ap_tr, \
                 r2_pretr_straight_regr_hist, r2_pretr_straight_regr_hist_tr], f)

# %% [markdown]
# Our lasso + ridge penalty pre-train + freeze the first 2 layers + unfreeze model.

# %%
from bottleneck_networks import FreezeUnfreeze

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([1e-4, 1e-2, 1e-1, 1])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs
pre_trained_weights=True
unfreeze = [False, False, True, True, True, True] # last 4 layers can be trained only first
prune=True

r2_before_unfreezing = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_before_unfreezing_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_ap = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_ap_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_freeze_unfreeze_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))
r2_freeze_unfreeze_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

nodes_list=[512,128,2,128,512]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    input_dim = x_train.shape[1]
    output_dim = y_train.shape[1]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)
            
            pre_trained_weights_h5 = 'KerasSavedModels/Classification_last_weights_{}_{}_{}.h5'.format(cvfold, j, i)
            input_dim = x_train.shape[1]
            output_dim = y_train.shape[1]
            BN_PreTrFreezeUnfreeze = FreezeUnfreeze(l1=l1, l2=l2, lr=lr, act=act, input_dim=input_dim, output_dim=output_dim, \
                                                       unfreeze = unfreeze, \
                                                       pre_trained_weights=pre_trained_weights, \
                                                       pre_trained_weights_h5=pre_trained_weights_h5, nodes_list=nodes_list)
            r2_before_unfreezing_train, r2_before_unfreezing_test, \
                r2_after_unfreezing_train, r2_after_unfreezing_test, \
                r2_after_unfreezing_train_ap, r2_after_unfreezing_test_ap, \
                train_hist, test_hist = BN_PreTrFreezeUnfreeze.train(x_train=x_train, y_train=y_train, \
                                                                    x_test=x_test, y_test=y_test, \
                                                                    epochs=epochs, bs=bs, patience=patience, \
                                                                    cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                    prune=prune, geneNames=gene_names, \
                                                                    verbose=0)
            r2_before_unfreezing[cvfold, j, i] = r2_before_unfreezing_test
            r2_before_unfreezing_tr[cvfold, j, i] = r2_before_unfreezing_train
            r2_after_unfreezing[cvfold, j, i] = r2_after_unfreezing_test
            r2_after_unfreezing_tr[cvfold, j, i] = r2_after_unfreezing_train
            r2_after_unfreezing_ap[cvfold, j, i] = r2_after_unfreezing_test_ap
            r2_after_unfreezing_ap_tr[cvfold, j, i] = r2_after_unfreezing_train_ap
            r2_freeze_unfreeze_hist[cvfold, j, i] = test_hist
            r2_freeze_unfreeze_hist_tr[cvfold, j, i] = train_hist
            #print('Test R^2 score (before unfreezing): ', r2_before_unfreezing[cvfold, j, i])
            #print('Test R^2 score (after unfreezing): ', r2_after_unfreezing[cvfold, j, i])
            #print('Test R^2 score (after unfreezing and after pruning): ', r2_after_unfreezing_ap[cvfold, j, i])
            
t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Gpm6a' 'Gm43670' 'Plch2' 'Cntnap5c' 'Tmem44' 'Sat1' 'Gabra1' 'Tubb4a'
#  'Acsbg1' 'Smim13' 'Ppp2r1a' 'Pcsk2' 'Elmo1' 'Abcc2' 'Gm11549' 'Oxr1'
#  'Zfp677' 'Zfp551' 'Chat' 'Pvalb' 'Ndst3' 'Htr3a' 'Sash3' 'Gpc3' 'Tlr13']
# [INFO] training network...
# Train R^2 before unfreezing:  0.458681583404541
# Test R^2 before unfreezing:  0.3678104877471924
# Train R^2 after unfreezing:  0.5115241408348083
# Test R^2 after unfreezing:  0.3902543783187866
# Train R^2 after unfreezing and pruning:  0.3560143709182739
# Test R^2 after unfreezing and pruning:  0.35635238885879517
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Kcnab1' 'Atp1a3' 'Htra1' 'Thsd7a' 'Calb1' 'Aldoc' 'Rab26' 'Megf10'
#  'Tac2' 'Prox1' 'Cntnap5c' 'Reln' 'Gm11549' 'Bcan' 'Stxbp6' 'Skp1a' 'Egfr'
#  'Cplx1' 'Cplx3' 'Tnnt1' 'Vip' 'Gm49948' 'Gad1' 'Erbb4' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4140591621398926
# Test R^2 before unfreezing:  0.33327215909957886
# Train R^2 after unfreezing:  0.510204404592514
# Test R^2 after unfreezing:  0.41042816638946533
# Train R^2 after unfreezing and pruning:  0.42590731382369995
# Test R^2 after unfreezing and pruning:  0.3966565728187561
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Grip1' 'Kcnab1' 'Pcdh7' 'Pcp4l1' 'Cplx3' 'Elmo1' 'Mybpc1' 'Cacna2d3'
#  'Rab3b' 'Sema5a' 'Coro6' 'Atp1a3' 'Plch2' 'Calb1' 'Cbln2' 'Egfr' 'Ptk2b'
#  'Fxyd6' 'Cplx1' 'Slc6a1' 'Reln' 'Tafa1' 'Erbb4' 'Pvalb' 'Gad1']
# [INFO] training network...
# Train R^2 before unfreezing:  0.3829691410064697
# Test R^2 before unfreezing:  0.3881816267967224
# Train R^2 after unfreezing:  0.4252051115036011
# Test R^2 after unfreezing:  0.43459373712539673
# Train R^2 after unfreezing and pruning:  0.4202192425727844
# Test R^2 after unfreezing and pruning:  0.42357057332992554
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Htr3a' 'Atp1a3' 'Kcnc2' 'Cxcl14' 'Zfp11' 'Ptk2b' 'Gpm6b' 'Jcad' 'Sema5a'
#  'Cacna2d3' 'Adcyap1' 'Ngef' 'Rab3b' 'Lingo2' 'Nell2' 'Gabra1' 'Mgst1'
#  'Cacna2d1' 'Tac2' 'Erbb4' 'Arpp21' 'Nell1' 'Gad1' 'Lamp5' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.32154595851898193
# Test R^2 before unfreezing:  0.36870384216308594
# Train R^2 after unfreezing:  0.3479815721511841
# Test R^2 after unfreezing:  0.3983380198478699
# Train R^2 after unfreezing and pruning:  0.37741905450820923
# Test R^2 after unfreezing and pruning:  0.400206983089447
#
# CVFOLD:  1
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Kbtbd8' 'Zfp536' 'Egfr' 'Zfp871' 'AW551984' 'Atp6v1h' 'Elmo1' 'Actr1b'
#  'Zfp941' 'Rspo2' 'Kcnc2' 'Hpse' 'Eprs' 'Ado' 'Galnt14' 'Cmtr2' 'Calb1'
#  'Poglut1' 'Rbm18' 'Dlgap1' 'Farsb' 'Zfp11' 'Pvalb' 'Gpc3' 'Cntnap5c']
# [INFO] training network...
# Train R^2 before unfreezing:  0.44382715225219727
# Test R^2 before unfreezing:  0.3137339949607849
# Train R^2 after unfreezing:  0.5277820229530334
# Test R^2 after unfreezing:  0.3297070860862732
# Train R^2 after unfreezing and pruning:  0.311004638671875
# Test R^2 after unfreezing and pruning:  0.26153993606567383
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['App' 'Kcnip2' 'Npnt' 'Acot7' 'Nxph1' 'Dner' 'Ptgs2' 'Prox1' 'Erbb4'
#  'Elmo1' 'Gad1' 'Igf1' 'Kcnc2' 'Sparcl1' 'Vip' 'Gm49948' 'Pdyn' 'Slc6a1'
#  'Npy' 'Gad2' 'Kit' 'Egfr' 'Cplx3' 'Tnnt1' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.44580286741256714
# Test R^2 before unfreezing:  0.3493052124977112
# Train R^2 after unfreezing:  0.5032463669776917
# Test R^2 after unfreezing:  0.42044132947921753
# Train R^2 after unfreezing and pruning:  0.42769908905029297
# Test R^2 after unfreezing and pruning:  0.3923417329788208
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Galnt14' 'Dusp14' 'Phactr1' '6330403K07Rik' 'Ndst3' 'Atp1a3' 'Elfn1'
#  'Col24a1' 'Kcnip2' 'Pcp4l1' 'Kcnc2' 'Grip1' 'Erbb4' 'Enpp2' 'Unc13c'
#  'Plch2' 'Tac2' 'Gad1' 'Sparcl1' 'Gm49948' 'Ndn' 'Lamp5' 'Pvalb' 'Sst'
#  'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.3883780837059021
# Test R^2 before unfreezing:  0.35710179805755615
# Train R^2 after unfreezing:  0.43833667039871216
# Test R^2 after unfreezing:  0.4262346029281616
# Train R^2 after unfreezing and pruning:  0.42621761560440063
# Test R^2 after unfreezing and pruning:  0.4097118377685547
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Nxph1' 'Parm1' 'Cacna2d3' 'Grip1' 'Mobp' 'Bdnf' 'Atp5b' 'Arhgef6'
#  'Slc6a1' 'Prnp' 'Elfn1' 'Sema5a' 'Akr1c18' 'Ptk2b' 'Cbln2' 'Nell2'
#  'Ptgs2' 'Lamp5' 'Plch2' 'Gabra1' 'Gas7' 'Erbb4' 'Atp1a3' 'Gad1' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.3234407901763916
# Test R^2 before unfreezing:  0.3238397240638733
# Train R^2 after unfreezing:  0.35240113735198975
# Test R^2 after unfreezing:  0.33827757835388184
# Train R^2 after unfreezing and pruning:  0.3791019916534424
# Test R^2 after unfreezing and pruning:  0.3352935314178467
#
# CVFOLD:  2
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Fezf2' 'Dlst' 'Blnk' 'Cp' 'Hapln4' 'Zfp473' 'Tmem184c' 'Zfp11' 'Crh'
#  'Col11a1' 'Slc7a3' 'Gabra4' 'Mdh2' 'Pde1a' 'Rab3c' 'Prox1' 'Plcxd3'
#  'Ndnf' 'Ldha' 'Sv2a' 'Gpc3' 'Nxph1' 'Wls' 'Th' 'Ighm']
# [INFO] training network...
# Train R^2 before unfreezing:  0.45919597148895264
# Test R^2 before unfreezing:  0.32857245206832886
# Train R^2 after unfreezing:  0.5234119296073914
# Test R^2 after unfreezing:  0.3313884139060974
# Train R^2 after unfreezing and pruning:  0.3451792001724243
# Test R^2 after unfreezing and pruning:  0.27029603719711304
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Fezf2' 'Dlx6os1' 'Ptgs2' 'Arpp19' 'Adarb2' 'Crh' 'Gm24105' 'Erbb4'
#  'Ptk2b' 'Syt1' 'Coro6' 'Gm11549' 'Thsd7a' 'Chl1' 'Ndn' 'Gad1' 'Rph3a'
#  'Cplx1' 'Tafa1' 'Adcyap1' 'Prox1' 'Vip' 'Sst' 'Ndst3' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.417330801486969
# Test R^2 before unfreezing:  0.31299299001693726
# Train R^2 after unfreezing:  0.5162238478660583
# Test R^2 after unfreezing:  0.3700396418571472
# Train R^2 after unfreezing and pruning:  0.4381123185157776
# Test R^2 after unfreezing and pruning:  0.39105069637298584
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Plch2' 'Atp1a3' 'Htr3a' 'Cacna1e' 'Ptk2b' 'Cplx1' 'Kcnip2' 'Kcnc2'
#  'Elmo1' 'Grm7' 'Unc13c' 'Galnt14' 'Enpp2' 'Elfn1' 'Pcp4l1' 'Erbb4'
#  'Gm49948' 'Gad1' 'Tac2' 'Lamp5' 'Sparcl1' 'Ndn' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.40060925483703613
# Test R^2 before unfreezing:  0.3479740023612976
# Train R^2 after unfreezing:  0.4326530694961548
# Test R^2 after unfreezing:  0.392764687538147
# Train R^2 after unfreezing and pruning:  0.43455779552459717
# Test R^2 after unfreezing and pruning:  0.39264971017837524
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Ngef' 'Rph3a' 'Chl1' 'Slc6a1' 'Cacna1e' 'Npas1' 'Sorcs3' 'Nell2' 'Gabrd'
#  'Atp1a3' 'Pcp4l1' 'Ptk2b' 'Synpr' 'Ndn' 'Htr3a' 'Galnt14' 'Unc13c'
#  'Lamp5' 'Sst' 'Plch2' 'Cacna2d1' 'Elfn1' 'Gad1' 'Tac2' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.37096065282821655
# Test R^2 before unfreezing:  0.35984766483306885
# Train R^2 after unfreezing:  0.36879438161849976
# Test R^2 after unfreezing:  0.34777408838272095
# Train R^2 after unfreezing and pruning:  0.4098612666130066
# Test R^2 after unfreezing and pruning:  0.3748222589492798
#
# CVFOLD:  3
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Zgpat' 'Icam1' 'Upk1b' 'Plch2' 'Cnbp' 'Synpr' 'Chmp2b' 'Hsdl1' 'Gm11549'
#  'Cntnap5c' 'Vip' 'Edil3' 'Exd2' 'Gad1' 'Tmem200a' 'Kcnf1' 'Pik3r5'
#  'Msantd4' 'Dmrt2' 'Mybpc1' 'Col6a2' 'Rcn2' 'Pvalb' 'Col24a1' 'Vwa5b1']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4528917670249939
# Test R^2 before unfreezing:  0.3800778388977051
# Train R^2 after unfreezing:  0.5606298744678497
# Test R^2 after unfreezing:  0.3946365714073181
# Train R^2 after unfreezing and pruning:  0.3861504793167114
# Test R^2 after unfreezing and pruning:  0.35481375455856323
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Rab3b' 'Adcyap1' 'Lamp5' 'Sst' 'Arpp19' 'Erbb4' 'Rph3a' 'Ube3a' 'Ndst3'
#  'Pamr1' 'Elmo1' 'Sparcl1' 'Cplx1' 'Galnt14' 'Crh' 'Elfn1' 'Egfr' 'Tnnt1'
#  'Gm49948' 'Ptgs2' 'Prox1' 'Gad1' 'Pvalb' 'Pdyn' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.430036723613739
# Test R^2 before unfreezing:  0.3269115090370178
# Train R^2 after unfreezing:  0.504873663187027
# Test R^2 after unfreezing:  0.40846163034439087
# Train R^2 after unfreezing and pruning:  0.4258922338485718
# Test R^2 after unfreezing and pruning:  0.4017948508262634
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Enpp2' 'Sema3c' 'Dusp14' 'Phactr1' 'Unc13c' 'Plch2' 'Pcp4l1' 'Elfn1'
#  'Afap1' 'Gabrd' 'Kcnip2' 'Cplx1' 'Tac2' 'Ndst3' 'Htr3a' 'Cacna1e'
#  'Galnt14' 'Sparcl1' 'Gm49948' 'Ndn' 'Lamp5' 'Gad1' 'Pvalb' 'Sst' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.39391225576400757
# Test R^2 before unfreezing:  0.38969844579696655
# Train R^2 after unfreezing:  0.445401668548584
# Test R^2 after unfreezing:  0.41863512992858887
# Train R^2 after unfreezing and pruning:  0.43042057752609253
# Test R^2 after unfreezing and pruning:  0.4123631715774536
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Plch2' 'Arpp21' 'Npas1' 'Akr1c18' 'Ptpru' 'Col24a1' 'Bdnf' 'Unc13c'
#  'Coro6' 'Kcnip2' 'Elmo1' 'Gabra1' 'Enpp2' 'Prkcd' 'Cacna2d1' 'Ptk2b'
#  'Grip1' 'Htr3a' 'Galnt14' 'Lamp5' 'Ndn' 'Elfn1' 'Gad1' 'Sst' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.34887027740478516
# Test R^2 before unfreezing:  0.32428497076034546
# Train R^2 after unfreezing:  0.353046715259552
# Test R^2 after unfreezing:  0.34785670042037964
# Train R^2 after unfreezing and pruning:  0.40575385093688965
# Test R^2 after unfreezing and pruning:  0.4025123715400696
#
# CVFOLD:  4
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Enpp2' 'Prox1' 'Tlr7' 'Dlx6os1' 'Cnbp' 'Pcdh18' 'Ssr3' 'Immt' 'Arc'
#  'Col19a1' 'Scg2' 'Olfm3' 'Chl1' 'Gabra1' 'Pcp4l1' 'Crh' 'Arpp19' 'Ndst3'
#  'Sema3e' 'Col24a1' 'Npas1' 'Elmo1' 'Pvalb' 'Tiam2' 'Acot7']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4528433084487915
# Test R^2 before unfreezing:  0.34261345863342285
# Train R^2 after unfreezing:  0.5188198089599609
# Test R^2 after unfreezing:  0.3436025381088257
# Train R^2 after unfreezing and pruning:  0.39074021577835083
# Test R^2 after unfreezing and pruning:  0.3199191689491272
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Tnnt1' 'Atp1a3' 'Gm37899' 'Wls' 'Tafa1' 'Gm49948' 'Ndst3' 'Scg2' 'Prox1'
#  'Sst' 'Unc13c' 'Adarb2' 'Tcf4' 'Ndn' 'Lamp5' 'Htr3a' 'Ptgs2' 'Dlx6os1'
#  'Pvalb' 'Crh' 'Galnt14' 'Slc6a1' 'Npy' 'Gad1' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.40380847454071045
# Test R^2 before unfreezing:  0.3037046194076538
# Train R^2 after unfreezing:  0.524608314037323
# Test R^2 after unfreezing:  0.39578497409820557
# Train R^2 after unfreezing and pruning:  0.42470628023147583
# Test R^2 after unfreezing and pruning:  0.36185377836227417
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Th' 'Enpp2' 'Kcnip2' 'Ndst3' 'Nell2' 'Ptk2b' 'Elfn1' 'Rph3a' 'Phactr1'
#  'Ndfip1' 'Dusp14' 'Cacna1e' 'Pcp4l1' 'Galnt14' 'Tac2' 'Htr3a' 'Sparcl1'
#  'Unc13c' 'Gm49948' 'Ndn' 'Lamp5' 'Gad1' 'Pvalb' 'Sst' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.3994331359863281
# Test R^2 before unfreezing:  0.3425002098083496
# Train R^2 after unfreezing:  0.4199736714363098
# Test R^2 after unfreezing:  0.3835940361022949
# Train R^2 after unfreezing and pruning:  0.43323636054992676
# Test R^2 after unfreezing and pruning:  0.3886430859565735
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Pcsk2' 'Ndn' 'Nxph1' 'Mas1' 'Bdnf' 'Afap1' 'Nrip3' 'Gm49948' 'Nfib'
#  'Syt6' 'Gabrd' 'Grm7' 'Rgs12' 'Lamp5' 'Phactr1' 'Gad1' 'Plch2' 'Ptk2b'
#  'Synpr' 'Npas1' 'Tac2' 'Htr3a' 'Elfn1' 'Sst' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.36391448974609375
# Test R^2 before unfreezing:  0.34323930740356445
# Train R^2 after unfreezing:  0.35877060890197754
# Test R^2 after unfreezing:  0.3384183645248413
# Train R^2 after unfreezing and pruning:  0.40980637073516846
# Test R^2 after unfreezing and pruning:  0.3643862009048462
#
# CVFOLD:  5
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Gm29216' 'Alg2' 'Moxd1' 'Serpini1' 'Prox1' 'Abcc2' 'Pde1a' 'Zfp472'
#  'Gdi2' 'Mpped1' 'Plat' 'Rspo2' 'Pvalb' 'Ndn' 'Sstr2' 'Trbc2' 'Ndst3'
#  'Syt1' 'Nfib' 'Sst' 'Chl1' 'Tac2' 'Egfr' 'Gm11549' 'Elmo1']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4732569456100464
# Test R^2 before unfreezing:  0.33554357290267944
# Train R^2 after unfreezing:  0.5437453091144562
# Test R^2 after unfreezing:  0.35373061895370483
# Train R^2 after unfreezing and pruning:  0.40885430574417114
# Test R^2 after unfreezing and pruning:  0.34109896421432495
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Gabra1' 'Gabrq' 'Npas1' 'Thsd7a' 'Gad2' 'Rprm' 'Grm7' 'Arpp19' 'Chat'
#  'Mas1' 'Ptger3' 'Gad1' 'Galnt14' 'Sst' 'Ndst3' 'Vwa5b1' 'Coro6' 'Gpc3'
#  'Lamp5' 'Ndnf' 'Slc6a1' 'Tac2' 'Cplx3' 'Htr3a' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.41120320558547974
# Test R^2 before unfreezing:  0.27511996030807495
# Train R^2 after unfreezing:  0.5134409666061401
# Test R^2 after unfreezing:  0.3843139410018921
# Train R^2 after unfreezing and pruning:  0.4224831461906433
# Test R^2 after unfreezing and pruning:  0.38419610261917114
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Dusp14' 'Mas1' 'Cplx1' 'Cacna1e' 'Enpp2' 'Afap1' 'Elfn1' 'Kcnc2'
#  'Pcp4l1' 'Unc13c' 'Ndst3' 'Galnt14' 'Slc6a1' 'Erbb4' 'Plch2' 'Htr3a'
#  'Sparcl1' 'Gm49948' 'Tac2' 'Gad1' 'Ndn' 'Lamp5' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.3887345790863037
# Test R^2 before unfreezing:  0.35563868284225464
# Train R^2 after unfreezing:  0.44205033779144287
# Test R^2 after unfreezing:  0.3901887536048889
# Train R^2 after unfreezing and pruning:  0.43666619062423706
# Test R^2 after unfreezing and pruning:  0.376517653465271
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Ust' 'Plch2' 'Hpca' 'Ndn' 'Col24a1' 'Pcp4l1' 'Tiam2' 'Nrip3' 'Lamp5'
#  'Gabrd' 'Prokr2' 'Grip1' 'Elfn1' 'Elmo1' 'Mas1' 'Synpr' 'Kcnip2' 'Htr3a'
#  'Ndst3' 'Sst' 'Npas1' 'Gad1' 'Galnt14' 'Tac2' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.36548811197280884
# Test R^2 before unfreezing:  0.34020400047302246
# Train R^2 after unfreezing:  0.36348217725753784
# Test R^2 after unfreezing:  0.3398566246032715
# Train R^2 after unfreezing and pruning:  0.40959441661834717
# Test R^2 after unfreezing and pruning:  0.36544448137283325
#
# CVFOLD:  6
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Tlr7' 'Usp14' 'Ache' 'Ghitm' 'Fxyd6' 'Hpse' 'Plat' 'Prox1' 'Ppp1r15a'
#  'Kctd21' 'Cav1' 'Cntnap5c' 'Serinc1' 'Galnt14' 'Rprm' 'Gng7' 'Tac2'
#  'Gm47283' 'Vip' 'Ssr3' 'Immt' 'Elmo1' 'Pvalb' 'Ndst3' 'Egfr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.44737279415130615
# Test R^2 before unfreezing:  0.3278433084487915
# Train R^2 after unfreezing:  0.5161290764808655
# Test R^2 after unfreezing:  0.32900500297546387
# Train R^2 after unfreezing and pruning:  0.3520745038986206
# Test R^2 after unfreezing and pruning:  0.32435154914855957
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Nrip3' 'Ndst3' 'Ddr2' 'Plcxd3' 'Synpr' 'Elmo1' 'Kit' 'Ndnf' 'Kcnc2'
#  'Crh' 'Tnnt1' 'Igf1' 'Erbb4' 'Meg3' 'Sdr42e1' 'Egr2' 'Prox1' 'Ndn' 'Gad1'
#  'Gprc5c' 'Pvalb' 'Slc6a1' 'Gm49948' 'Vip' 'Cplx3']
# [INFO] training network...
# Train R^2 before unfreezing:  0.41169649362564087
# Test R^2 before unfreezing:  0.30728018283843994
# Train R^2 after unfreezing:  0.5180103480815887
# Test R^2 after unfreezing:  0.35381919145584106
# Train R^2 after unfreezing and pruning:  0.406732976436615
# Test R^2 after unfreezing and pruning:  0.380810022354126
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Tac1' 'Gm11549' 'Slc5a7' 'Plch2' 'Slc6a1' 'Galnt14' 'Ndst3' 'Elmo1'
#  'Kcnip2' 'Afap1' 'Unc13c' 'Enpp2' 'Erbb4' 'Elfn1' 'Htr3a' 'Sparcl1'
#  'Gabrd' 'Tac2' 'Gm49948' 'Gad1' 'Ndn' 'Lamp5' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.37719565629959106
# Test R^2 before unfreezing:  0.3678203225135803
# Train R^2 after unfreezing:  0.4280813932418823
# Test R^2 after unfreezing:  0.4120251536369324
# Train R^2 after unfreezing and pruning:  0.43273502588272095
# Test R^2 after unfreezing and pruning:  0.4142534136772156
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Slc6a1' 'Galnt14' 'Adamts15' 'Mlip' 'Cacna2d1' 'Cdc42se2' 'Ptgs2'
#  'Col24a1' 'Nek7' 'Lingo2' 'Cbln2' 'Ptk2b' 'Magel2' 'Elfn1' 'Nrip3' 'Gad1'
#  'Sst' 'Lamp5' 'Htr3a' 'Atp1a3' 'Ndn' 'Tac1' 'Tac2' 'Synpr' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.3575192093849182
# Test R^2 before unfreezing:  0.3590291142463684
# Train R^2 after unfreezing:  0.36348778009414673
# Test R^2 after unfreezing:  0.3579898476600647
# Train R^2 after unfreezing and pruning:  0.40035027265548706
# Test R^2 after unfreezing and pruning:  0.38300466537475586
#
# CVFOLD:  7
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Fibcd1' 'Rasgrf1' 'Cnr1' 'Pde1a' 'Kcng4' 'Acot7' 'Cplx3' 'Elmo1' 'Cmtm6'
#  'Kcnh7' 'Eif4a2' 'Gpm6a' 'Fbh1' 'Upk1b' 'Tlr13' 'Gm48745' 'Cstf2t' 'Tlr7'
#  'Cmtr2' 'Sparcl1' 'Actr1b' 'Vip' 'Prox1' 'Th' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.41197657585144043
# Test R^2 before unfreezing:  0.3688231110572815
# Train R^2 after unfreezing:  0.5413129031658173
# Test R^2 after unfreezing:  0.39776748418807983
# Train R^2 after unfreezing and pruning:  0.3387143015861511
# Test R^2 after unfreezing and pruning:  0.3008590340614319
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Snca' 'Tmem200a' 'Btbd11' 'Sdc2' 'Igf1' 'Klhl23' 'Reln' 'Penk' 'Adcyap1'
#  'Syne1' 'Crh' 'Fbxo9' 'Tafa1' 'Blnk' 'Ptgs2' 'Mlip' 'Magel2' 'Mas1' 'Th'
#  'Elmo1' 'Lamp5' 'Gm11549' 'Zfp677' 'Vip' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.3830013871192932
# Test R^2 before unfreezing:  0.2729518413543701
# Train R^2 after unfreezing:  0.5224035382270813
# Test R^2 after unfreezing:  0.3242541551589966
# Train R^2 after unfreezing and pruning:  0.36395394802093506
# Test R^2 after unfreezing and pruning:  0.3148460388183594
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Satb1' 'Ndnf' 'Erbb4' 'Afap1' 'Slc6a1' 'Elmo1' 'Phactr1' 'Atp1a3'
#  'Cacna1e' 'Grm7' 'Htr3a' 'Ndst3' 'Pcp4l1' 'Igf1' 'Plch2' 'Galnt14'
#  'Sparcl1' 'Tac2' 'Ndn' 'Gm49948' 'Lamp5' 'Sst' 'Gad1' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.38812386989593506
# Test R^2 before unfreezing:  0.4075952172279358
# Train R^2 after unfreezing:  0.43707430362701416
# Test R^2 after unfreezing:  0.4454355239868164
# Train R^2 after unfreezing and pruning:  0.4304783344268799
# Test R^2 after unfreezing and pruning:  0.43672698736190796
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Cck' 'Plch2' 'Zfp677' 'Elmo1' 'Spock3' 'Tlr13' 'Sst' 'Ndst3' 'Rxfp3'
#  'Tac2' 'Tmem100' 'Mgst1' 'Htr3a' 'Cplx1' 'Lamp5' 'Galnt14' 'Gm49948'
#  'Atp1a3' 'Cacna2d1' 'Ndn' 'Vip' 'Gabrd' 'Synpr' 'Gad1' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.3655589818954468
# Test R^2 before unfreezing:  0.38888442516326904
# Train R^2 after unfreezing:  0.3662470579147339
# Test R^2 after unfreezing:  0.39084702730178833
# Train R^2 after unfreezing and pruning:  0.4011055827140808
# Test R^2 after unfreezing and pruning:  0.4207947254180908
#
# CVFOLD:  8
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Kctd21' 'Kcnc2' 'Pik3r5' 'Itih3' 'Chrdl1' 'Pcp4l1' 'Ndn' 'Zfp871'
#  'Hnrnpk' 'Kcnip2' 'Gm49948' 'Gm48745' 'Npnt' 'Lrrn3' 'Gm37899' 'Calu'
#  'Sst' 'Mobp' 'Eif4a2' 'Blnk' 'Elmo1' 'Anxa3' 'Sema5a' 'Ndst3' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4113196134567261
# Test R^2 before unfreezing:  0.3148043155670166
# Train R^2 after unfreezing:  0.5137811303138733
# Test R^2 after unfreezing:  0.2978582978248596
# Train R^2 after unfreezing and pruning:  0.3702157139778137
# Test R^2 after unfreezing and pruning:  0.33622831106185913
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Rit2' 'Neurod6' 'Lingo2' 'Sstr2' 'Gm11549' 'Tafa1' 'Bdnf' 'Gabra1'
#  'Ptger3' 'Ptprk' 'Galnt14' 'Npas1' 'Atp1a3' 'Trbc2' 'Grip1' 'Calb1'
#  'Reln' 'Dlx6os1' 'Gm49948' 'Slc6a1' 'Htr3a' 'Ndn' 'Gad1' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4373083710670471
# Test R^2 before unfreezing:  0.29217368364334106
# Train R^2 after unfreezing:  0.5214024186134338
# Test R^2 after unfreezing:  0.3544238209724426
# Train R^2 after unfreezing and pruning:  0.4124579429626465
# Test R^2 after unfreezing and pruning:  0.34705787897109985
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Npas1' 'Erbb4' 'Enpp2' 'Kcnc2' 'Kcnip2' 'Col24a1' 'Cplx1' 'Cacna1e'
#  'Afap1' 'Ndst3' 'Pcp4l1' 'Gabrd' 'Plch2' 'Htr3a' 'Elfn1' 'Tac2' 'Galnt14'
#  'Sparcl1' 'Lamp5' 'Gm49948' 'Sst' 'Ndn' 'Gad1' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.3712902069091797
# Test R^2 before unfreezing:  0.29966622591018677
# Train R^2 after unfreezing:  0.43256527185440063
# Test R^2 after unfreezing:  0.39473551511764526
# Train R^2 after unfreezing and pruning:  0.43642252683639526
# Test R^2 after unfreezing and pruning:  0.38293856382369995
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Erbb4' 'Synpr' 'Sst' 'Afap1' 'Pcp4l1' 'Pcsk2' 'Slc6a1' 'Elfn1' 'Reln'
#  'Plch2' 'Galnt14' 'Htr3a' 'Grip1' 'Gabrd' 'Kcnip2' 'Tac2' 'Npas1'
#  'Cacna2d3' 'Cacna1e' 'Atp1a3' 'Cacna2d1' 'Ndn' 'Lamp5' 'Gad1' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.30752086639404297
# Test R^2 before unfreezing:  0.27288925647735596
# Train R^2 after unfreezing:  0.346416711807251
# Test R^2 after unfreezing:  0.3335702419281006
# Train R^2 after unfreezing and pruning:  0.4057866334915161
# Test R^2 after unfreezing and pruning:  0.3735969066619873
#
# CVFOLD:  9
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Igfbp4' 'Nrip3' 'Zfp536' 'Tmem200a' 'Sdc2' 'Rbp4' 'Crh' 'Igf1' 'Trpm2'
#  'Gng4' 'Edn1' 'Cd81' 'Topors' 'Pamr1' 'Zfp677' 'Htatsf1' 'Enpp5'
#  'Rasgef1b' 'Vwc2l' 'Vip' 'Tac2' 'Scg2' 'Mat2b' 'Tnfaip3' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.42786580324172974
# Test R^2 before unfreezing:  0.28132855892181396
# Train R^2 after unfreezing:  0.5322311520576477
# Test R^2 after unfreezing:  0.2842419147491455
# Train R^2 after unfreezing and pruning:  0.35938411951065063
# Test R^2 after unfreezing and pruning:  0.33381783962249756
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Grip1' 'Cnr1' 'Arpp21' 'Lgi1' 'Nell2' 'Pik3r5' 'Cbln2' 'Pdyn' 'Trbc2'
#  'Htr3a' 'Egfr' 'Calb1' 'Tafa1' 'Coro6' 'App' 'Fxyd6' 'Gad2' 'Cplx3'
#  'Reln' 'Adcyap1' 'Erbb4' 'Plch2' 'Pvalb' 'Gad1' 'Slc6a1']
# [INFO] training network...
# Train R^2 before unfreezing:  0.39185774326324463
# Test R^2 before unfreezing:  0.3374559283256531
# Train R^2 after unfreezing:  0.5151219964027405
# Test R^2 after unfreezing:  0.42542731761932373
# Train R^2 after unfreezing and pruning:  0.43265652656555176
# Test R^2 after unfreezing and pruning:  0.4022688865661621
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Dlx6os1' 'Erbb4' 'Col24a1' 'Afap1' 'Elmo1' 'Gpm6b' 'Calb2' 'Mas1'
#  'Plch2' 'Unc13c' 'Ndst3' 'Enpp2' 'Gabrd' 'Elfn1' 'Htr3a' 'Sparcl1'
#  'Galnt14' 'Tac2' 'Gm49948' 'Lamp5' 'Gad1' 'Ndn' 'Pvalb' 'Sst' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4018121361732483
# Test R^2 before unfreezing:  0.3743050694465637
# Train R^2 after unfreezing:  0.4335033893585205
# Test R^2 after unfreezing:  0.411365270614624
# Train R^2 after unfreezing and pruning:  0.4211542010307312
# Test R^2 after unfreezing and pruning:  0.3948982357978821
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Erbb4' 'Thbs2' 'Vip' 'Gabrd' 'Gas7' 'Gm11549' 'Tac2' 'Kcnab1' 'Arpp21'
#  'Slc17a7' 'Kcnab3' 'Galnt14' 'Cacna2d1' 'Kcnc2' 'Ptk2b' 'Cbln2' 'Nell2'
#  'Gm49948' 'Elfn1' 'Mybpc1' 'Synpr' 'Lamp5' 'Htr3a' 'Gad1' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.31956690549850464
# Test R^2 before unfreezing:  0.3237319588661194
# Train R^2 after unfreezing:  0.3430868983268738
# Test R^2 after unfreezing:  0.35829585790634155
# Train R^2 after unfreezing and pruning:  0.4024117588996887
# Test R^2 after unfreezing and pruning:  0.38622409105300903
# Time: 0.0h 28m 10s

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_pre_tr_and_freeze_unfreeze_lasso.pickle', 'wb') as f:
    pickle.dump([r2_before_unfreezing, r2_before_unfreezing_tr, \
                 r2_after_unfreezing, r2_after_unfreezing_tr, \
                 r2_after_unfreezing_ap, r2_after_unfreezing_ap_tr, \
                 r2_freeze_unfreeze_hist, r2_freeze_unfreeze_hist_tr], f)

# %% [markdown]
# In the next section we perform reduced-rank regression cross validation (rank = 2 and full rank).

# %%
# CV sRRR rank = 2

lambdas = np.arange(.1,2,.1)
alphas = np.array([1])

rank = 2
folds = 10
seed = 42

r2_sRRR_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_rank2_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank2_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
nonzero_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
corrs_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))
corrs_relaxed_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))


t = time.time()

np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    x_train = x_train.astype('float64')
    y_train = y_train.astype('float64')
    x_test = x_test.astype('float64')
    y_test = y_test.astype('float64')
    
    for i,a in enumerate(lambdas):
        #print('Lambdau: ', a)
        for j, b in enumerate(alphas):
            #print('Alpha: ', b)
            vx,vy = sparseRRR.elastic_rrr(x_train, y_train, lambdau=a, alpha=b, rank=rank, sparsity='row-wise')

            nz = np.sum(np.abs(vx), axis=1) != 0
            if np.sum(nz) < rank:
                nonzero_rank2[cvfold, j, i] = np.nan
                continue

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank2[cvfold, j, i] = np.nan
                continue

            nonzero_rank2[cvfold, j, i] = np.sum(nz)
            r2_sRRR_rank2[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum(y_test**2)
            r2_sRRR_rank2_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum(y_train**2)
            for r in range(rank):
                corrs_rank2[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]

            # Relaxation
            vx[nz,:],vy = sparseRRR.elastic_rrr(x_train[:,nz], y_train, lambdau=a, alpha=0, rank=rank, sparsity='row-wise')

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank2[cvfold, j, i] = np.nan
                continue

            r2_sRRR_relaxed_rank2[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum(y_test**2)
            r2_sRRR_relaxed_rank2_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum(y_train**2)
            for r in range(rank):
                corrs_relaxed_rank2[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]
            #print(r2_sRRR_relaxed_rank2[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
#
# CVFOLD:  1
#
# CVFOLD:  2
#
# CVFOLD:  3
#
# CVFOLD:  4
#
# CVFOLD:  5
#
# CVFOLD:  6
#
# CVFOLD:  7
#
# CVFOLD:  8
#
# CVFOLD:  9
# Time: 0.0h  0m 52s

# %%
with open('KerasSavedModels/scala_2020/sRRR_vs_Bottleneck_rank2_CV_lasso.pickle', 'wb') as f:
    pickle.dump([r2_sRRR_rank2, r2_sRRR_relaxed_rank2, r2_sRRR_rank2_tr, r2_sRRR_relaxed_rank2_tr, \
                nonzero_rank2, corrs_rank2, corrs_relaxed_rank2], f)

# %%
# CV sRRR full rank

lambdas = np.arange(.1,2,.1)
alphas = np.array([1])

rank = ephys.shape[1]
folds = 10
seed = 42

r2_sRRR_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_rank16_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank16_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
nonzero_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
corrs_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))
corrs_relaxed_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))


t = time.time()

np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    x_train = x_train.astype('float64')
    y_train = y_train.astype('float64')
    x_test = x_test.astype('float64')
    y_test = y_test.astype('float64')
    
    for i,a in enumerate(lambdas):
        #print('Labmdau: ', a)
        for j, b in enumerate(alphas):
            #print('Alpha: ', b)
            vx,vy = sparseRRR.elastic_rrr(x_train, y_train, lambdau=a, alpha=b, rank=rank, sparsity='row-wise')

            nz = np.sum(np.abs(vx), axis=1) != 0
            if np.sum(nz) < rank:
                nonzero_rank16[cvfold, j, i] = np.nan
                continue

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank16[cvfold, j, i] = np.nan
                continue

            nonzero_rank16[cvfold, j, i] = np.sum(nz)
            r2_sRRR_rank16[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum(y_test**2)
            r2_sRRR_rank16_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum(y_train**2)
            for r in range(rank):
                corrs_rank16[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]

            # Relaxation
            vx[nz,:],vy = sparseRRR.elastic_rrr(x_train[:,nz], y_train, lambdau=a, alpha=0, rank=rank, sparsity='row-wise')

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank16[cvfold, j, i] = np.nan
                continue

            r2_sRRR_relaxed_rank16[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum(y_test**2)
            r2_sRRR_relaxed_rank16_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum(y_train**2)
            for r in range(rank):
                corrs_relaxed_rank16[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]
            #print(r2_sRRR_relaxed_rank16[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
#
# CVFOLD:  1
#
# CVFOLD:  2
#
# CVFOLD:  3
#
# CVFOLD:  4
#
# CVFOLD:  5
#
# CVFOLD:  6
#
# CVFOLD:  7
#
# CVFOLD:  8
#
# CVFOLD:  9
# Time: 0.0h  1m 51s

# %%
with open('KerasSavedModels/scala_2020/sRRR_vs_Bottleneck_rank16_CV_lasso.pickle', 'wb') as f:
    pickle.dump([r2_sRRR_rank16, r2_sRRR_relaxed_rank16, r2_sRRR_rank16_tr, r2_sRRR_relaxed_rank16_tr, \
                nonzero_rank16, corrs_rank16, corrs_relaxed_rank16], f)

# %% [markdown]
# Let us now analyse and visualise the differences.

# %%
lambdas = np.arange(.1,2,.1)
alphas = np.array([1])

# %%
with open('KerasSavedModels/scala_2020/sRRR_vs_Bottleneck_rank2_CV_lasso.pickle', 'rb') as f:
    r2_sRRR_rank2, r2_sRRR_relaxed_rank2, r2_sRRR_rank2_tr, r2_sRRR_relaxed_rank2_tr, \
                nonzero_rank2, corrs_rank2, corrs_relaxed_rank2 = pickle.load(f)

# %%
with open('KerasSavedModels/scala_2020/sRRR_vs_Bottleneck_rank16_CV_lasso.pickle', 'rb') as f:
    r2_sRRR_rank16, r2_sRRR_relaxed_rank16, r2_sRRR_rank16_tr, r2_sRRR_relaxed_rank16_tr, \
                nonzero_rank16, corrs_rank16, corrs_relaxed_rank16 = pickle.load(f)

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_pre_tr_lasso.pickle', 'rb') as f:
    CE_loss, CE_loss_tr, pre_tr_hist, pre_tr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_straight_regr_lasso.pickle', 'rb') as f:
    r2_straight_regr, r2_straight_regr_tr, \
    r2_straight_regr_ap, r2_straight_regr_ap_tr, \
    r2_straight_regr_hist, r2_straight_regr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_pre_tr_and_straight_regr_lasso.pickle', 'rb') as f:
    r2_pretr_straight_regr, r2_pretr_straight_regr_tr, \
    r2_pretr_straight_regr_ap, r2_pretr_straight_regr_ap_tr, \
    r2_pretr_straight_regr_hist, r2_pretr_straight_regr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_pre_tr_and_freeze_unfreeze_lasso.pickle', 'rb') as f:
    r2_before_unfreezing, r2_before_unfreezing_tr, \
    r2_after_unfreezing, r2_after_unfreezing_tr, \
    r2_after_unfreezing_ap, r2_after_unfreezing_ap_tr, \
    r2_freeze_unfreeze_hist, r2_freeze_unfreeze_hist_tr = pickle.load(f)

# %%
# Select closest to 25 genes value
# suppressing "mean of empty slice" warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    n_rank2 = np.nanmean(nonzero_rank2, axis=0)[0, :]
    r_rank2_r = np.nanmean(r2_sRRR_relaxed_rank2, axis=0)[0, :]
    n_rank16 = np.nanmean(nonzero_rank16, axis=0)[0, :]
    r_rank16_r = np.nanmean(r2_sRRR_relaxed_rank16, axis=0)[0, :]

# %%
r_rank16_r[np.isclose(n_rank16, 25, atol=3)][0]
# Out:
# 0.39811512463141036

# %%
r_rank2_r[np.isclose(n_rank2, 25, atol=3)][0]
# Out:
# 0.35036089702192025

# %%
np.mean(r2_freeze_unfreeze_hist,axis=0)[2,0,-1]
# Out:
# 0.3954786151647568

# %%
np.mean(r2_straight_regr_hist,axis=0)[0,0,-1]
# Out:
# 0.37535181641578674

# %%
# # All together in one plot
# linewidth = 2
# sns_styleset()

# # suppressing "mean of empty slice" warnings
# with warnings.catch_warnings():
#     warnings.simplefilter("ignore", category=RuntimeWarning)
#     n_2 = np.nanmean(nonzero_rank2, axis=0)[0, :]
#     cr_2 = np.nanmean(r2_sRRR_relaxed_rank2, axis=0)[0, :]
#     n_16 = np.nanmean(nonzero_rank16, axis=0)[0, :]
#     cr_16= np.nanmean(r2_sRRR_relaxed_rank16, axis=0)[0, :]
    
    

# # suppressing "mean of empty slice" warnings
# with warnings.catch_warnings():
#     warnings.simplefilter("ignore", category=RuntimeWarning)
#     n_rank2 = np.nanmean(nonzero_rank2, axis=0)[0, :]
#     r_rank2_r = np.nanmean(r2_sRRR_relaxed_rank2, axis=0)[0, :]
#     n_rank16 = np.nanmean(nonzero_rank16, axis=0)[0, :]
#     r_rank16_r = np.nanmean(r2_sRRR_relaxed_rank16, axis=0)[0, :]

# # All together in one plot for the paper
# fig = plt.figure(figsize=(19, 4.5))
# widths = [1, 1, 2]
# heights = [1]
# spec = fig.add_gridspec(ncols=3, nrows=1, width_ratios=widths,
#                           height_ratios=heights)
# ax1 = fig.add_subplot(spec[0, 0])
# ax1.plot(n_2, cr_2, '.-', c = np.array([0, 0, 0])/256, linewidth=2)
# ax1.plot(n_16[1:], cr_16[1:], '.-', c = np.array([0, 0, 0]) / 256, linewidth=2)
# ax1.set_ylim([0.3,0.45])
# ax1.set_xlabel('Number of selected genes', fontsize = 17)
# ax1.set_ylabel(r'Cross validated $R^2$', fontsize = 17)
# ax1.set_title('Sparse reduced-rank regression', fontsize = 20, y=1.02)
# ax1.tick_params(axis='both', which='major', labelsize=15)
# ax1.tick_params(axis='both', which='minor', labelsize=15)
# ax1.vlines(x=25, ymin=ax1.get_ylim()[0], ymax=ax1.get_ylim()[1], linestyles='dashed')
# ax1.annotate('sRRR, r=16', (70, np.max(cr_16)+0.0003), fontsize=15)
# ax1.annotate('sRRR, r=2', (70, np.max(cr_2)+0.0003), fontsize=15)


# ax2 = fig.add_subplot(spec[0, 1])
# ax2.plot(range(50), np.mean(pre_tr_hist_tr, axis=(0, 2))[2, :], \
#          '--', c = 'k', linewidth=linewidth)
# ax2.plot(range(50), np.mean(pre_tr_hist, axis=(0, 2))[2, :], \
#          c = 'k', linewidth=linewidth)
# ax2.set_title('Pretraining', fontsize = 19, y=1.02)
# ax2.set_xlabel('Epoch', fontsize = 17)
# ax2.set_ylabel('Cross entropy loss', fontsize = 17)
# ax2.tick_params(axis='both', which='major', labelsize=15)
# ax2.tick_params(axis='both', which='minor', labelsize=15)
# ax2.set_ylim([0, ax2.get_ylim()[1]])
# ax2.annotate('Training', (35, 1.65), fontsize=15)
# ax2.annotate('Test', (35, 2.36), fontsize=15)
# ax2.set_xticks(np.arange(0, 60, 10))

# epochs_used=200
# ax3 = fig.add_subplot(spec[0, 2])
# ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist_tr, axis=(0))[2,0,:], \
#          '--', c = '#1b9e77', linewidth=linewidth)
# ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist, axis=(0))[2,0,:], \
#          c = '#1b9e77', linewidth=linewidth, label='Pre-training + freezing + unfreezing')
# ax3.plot(range(epochs_used), np.mean(r2_pretr_straight_regr_hist_tr, axis=(0))[0,0,:], \
#          '--', c = '#d95f02', linewidth=linewidth)
# ax3.plot(range(epochs_used), np.mean(r2_pretr_straight_regr_hist, axis=(0))[0,0,:], \
#          c = '#d95f02', linewidth=linewidth, label='Pre-training + no freezing')
# ax3.plot(range(epochs_used), np.mean(r2_straight_regr_hist_tr, axis=(0))[0,0,:], \
#          '--', c = '#7570b3', linewidth=linewidth)
# ax3.plot(range(epochs_used), np.mean(r2_straight_regr_hist, axis=(0))[0,0,:], \
#          c = '#7570b3', linewidth=linewidth, label='No pre-training')
# ax3.hlines(r_rank16_r[np.isclose(n_rank16, 25, atol=3)], xmin = 0, xmax = epochs_used, \
#             colors = np.array([0, 0, 0])/256, linewidth=linewidth)
# ax3.hlines(r_rank2_r[np.isclose(n_rank2, 25, atol=3)], xmin = 0, xmax = epochs_used, \
#             colors = np.array([0, 0, 0])/256, linewidth=linewidth)
# ax3.set_ylim([0.3,0.45])
# ax3.set_xlim([0,200])
# ax3.set_xticks(np.arange(0, 225, 25))
# ax3.annotate('RRR, r=16', (178, r_rank16_r[np.isclose(n_rank16, 25, atol=3)]+0.01), fontsize=15)
# ax3.annotate('RRR, r=2', (178, r_rank2_r[np.isclose(n_rank2, 25, atol=3)]+0.003), fontsize=15)
# ax3.set_title('Bottleneck neural network', fontsize = 19, y=1.02)
# ax3.set_xlabel('Epoch', fontsize = 17)
# ax3.set_ylabel(r'$R^2$', fontsize = 17)
# ax3.tick_params(axis='both', which='major', labelsize=15)
# ax3.tick_params(axis='both', which='minor', labelsize=15)
# ax3.legend(loc='lower right', fontsize=15)
# ax3.vlines(x=50, ymin=ax3.get_ylim()[0], ymax=ax3.get_ylim()[1], linestyles='dashed')
# ax3.vlines(x=100, ymin=ax3.get_ylim()[0], ymax=ax3.get_ylim()[1], linestyles='dashed')

# plt.text(-0.25, 1.04, 'a', transform = ax1.transAxes, fontsize=25, fontweight='bold')
# plt.text(-0.11, 1.04, 'b', transform = ax2.transAxes, fontsize=25, fontweight='bold')
# plt.text(-0.13, 1.04, 'c', transform = ax3.transAxes, fontsize=25, fontweight='bold')
# sns.despine()

# plt.savefig('figures/Lasso_training_curves.pdf', bbox_inches='tight',
#     pad_inches=0)
# plt.savefig('figures/Lasso_training_curves.png', bbox_inches='tight',
#     pad_inches=0)

# %%
# All together in one plot
linewidth = 2
sns_styleset()

# suppressing "mean of empty slice" warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    n_2 = np.nanmean(nonzero_rank2, axis=0)[0, :]
    cr_2 = np.nanmean(r2_sRRR_relaxed_rank2, axis=0)[0, :]
    n_16 = np.nanmean(nonzero_rank16, axis=0)[0, :]
    cr_16= np.nanmean(r2_sRRR_relaxed_rank16, axis=0)[0, :]
    
    

# suppressing "mean of empty slice" warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    n_rank2 = np.nanmean(nonzero_rank2, axis=0)[0, :]
    r_rank2_r = np.nanmean(r2_sRRR_relaxed_rank2, axis=0)[0, :]
    n_rank16 = np.nanmean(nonzero_rank16, axis=0)[0, :]
    r_rank16_r = np.nanmean(r2_sRRR_relaxed_rank16, axis=0)[0, :]

# All together in one plot for the paper
fig = plt.figure(figsize=(19, 4.5))
widths = [1, 1, 2]
heights = [1]
spec = fig.add_gridspec(ncols=3, nrows=1, width_ratios=widths,
                          height_ratios=heights)
ax1 = fig.add_subplot(spec[0, 0])
ax1.plot(n_2, cr_2, '.-', c = np.array([0, 0, 0])/256, linewidth=2)
ax1.plot(n_16[1:], cr_16[1:], '.-', c = np.array([0, 0, 0]) / 256, linewidth=2)
ax1.set_ylim([0.3,0.45])
ax1.set_xlabel('Number of selected genes', fontsize = 17)
ax1.set_ylabel(r'Cross validated $R^2$', fontsize = 17)
ax1.set_title('Sparse reduced-rank regression', fontsize = 20, y=1.02)
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.tick_params(axis='both', which='minor', labelsize=15)
ax1.vlines(x=25, ymin=ax1.get_ylim()[0], ymax=ax1.get_ylim()[1], linestyles='dashed')
ax1.annotate('sRRR, r=16', (70, np.max(cr_16)+0.0003), fontsize=15)
ax1.annotate('sRRR, r=2', (70, np.max(cr_2)+0.0003), fontsize=15)


ax2 = fig.add_subplot(spec[0, 1])
ax2.plot(range(50), np.mean(pre_tr_hist_tr, axis=(0, 2))[2, :], \
         '--', c = 'k', linewidth=linewidth)
ax2.plot(range(50), np.mean(pre_tr_hist, axis=(0, 2))[2, :], \
         c = 'k', linewidth=linewidth)
ax2.set_title('Pretraining', fontsize = 19, y=1.02)
ax2.set_xlabel('Epoch', fontsize = 17)
ax2.set_ylabel('Cross entropy loss', fontsize = 17)
ax2.tick_params(axis='both', which='major', labelsize=15)
ax2.tick_params(axis='both', which='minor', labelsize=15)
ax2.set_ylim([0, ax2.get_ylim()[1]])
ax2.annotate('Training', (35, 1.65), fontsize=15)
ax2.annotate('Test', (35, 2.36), fontsize=15)
ax2.set_xticks(np.arange(0, 60, 10))

epochs_used=200
ax3 = fig.add_subplot(spec[0, 2])
ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist_tr, axis=(0))[2,0,:], \
         '--', c = '#1b9e77', linewidth=linewidth)
ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist, axis=(0))[2,0,:], \
         c = '#1b9e77', linewidth=linewidth, label='With pre-training')
# ax3.plot(range(epochs_used), np.mean(r2_pretr_straight_regr_hist_tr, axis=(0))[0,0,:], \
#          '--', c = '#d95f02', linewidth=linewidth)
# ax3.plot(range(epochs_used), np.mean(r2_pretr_straight_regr_hist, axis=(0))[0,0,:], \
#          c = '#d95f02', linewidth=linewidth, label='Pre-training + no freezing')
ax3.plot(range(epochs_used), np.mean(r2_straight_regr_hist_tr, axis=(0))[0,0,:], \
         '--', c = '#d95f02', linewidth=linewidth)
ax3.plot(range(epochs_used), np.mean(r2_straight_regr_hist, axis=(0))[0,0,:], \
         c = '#d95f02', linewidth=linewidth, label='No pre-training')
ax3.hlines(r_rank16_r[np.isclose(n_rank16, 25, atol=3)], xmin = 0, xmax = epochs_used, \
            colors = np.array([0, 0, 0])/256, linewidth=linewidth)
ax3.hlines(r_rank2_r[np.isclose(n_rank2, 25, atol=3)], xmin = 0, xmax = epochs_used, \
            colors = np.array([0, 0, 0])/256, linewidth=linewidth)
ax3.set_ylim([0.3,0.45])
ax3.set_xlim([0,200])
ax3.set_xticks(np.arange(0, 225, 25))
ax3.annotate('RRR, r=16', (178, r_rank16_r[np.isclose(n_rank16, 25, atol=3)]+0.01), fontsize=15)
ax3.annotate('RRR, r=2', (178, r_rank2_r[np.isclose(n_rank2, 25, atol=3)]+0.003), fontsize=15)
ax3.set_title('Bottleneck neural network', fontsize = 19, y=1.02)
ax3.set_xlabel('Epoch', fontsize = 17)
ax3.set_ylabel(r'$R^2$', fontsize = 17)
ax3.tick_params(axis='both', which='major', labelsize=15)
ax3.tick_params(axis='both', which='minor', labelsize=15)
ax3.legend(loc='lower right', fontsize=15)
ax3.vlines(x=50, ymin=ax3.get_ylim()[0], ymax=ax3.get_ylim()[1], linestyles='dashed')
ax3.vlines(x=100, ymin=ax3.get_ylim()[0], ymax=ax3.get_ylim()[1], linestyles='dashed')

plt.text(-0.25, 1.04, 'a', transform = ax1.transAxes, fontsize=25, fontweight='bold')
plt.text(-0.11, 1.04, 'b', transform = ax2.transAxes, fontsize=25, fontweight='bold')
plt.text(-0.13, 1.04, 'c', transform = ax3.transAxes, fontsize=25, fontweight='bold')
sns.despine()

plt.savefig('figures/Lasso_training_curves.pdf', bbox_inches='tight',
    pad_inches=0)
plt.savefig('figures/Lasso_training_curves.png', bbox_inches='tight',
    pad_inches=0)

# %% [markdown]
# # Extensions

# %% [markdown]
# How many nodes in the bottleneck do we need to really perform clearly above (and relatively soon above) the full rank linear model?

# %%
importlib.reload(bottleneck_networks)
# Out:
# <module 'bottleneck_networks' from '/gpfs01/berens/user/ybernaerts/EphysAnalysis/data/ephys/sBNN/bottleneck_networks.py'>

# %%
from bottleneck_networks import ClassificationPreTrain

# %%
# What about using different amount of nodes in the bottleneck?
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([1e-1])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs


t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]
clusters_ = clusters[ind]
ind_pre_train = ind_pre_training_clusters[ind]

CE_loss = np.zeros((len(range(2,12,2)), folds, l1_params.shape[0], l2_params.shape[0]))
CE_loss_tr = np.zeros((len(range(2,12,2)), folds, l1_params.shape[0], l2_params.shape[0]))
pre_tr_hist = np.zeros((len(range(2,12,2)), folds, l1_params.shape[0], l2_params.shape[0], epochs))
pre_tr_hist_tr = np.zeros((len(range(2,12,2)), folds, l1_params.shape[0], l2_params.shape[0], epochs))


for u,f in enumerate(range(2,12,2)):
    nodes_list=[512, 128, f, 128, 512]
    print('Bottleneck with {} nodes'.format(f))
    # CV folds
    for cvfold in range(folds):
        print('\nCVFOLD: ', cvfold)
        indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
        indtrain = np.setdiff1d(np.arange(n), indtest)
        x_train = np.copy(X[indtrain,:])
        clusters_train = np.copy(clusters_[indtrain])
        y_train = np.copy(Y[indtrain,:])
        x_test = np.copy(X[indtest,:])
        clusters_test = np.copy(clusters_[indtest])
        y_test = np.copy(Y[indtest,:])

        # Mean centering (like sRRR)
        X_mean = np.mean(x_train, axis=0)
        x_train -= X_mean
        x_test -= X_mean
        Y_mean = np.mean(y_train, axis=0)
        y_train -= Y_mean
        y_test -= Y_mean

        # In our training set we now look for a 'pretraining' training and test data set that we can use
        # for pretraing a classification network, i.e. picking the best model will be dones with a seperate val set in our
        # training set for regression.

        x_train_pre_tr = x_train[ind_pre_train[indtrain], :]
        clusters_train_pre_tr = clusters_train[ind_pre_train[indtrain]]

        pre_train_size = 0.6
        train_cnt = round(x_train_pre_tr.shape[0]*pre_train_size)
        x_train_pre_tr_ = x_train_pre_tr[:train_cnt, :]
        x_test_pre_tr_ = x_train_pre_tr[train_cnt:, :]
        clusters_train_pre_tr_ = clusters_train_pre_tr[:train_cnt]
        clusters_test_pre_tr_ = clusters_train_pre_tr[train_cnt:]

        for i, l2 in enumerate(l2_params):
            #print('Ridge penalty: ', l2)
            for j, l1 in enumerate(l1_params):
                #print('Lasso penalty: ', l1)


                input_dim = x_train.shape[1]
                output_dim = to_categorical(clusters_train_pre_tr).shape[1]
                BN_Classification = ClassificationPreTrain(l1=l1, l2=l2, lr=lr, act=act, input_dim=input_dim, \
                                                           output_dim=output_dim, nodes_list=nodes_list)
                CE_train, CE_test, train_hist, test_hist = BN_Classification.train(x_train=x_train_pre_tr_, \
                                                                                   cluster_train=clusters_train_pre_tr_, \
                                                                                   x_test=x_test_pre_tr_, \
                                                                                   cluster_test=clusters_test_pre_tr_, \
                                                                                   epochs=epochs, bs=bs, patience=patience, \
                                                                                   cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                                   verbose=0, \
                                                                                   output_name='nodes_list_{}'.format(u))
                CE_loss[u, cvfold, j, i] = CE_test
                CE_loss_tr[u, cvfold, j, i] = CE_train
                pre_tr_hist[u, cvfold, j, i] = test_hist
                pre_tr_hist_tr[u, cvfold, j, i] = train_hist
                #print('Test CE loss (pre-trainin): ', CE_loss[cvfold, j, i])
            
t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# Bottleneck with 2 nodes
#
# CVFOLD:  0
# [INFO] training network...
# 655/655 [==============================] - 0s 201us/sample - loss: 55.4119 - categorical_crossentropy: 1.7637
# 437/437 [==============================] - 0s 84us/sample - loss: 55.8082 - categorical_crossentropy: 2.1601
#
# CVFOLD:  1
# [INFO] training network...
# 655/655 [==============================] - 0s 186us/sample - loss: 48.2314 - categorical_crossentropy: 1.6103
# 437/437 [==============================] - 0s 83us/sample - loss: 48.6748 - categorical_crossentropy: 2.0537
#
# CVFOLD:  2
# [INFO] training network...
# 655/655 [==============================] - 0s 195us/sample - loss: 48.4081 - categorical_crossentropy: 1.4603
# 437/437 [==============================] - 0s 82us/sample - loss: 48.9267 - categorical_crossentropy: 1.9789
#
# CVFOLD:  3
# [INFO] training network...
# 655/655 [==============================] - 0s 197us/sample - loss: 54.9541 - categorical_crossentropy: 1.7625
# 437/437 [==============================] - 0s 91us/sample - loss: 55.2931 - categorical_crossentropy: 2.1016
#
# CVFOLD:  4
# [INFO] training network...
# 655/655 [==============================] - 0s 190us/sample - loss: 47.9313 - categorical_crossentropy: 1.6738
# 437/437 [==============================] - 0s 87us/sample - loss: 48.2927 - categorical_crossentropy: 2.0351
#
# CVFOLD:  5
# [INFO] training network...
# 655/655 [==============================] - 0s 194us/sample - loss: 54.9445 - categorical_crossentropy: 1.7551
# 437/437 [==============================] - 0s 91us/sample - loss: 55.3030 - categorical_crossentropy: 2.1135
#
# CVFOLD:  6
# [INFO] training network...
# 655/655 [==============================] - 0s 198us/sample - loss: 55.0913 - categorical_crossentropy: 1.7652
# 437/437 [==============================] - 0s 94us/sample - loss: 55.5487 - categorical_crossentropy: 2.2226
#
# CVFOLD:  7
# [INFO] training network...
# 655/655 [==============================] - 0s 204us/sample - loss: 44.8284 - categorical_crossentropy: 1.5517
# 437/437 [==============================] - 0s 89us/sample - loss: 45.3527 - categorical_crossentropy: 2.0761
#
# CVFOLD:  8
# [INFO] training network...
# 655/655 [==============================] - 0s 190us/sample - loss: 48.2556 - categorical_crossentropy: 1.6212
# 437/437 [==============================] - 0s 88us/sample - loss: 48.7155 - categorical_crossentropy: 2.0811
#
# CVFOLD:  9
# [INFO] training network...
# 655/655 [==============================] - 0s 185us/sample - loss: 2.1244 - categorical_crossentropy: 1.4778
# 437/437 [==============================] - 0s 91us/sample - loss: 2.7875 - categorical_crossentropy: 2.1410
# Bottleneck with 4 nodes
#
# CVFOLD:  0
# [INFO] training network...
# 655/655 [==============================] - 0s 211us/sample - loss: 55.1463 - categorical_crossentropy: 1.4156
# 437/437 [==============================] - 0s 91us/sample - loss: 55.6218 - categorical_crossentropy: 1.8911
#
# CVFOLD:  1
# [INFO] training network...
# 655/655 [==============================] - 0s 189us/sample - loss: 55.1325 - categorical_crossentropy: 1.3862
# 437/437 [==============================] - 0s 88us/sample - loss: 55.6342 - categorical_crossentropy: 1.8879
#
# CVFOLD:  2
# [INFO] training network...
# 655/655 [==============================] - 0s 186us/sample - loss: 52.1214 - categorical_crossentropy: 1.2930
# 437/437 [==============================] - 0s 92us/sample - loss: 52.6955 - categorical_crossentropy: 1.8671
#
# CVFOLD:  3
# [INFO] training network...
# 655/655 [==============================] - 0s 209us/sample - loss: 55.2445 - categorical_crossentropy: 1.4362
# 437/437 [==============================] - 0s 93us/sample - loss: 55.7900 - categorical_crossentropy: 1.9817
#
# CVFOLD:  4
# [INFO] training network...
# 655/655 [==============================] - 0s 197us/sample - loss: 55.2091 - categorical_crossentropy: 1.3547
# 437/437 [==============================] - 0s 99us/sample - loss: 55.7478 - categorical_crossentropy: 1.8934
#
# CVFOLD:  5
# [INFO] training network...
# 655/655 [==============================] - 0s 196us/sample - loss: 52.0018 - categorical_crossentropy: 1.3450
# 437/437 [==============================] - 0s 87us/sample - loss: 52.5989 - categorical_crossentropy: 1.9421
#
# CVFOLD:  6
# [INFO] training network...
# 655/655 [==============================] - 0s 194us/sample - loss: 48.6819 - categorical_crossentropy: 1.2080
# 437/437 [==============================] - 0s 94us/sample - loss: 49.3798 - categorical_crossentropy: 1.9058
#
# CVFOLD:  7
# [INFO] training network...
# 655/655 [==============================] - 0s 189us/sample - loss: 51.7470 - categorical_crossentropy: 1.3080
# 437/437 [==============================] - 0s 88us/sample - loss: 52.4490 - categorical_crossentropy: 2.0100
#
# CVFOLD:  8
# [INFO] training network...
# 655/655 [==============================] - 0s 240us/sample - loss: 55.2262 - categorical_crossentropy: 1.4300
# 437/437 [==============================] - 0s 107us/sample - loss: 55.6850 - categorical_crossentropy: 1.8888
#
# CVFOLD:  9
# [INFO] training network...
# 655/655 [==============================] - 0s 204us/sample - loss: 55.3545 - categorical_crossentropy: 1.4004
# 437/437 [==============================] - 0s 100us/sample - loss: 56.0590 - categorical_crossentropy: 2.1049
# Bottleneck with 6 nodes
#
# CVFOLD:  0
# [INFO] training network...
# 655/655 [==============================] - 0s 218us/sample - loss: 55.8366 - categorical_crossentropy: 1.2569
# 437/437 [==============================] - 0s 94us/sample - loss: 56.5091 - categorical_crossentropy: 1.9293
#
# CVFOLD:  1
# [INFO] training network...
# 655/655 [==============================] - 0s 218us/sample - loss: 55.4811 - categorical_crossentropy: 1.2833
# 437/437 [==============================] - 0s 93us/sample - loss: 56.0830 - categorical_crossentropy: 1.8853
#
# CVFOLD:  2
# [INFO] training network...
# 655/655 [==============================] - 0s 264us/sample - loss: 52.6407 - categorical_crossentropy: 1.1392
# 437/437 [==============================] - 0s 94us/sample - loss: 53.3792 - categorical_crossentropy: 1.8777
#
# CVFOLD:  3
# [INFO] training network...
# 655/655 [==============================] - 0s 201us/sample - loss: 55.8897 - categorical_crossentropy: 1.2592
# 437/437 [==============================] - 0s 92us/sample - loss: 56.5516 - categorical_crossentropy: 1.9210
#
# CVFOLD:  4
# [INFO] training network...
# 655/655 [==============================] - 0s 204us/sample - loss: 55.4784 - categorical_crossentropy: 1.3029
# 437/437 [==============================] - 0s 92us/sample - loss: 56.0578 - categorical_crossentropy: 1.8823
#
# CVFOLD:  5
# [INFO] training network...
# 655/655 [==============================] - 0s 211us/sample - loss: 52.5329 - categorical_crossentropy: 1.1650
# 437/437 [==============================] - 0s 98us/sample - loss: 53.3122 - categorical_crossentropy: 1.9443
#
# CVFOLD:  6
# [INFO] training network...
# 655/655 [==============================] - 0s 195us/sample - loss: 52.4399 - categorical_crossentropy: 1.1580
# 437/437 [==============================] - 0s 94us/sample - loss: 53.1854 - categorical_crossentropy: 1.9036
#
# CVFOLD:  7
# [INFO] training network...
# 655/655 [==============================] - 0s 200us/sample - loss: 52.0401 - categorical_crossentropy: 1.1984
# 437/437 [==============================] - 0s 83us/sample - loss: 52.7621 - categorical_crossentropy: 1.9204
#
# CVFOLD:  8
# [INFO] training network...
# 655/655 [==============================] - 0s 193us/sample - loss: 55.5457 - categorical_crossentropy: 1.3065
# 437/437 [==============================] - 0s 91us/sample - loss: 56.1306 - categorical_crossentropy: 1.8915
#
# CVFOLD:  9
# [INFO] training network...
# 655/655 [==============================] - 0s 194us/sample - loss: 52.6862 - categorical_crossentropy: 1.0562
# 437/437 [==============================] - 0s 92us/sample - loss: 53.5295 - categorical_crossentropy: 1.8994
# Bottleneck with 8 nodes
#
# CVFOLD:  0
# [INFO] training network...
# 655/655 [==============================] - 0s 261us/sample - loss: 52.9488 - categorical_crossentropy: 1.0813
# 437/437 [==============================] - 0s 88us/sample - loss: 53.8297 - categorical_crossentropy: 1.9622
#
# CVFOLD:  1
# [INFO] training network...
# 655/655 [==============================] - 0s 205us/sample - loss: 55.8577 - categorical_crossentropy: 1.2539
# 437/437 [==============================] - 0s 97us/sample - loss: 56.5162 - categorical_crossentropy: 1.9123
#
# CVFOLD:  2
# [INFO] training network...
# 655/655 [==============================] - 0s 207us/sample - loss: 55.8588 - categorical_crossentropy: 1.2338
# 437/437 [==============================] - 0s 98us/sample - loss: 56.5722 - categorical_crossentropy: 1.9472
#
# CVFOLD:  3
# [INFO] training network...
# 655/655 [==============================] - 0s 191us/sample - loss: 52.6194 - categorical_crossentropy: 1.0931
# 437/437 [==============================] - 0s 98us/sample - loss: 53.4165 - categorical_crossentropy: 1.8901
#
# CVFOLD:  4
# [INFO] training network...
# 655/655 [==============================] - 0s 224us/sample - loss: 55.9441 - categorical_crossentropy: 1.2632
# 437/437 [==============================] - 0s 94us/sample - loss: 56.6229 - categorical_crossentropy: 1.9420
#
# CVFOLD:  5
# [INFO] training network...
# 655/655 [==============================] - 0s 188us/sample - loss: 56.3906 - categorical_crossentropy: 1.1557
# 437/437 [==============================] - 0s 85us/sample - loss: 57.0775 - categorical_crossentropy: 1.8427
#
# CVFOLD:  6
# [INFO] training network...
# 655/655 [==============================] - 0s 197us/sample - loss: 52.6805 - categorical_crossentropy: 1.1113
# 437/437 [==============================] - 0s 84us/sample - loss: 53.4330 - categorical_crossentropy: 1.8638
#
# CVFOLD:  7
# [INFO] training network...
# 655/655 [==============================] - 0s 199us/sample - loss: 55.8537 - categorical_crossentropy: 1.2911
# 437/437 [==============================] - 0s 96us/sample - loss: 56.5173 - categorical_crossentropy: 1.9548
#
# CVFOLD:  8
# [INFO] training network...
# 655/655 [==============================] - 0s 192us/sample - loss: 52.8761 - categorical_crossentropy: 1.0805
# 437/437 [==============================] - 0s 84us/sample - loss: 53.6829 - categorical_crossentropy: 1.8873
#
# CVFOLD:  9
# [INFO] training network...
# 655/655 [==============================] - 0s 194us/sample - loss: 49.4251 - categorical_crossentropy: 1.0839
# 437/437 [==============================] - 0s 84us/sample - loss: 50.1944 - categorical_crossentropy: 1.8533
# Bottleneck with 10 nodes
#
# CVFOLD:  0
# [INFO] training network...
# 655/655 [==============================] - 0s 200us/sample - loss: 59.4730 - categorical_crossentropy: 1.2990
# 437/437 [==============================] - 0s 92us/sample - loss: 60.1367 - categorical_crossentropy: 1.9626
#
# CVFOLD:  1
# [INFO] training network...
# 655/655 [==============================] - 0s 194us/sample - loss: 52.5257 - categorical_crossentropy: 1.0145
# 437/437 [==============================] - 0s 96us/sample - loss: 53.4483 - categorical_crossentropy: 1.9372
#
# CVFOLD:  2
# [INFO] training network...
# 655/655 [==============================] - 0s 191us/sample - loss: 49.4724 - categorical_crossentropy: 0.9493
# 437/437 [==============================] - 0s 86us/sample - loss: 50.3929 - categorical_crossentropy: 1.8698
#
# CVFOLD:  3
# [INFO] training network...
# 655/655 [==============================] - 0s 192us/sample - loss: 56.1256 - categorical_crossentropy: 1.1870
# 437/437 [==============================] - 0s 89us/sample - loss: 56.8543 - categorical_crossentropy: 1.9158
#
# CVFOLD:  4
# [INFO] training network...
# 655/655 [==============================] - 0s 194us/sample - loss: 59.4855 - categorical_crossentropy: 1.3589
# 437/437 [==============================] - 0s 93us/sample - loss: 60.0183 - categorical_crossentropy: 1.8917
#
# CVFOLD:  5
# [INFO] training network...
# 655/655 [==============================] - 0s 194us/sample - loss: 56.4221 - categorical_crossentropy: 1.1952
# 437/437 [==============================] - 0s 86us/sample - loss: 57.1311 - categorical_crossentropy: 1.9042
#
# CVFOLD:  6
# [INFO] training network...
# 655/655 [==============================] - 0s 191us/sample - loss: 56.0703 - categorical_crossentropy: 1.2020
# 437/437 [==============================] - 0s 93us/sample - loss: 56.7437 - categorical_crossentropy: 1.8754
#
# CVFOLD:  7
# [INFO] training network...
# 655/655 [==============================] - 0s 222us/sample - loss: 56.5335 - categorical_crossentropy: 1.0828
# 437/437 [==============================] - 0s 98us/sample - loss: 57.4306 - categorical_crossentropy: 1.9799
#
# CVFOLD:  8
# [INFO] training network...
# 655/655 [==============================] - 0s 214us/sample - loss: 49.7945 - categorical_crossentropy: 0.9095
# 437/437 [==============================] - 0s 92us/sample - loss: 50.7298 - categorical_crossentropy: 1.8447
#
# CVFOLD:  9
# [INFO] training network...
# 655/655 [==============================] - 0s 194us/sample - loss: 56.2597 - categorical_crossentropy: 1.2291
# 437/437 [==============================] - 0s 97us/sample - loss: 56.9155 - categorical_crossentropy: 1.8849
# Time: 0.0h  8m 43s

# %%
from bottleneck_networks import FreezeUnfreeze

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([1e-1])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs
pre_trained_weights=True
unfreeze = [False, False, True, True, True, True] # last 4 layers can be trained only first
prune=True

r2_before_unfreezing = np.zeros((len(range(2,12,2)), folds, l1_params.shape[0], l2_params.shape[0]))
r2_before_unfreezing_tr = np.zeros((len(range(2,12,2)), folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing = np.zeros((len(range(2,12,2)), folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_tr = np.zeros((len(range(2,12,2)), folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_ap = np.zeros((len(range(2,12,2)), folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_ap_tr = np.zeros((len(range(2,12,2)), folds, l1_params.shape[0], l2_params.shape[0]))
r2_freeze_unfreeze_hist = np.zeros((len(range(2,12,2)), folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))
r2_freeze_unfreeze_hist_tr = np.zeros((len(range(2,12,2)), folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

for u,f in enumerate(range(2,12,2)):
    nodes_list=[512, 128, f, 128, 512]
    print('Bottleneck with {} nodes'.format(f))
    # CV folds
    for cvfold in range(folds):
        print('\nCVFOLD: ', cvfold)
        indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
        indtrain = np.setdiff1d(np.arange(n), indtest)
        x_train = np.copy(X[indtrain,:])
        y_train = np.copy(Y[indtrain,:])
        x_test = np.copy(X[indtest,:])
        y_test = np.copy(Y[indtest,:])

        # Mean centering (like sRRR)
        X_mean = np.mean(x_train, axis=0)
        x_train -= X_mean
        x_test -= X_mean
        Y_mean = np.mean(y_train, axis=0)
        y_train -= Y_mean
        y_test -= Y_mean

        input_dim = x_train.shape[1]
        output_dim = y_train.shape[1]

        for i, l2 in enumerate(l2_params):
            #print('Ridge penalty: ', l2)
            for j, l1 in enumerate(l1_params):
                #print('Lasso penalty: ', l1)

                pre_trained_weights_h5 = 'KerasSavedModels/{}/Classification_last_weights_{}_{}_{}.h5'.\
                                                format('nodes_list_{}'.format(u),cvfold, j, i)
                input_dim = x_train.shape[1]
                output_dim = y_train.shape[1]
                BN_PreTrFreezeUnfreeze = FreezeUnfreeze(l1=l1, l2=l2, lr=lr, act=act, input_dim=input_dim, output_dim=output_dim, \
                                                           unfreeze = unfreeze, \
                                                           pre_trained_weights=pre_trained_weights, \
                                                           pre_trained_weights_h5=pre_trained_weights_h5, \
                                                           nodes_list=nodes_list)
                r2_before_unfreezing_train, r2_before_unfreezing_test, \
                    r2_after_unfreezing_train, r2_after_unfreezing_test, \
                    r2_after_unfreezing_train_ap, r2_after_unfreezing_test_ap, \
                    train_hist, test_hist = BN_PreTrFreezeUnfreeze.train(x_train=x_train, y_train=y_train, \
                                                                        x_test=x_test, y_test=y_test, \
                                                                        epochs=epochs, bs=bs, patience=patience, \
                                                                        cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                        prune=prune, geneNames=gene_names, \
                                                                        verbose=0)
                r2_before_unfreezing[u, cvfold, j, i] = r2_before_unfreezing_test
                r2_before_unfreezing_tr[u, cvfold, j, i] = r2_before_unfreezing_train
                r2_after_unfreezing[u, cvfold, j, i] = r2_after_unfreezing_test
                r2_after_unfreezing_tr[u, cvfold, j, i] = r2_after_unfreezing_train
                r2_after_unfreezing_ap[u, cvfold, j, i] = r2_after_unfreezing_test_ap
                r2_after_unfreezing_ap_tr[u, cvfold, j, i] = r2_after_unfreezing_train_ap
                r2_freeze_unfreeze_hist[u, cvfold, j, i] = test_hist
                r2_freeze_unfreeze_hist_tr[u, cvfold, j, i] = train_hist
                #print('Test R^2 score (before unfreezing): ', r2_before_unfreezing[cvfold, j, i])
                #print('Test R^2 score (after unfreezing): ', r2_after_unfreezing[cvfold, j, i])
                #print('Test R^2 score (after unfreezing and after pruning): ', r2_after_unfreezing_ap[cvfold, j, i])
            
t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# Bottleneck with 2 nodes
#
# CVFOLD:  0
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Erbb4' 'Mical2' 'Nell2' 'Phactr1' 'Kcnc2' 'Gabra1' 'Atp1a3' 'Gm11549'
#  'Plch2' 'Cplx1' 'Unc13c' 'Gabrd' 'Kcnip2' 'Enpp2' 'Grm7' 'Gm49948'
#  'Elfn1' 'Htr3a' 'Galnt14' 'Ndn' 'Lamp5' 'Gad1' 'Tac2' 'Pvalb' 'Sst']
# [INFO] training network...
# Train R^2 before unfreezing:  0.33830320835113525
# Test R^2 before unfreezing:  0.33475446701049805
# Train R^2 after unfreezing:  0.4302493929862976
# Test R^2 after unfreezing:  0.4383460283279419
# Train R^2 after unfreezing and pruning:  0.4181750416755676
# Test R^2 after unfreezing and pruning:  0.4496825337409973
#
# CVFOLD:  1
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Slc5a7' 'Nrip3' 'Elfn1' 'Gpm6b' 'Elmo1' 'Cdc42se2' 'Cplx1' 'Pfkp'
#  'Grip1' 'Sparcl1' 'Galnt14' 'Col24a1' 'Pcp4l1' 'Enpp2' 'Tac2' 'Plch2'
#  'Erbb4' 'Atp1a3' 'Ndn' 'Gm49948' 'Lamp5' 'Gad1' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.39688485860824585
# Test R^2 before unfreezing:  0.35895901918411255
# Train R^2 after unfreezing:  0.42294520139694214
# Test R^2 after unfreezing:  0.4182964563369751
# Train R^2 after unfreezing and pruning:  0.4203861951828003
# Test R^2 after unfreezing and pruning:  0.39681845903396606
#
# CVFOLD:  2
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Gm11549' 'Cacna1e' 'Phactr1' 'Kcnc2' 'Plch2' 'Arpp19' 'Kcnip2' 'Enpp2'
#  'Atp1a3' 'Cplx1' 'Htr3a' 'Galnt14' 'Ptk2b' 'Gm49948' 'Unc13c' 'Pcp4l1'
#  'Elfn1' 'Gad1' 'Sparcl1' 'Tac2' 'Lamp5' 'Ndn' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.39260631799697876
# Test R^2 before unfreezing:  0.3531184196472168
# Train R^2 after unfreezing:  0.44052737951278687
# Test R^2 after unfreezing:  0.39485108852386475
# Train R^2 after unfreezing and pruning:  0.43114393949508667
# Test R^2 after unfreezing and pruning:  0.38378679752349854
#
# CVFOLD:  3
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Gad2' 'Enpp2' 'Cnr1' 'Mas1' 'Cacna2d3' 'Pde1a' 'Phactr1' 'Gabra1'
#  'Cacna1e' 'Galnt14' 'Rit2' 'Zfp873' 'Satb1' 'Adcyap1' 'Mybpc1' 'Grip1'
#  'Ndn' 'Htr3a' 'Erbb4' 'Plch2' 'Lamp5' 'Sst' 'Tafa1' 'Pvalb' 'Gad1']
# [INFO] training network...
# Train R^2 before unfreezing:  0.3804553747177124
# Test R^2 before unfreezing:  0.3265131115913391
# Train R^2 after unfreezing:  0.4241916537284851
# Test R^2 after unfreezing:  0.3756125569343567
# Train R^2 after unfreezing and pruning:  0.41903239488601685
# Test R^2 after unfreezing and pruning:  0.3755820393562317
#
# CVFOLD:  4
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Kcnab1' 'Kcnip2' 'Sema3c' 'Enpp2' 'Col24a1' 'Satb1' 'Phactr1' 'Gm49948'
#  'Elfn1' 'Grm7' 'Unc13c' 'Galnt14' 'Nell2' 'Sparcl1' 'Tac2' 'Plch2'
#  'Htr3a' 'Synpr' 'Ndn' 'Ndst3' 'Lamp5' 'Sst' 'Gad1' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4054067134857178
# Test R^2 before unfreezing:  0.3661343455314636
# Train R^2 after unfreezing:  0.4414098858833313
# Test R^2 after unfreezing:  0.3785017728805542
# Train R^2 after unfreezing and pruning:  0.4290449023246765
# Test R^2 after unfreezing and pruning:  0.38072025775909424
#
# CVFOLD:  5
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Galnt14' 'Npy1r' 'Unc13c' 'Rab3b' 'Reln' 'Cbln2' 'Tac2' 'Elmo1' 'Kcnip2'
#  'Phactr1' 'Enpp2' 'Cacna1e' 'Htr3a' 'Chrnb3' 'Nell1' 'Mybpc1' 'Slc6a1'
#  'Ndn' 'Erbb4' 'Plch2' 'Tafa1' 'Lamp5' 'Sst' 'Gad1' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.38144975900650024
# Test R^2 before unfreezing:  0.31532806158065796
# Train R^2 after unfreezing:  0.4294703006744385
# Test R^2 after unfreezing:  0.37394464015960693
# Train R^2 after unfreezing and pruning:  0.4253888726234436
# Test R^2 after unfreezing and pruning:  0.3689362406730652
#
# CVFOLD:  6
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Caln1' 'Cbln2' 'Cacna2d3' 'Ntm' 'Npy1r' 'Grip1' 'Elmo1' 'Npy' 'Tac1'
#  'Kcnab1' 'Sparcl1' 'Cplx1' 'Atp1a3' 'Synpr' 'Ptk2b' 'Adarb2' 'Tafa1'
#  'Fxyd6' 'Kit' 'Coro6' 'Slc6a1' 'Erbb4' 'Vip' 'Pvalb' 'Gad1']
# [INFO] training network...
# Train R^2 before unfreezing:  0.3662559390068054
# Test R^2 before unfreezing:  0.34128981828689575
# Train R^2 after unfreezing:  0.4236394762992859
# Test R^2 after unfreezing:  0.39210373163223267
# Train R^2 after unfreezing and pruning:  0.42557066679000854
# Test R^2 after unfreezing and pruning:  0.3951880931854248
#
# CVFOLD:  7
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Pcp4l1' 'Kcnip2' 'Phactr1' 'Gabrd' 'Afap1' 'Satb1' 'Mical2' 'Slc6a1'
#  'Npy1r' 'Atp1a3' 'Nell2' 'Htr3a' 'Cplx1' 'Plch2' 'Ndst3' 'Galnt14' 'Tac2'
#  'Gad1' 'Sparcl1' 'Gm49948' 'Ndn' 'Lamp5' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.37272173166275024
# Test R^2 before unfreezing:  0.38088470697402954
# Train R^2 after unfreezing:  0.4402594566345215
# Test R^2 after unfreezing:  0.43877410888671875
# Train R^2 after unfreezing and pruning:  0.42279261350631714
# Test R^2 after unfreezing and pruning:  0.4141160249710083
#
# CVFOLD:  8
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Galnt14' 'Bcl2l11' 'Pcdh7' 'Atp1b2' 'Cplx1' 'Htr3a' 'Grip1' 'Satb1'
#  'Cacna1e' 'Cbln2' 'Gabra1' 'Kcnab1' 'Adcyap1' 'Mybpc1' 'Thsd7a' 'Plch2'
#  'Atp1a3' 'Ptk2b' 'Reln' 'Ndn' 'Lamp5' 'Erbb4' 'Tafa1' 'Pvalb' 'Gad1']
# [INFO] training network...
# Train R^2 before unfreezing:  0.3713184595108032
# Test R^2 before unfreezing:  0.29688572883605957
# Train R^2 after unfreezing:  0.422140896320343
# Test R^2 after unfreezing:  0.37861037254333496
# Train R^2 after unfreezing and pruning:  0.41251134872436523
# Test R^2 after unfreezing and pruning:  0.3580824136734009
#
# CVFOLD:  9
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Mas1' 'Enpp2' 'Elfn1' 'Ptk2b' 'Satb1' 'Grip1' 'Grm7' 'Dlx6os1' 'Cacna1e'
#  'Sema3c' 'Unc13c' 'Cplx1' 'Erbb4' 'Atp1a3' 'Htr3a' 'Tac2' 'Ndst3' 'Synpr'
#  'Lamp5' 'Ndn' 'Coro6' 'Gad1' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.39657121896743774
# Test R^2 before unfreezing:  0.35908085107803345
# Train R^2 after unfreezing:  0.4349355101585388
# Test R^2 after unfreezing:  0.41218888759613037
# Train R^2 after unfreezing and pruning:  0.4258487820625305
# Test R^2 after unfreezing and pruning:  0.3858872652053833
# Bottleneck with 4 nodes
#
# CVFOLD:  0
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Mical2' 'Ndst3' 'Arhgap32' 'Gabra1' 'Tafa1' 'Syt1' 'Thsd7a' 'Enpp2'
#  'Kcnab3' 'Plch2' 'Elmo1' 'Galnt14' 'Pde1a' 'Htr3a' 'Fxyd6' 'Gm49948'
#  'Ndn' 'Cplx1' 'Lamp5' 'Gad1' 'Tac2' 'Erbb4' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.45504993200302124
# Test R^2 before unfreezing:  0.4081570506095886
# Train R^2 after unfreezing:  0.48931223154067993
# Test R^2 after unfreezing:  0.4636467695236206
# Train R^2 after unfreezing and pruning:  0.4678577184677124
# Test R^2 after unfreezing and pruning:  0.4461802840232849
#
# CVFOLD:  1
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Atp1a3' 'Ak5' 'Unc13c' 'Coro6' 'Kcnip2' 'Kcnv1' 'Elfn1' 'Ndst3' 'Tafa1'
#  'Plch2' 'Pde1a' 'Htr3a' 'Phactr1' 'Enpp2' 'Cplx1' 'Fxyd6' 'Ndn' 'Lamp5'
#  'Erbb4' 'Gm49948' 'Tac2' 'Gad1' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4489845633506775
# Test R^2 before unfreezing:  0.3485860824584961
# Train R^2 after unfreezing:  0.490619421005249
# Test R^2 after unfreezing:  0.44636404514312744
# Train R^2 after unfreezing and pruning:  0.46183186769485474
# Test R^2 after unfreezing and pruning:  0.43066179752349854
#
# CVFOLD:  2
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Sparcl1' 'Phactr1' 'Mas1' 'Kcnc2' 'Gm11549' 'Gm49948' 'Lingo2' 'Atp1a3'
#  'Elfn1' 'Gabra1' 'Unc13c' 'Plch2' 'Htr3a' 'Cplx1' 'Enpp2' 'Galnt14'
#  'Fxyd6' 'Tac2' 'Ndn' 'Lamp5' 'Erbb4' 'Sst' 'Gad1' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4606274366378784
# Test R^2 before unfreezing:  0.34698760509490967
# Train R^2 after unfreezing:  0.4891992211341858
# Test R^2 after unfreezing:  0.41572123765945435
# Train R^2 after unfreezing and pruning:  0.45432722568511963
# Test R^2 after unfreezing and pruning:  0.40093719959259033
#
# CVFOLD:  3
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Syt1' 'Plch2' 'Phactr1' 'Sparcl1' 'Cacna1e' 'Gabra1' 'Pdyn' 'Coro6'
#  'Elmo1' 'Tafa1' 'Galnt14' 'Ndst3' 'Satb1' 'Tac2' 'Thsd7a' 'Cplx1' 'Fxyd6'
#  'Erbb4' 'Ndn' 'Lamp5' 'Htr3a' 'Sst' 'Pvalb' 'Gad1' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4395413398742676
# Test R^2 before unfreezing:  0.3468536138534546
# Train R^2 after unfreezing:  0.4916002154350281
# Test R^2 after unfreezing:  0.44237321615219116
# Train R^2 after unfreezing and pruning:  0.4629012942314148
# Test R^2 after unfreezing and pruning:  0.436553955078125
#
# CVFOLD:  4
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Gabra1' 'Afap1' 'Fxyd6' 'Tac2' 'Pamr1' 'Plch2' 'Cplx3' 'Coro6' 'Enpp2'
#  'Phactr1' 'Tafa1' 'Gm49948' 'Cbln2' 'Lamp5' 'Atp1a3' 'Ndst3' 'Cplx1'
#  'Ndn' 'Galnt14' 'Gad1' 'Htr3a' 'Erbb4' 'Sst' 'Vip' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4619518518447876
# Test R^2 before unfreezing:  0.3825035095214844
# Train R^2 after unfreezing:  0.49391859769821167
# Test R^2 after unfreezing:  0.43460679054260254
# Train R^2 after unfreezing and pruning:  0.4653380513191223
# Test R^2 after unfreezing and pruning:  0.4374505281448364
#
# CVFOLD:  5
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Unc13c' 'Thsd7a' 'Pdyn' 'Coro6' 'Phactr1' 'Chrnb3' 'Elmo1' 'Atp1a3'
#  'Slc6a1' 'Cplx1' 'Npy' 'Plch2' 'Gm49948' 'Galnt14' 'Ndst3' 'Fxyd6'
#  'Erbb4' 'Ndn' 'Htr3a' 'Tac2' 'Lamp5' 'Sst' 'Gad1' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.41735249757766724
# Test R^2 before unfreezing:  0.32488131523132324
# Train R^2 after unfreezing:  0.4836316704750061
# Test R^2 after unfreezing:  0.41656434535980225
# Train R^2 after unfreezing and pruning:  0.45754969120025635
# Test R^2 after unfreezing and pruning:  0.395940363407135
#
# CVFOLD:  6
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Elfn1' 'Tafa1' 'Cdh13' 'Pcp4l1' 'Gabra1' 'Pcdh7' 'Galnt14' 'Sema5a'
#  'Plch2' 'Elmo1' 'Lingo2' 'Cplx1' 'Enpp2' 'Gm49948' 'Fxyd6' 'Htr3a' 'Tac2'
#  'Ndn' 'Atp1a3' 'Gad1' 'Lamp5' 'Erbb4' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.42840999364852905
# Test R^2 before unfreezing:  0.3583688735961914
# Train R^2 after unfreezing:  0.5004495084285736
# Test R^2 after unfreezing:  0.439289927482605
# Train R^2 after unfreezing and pruning:  0.46409904956817627
# Test R^2 after unfreezing and pruning:  0.4244677424430847
#
# CVFOLD:  7
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Mas1' 'Cbln2' 'Tafa1' 'Mical2' 'Npy1r' 'Plch2' 'Enpp2' 'Htr3a' 'Elmo1'
#  'Slc6a1' 'Tac2' 'Phactr1' 'Fxyd6' 'Atp1a3' 'Ndst3' 'Coro6' 'Ndn' 'Lamp5'
#  'Galnt14' 'Erbb4' 'Gad1' 'Cplx1' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4126642942428589
# Test R^2 before unfreezing:  0.3552681803703308
# Train R^2 after unfreezing:  0.48190003633499146
# Test R^2 after unfreezing:  0.45912206172943115
# Train R^2 after unfreezing and pruning:  0.4606616497039795
# Test R^2 after unfreezing and pruning:  0.4755675196647644
#
# CVFOLD:  8
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Calb1' 'Kcnip2' 'Kcnab3' 'Cacna1e' 'Arhgap32' 'Gabra1' 'Foxred1' 'Cck'
#  'Tac2' 'Gabrd' 'Tafa1' 'Enpp2' 'Fxyd6' 'Atp1a3' 'Cplx1' 'Sst' 'Lamp5'
#  'Gm49948' 'Galnt14' 'Erbb4' 'Htr3a' 'Ndn' 'Pvalb' 'Gad1' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.42941397428512573
# Test R^2 before unfreezing:  0.33999162912368774
# Train R^2 after unfreezing:  0.4763185977935791
# Test R^2 after unfreezing:  0.42408281564712524
# Train R^2 after unfreezing and pruning:  0.46659839153289795
# Test R^2 after unfreezing and pruning:  0.3876916766166687
#
# CVFOLD:  9
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Tafa1' 'Npy' 'Ndst3' 'Satb1' 'Chrnb3' 'Atp1a3' 'Gpc3' 'Reln' 'Gm49948'
#  'Cplx1' 'Enpp2' 'Fxyd6' 'Pdyn' 'Plch2' 'Calb1' 'Galnt14' 'Tac2' 'Ndn'
#  'Erbb4' 'Lamp5' 'Htr3a' 'Sst' 'Gad1' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4429005980491638
# Test R^2 before unfreezing:  0.3855038285255432
# Train R^2 after unfreezing:  0.5124344229698181
# Test R^2 after unfreezing:  0.45129042863845825
# Train R^2 after unfreezing and pruning:  0.43402570486068726
# Test R^2 after unfreezing and pruning:  0.41219788789749146
# Bottleneck with 6 nodes
#
# CVFOLD:  0
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Elmo1' 'Ndnf' 'Syt1' 'Pde1a' 'Plch2' 'Ndst3' 'Pdyn' 'Enpp2' 'Atp1a3'
#  'Gpc3' 'Kcnab3' 'Fxyd6' 'Thsd7a' 'Gm49948' 'Htr3a' 'Galnt14' 'Cplx1'
#  'Erbb4' 'Ndn' 'Lamp5' 'Tac2' 'Gad1' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4797060489654541
# Test R^2 before unfreezing:  0.4111354351043701
# Train R^2 after unfreezing:  0.5046976804733276
# Test R^2 after unfreezing:  0.46776437759399414
# Train R^2 after unfreezing and pruning:  0.47263914346694946
# Test R^2 after unfreezing and pruning:  0.4450472593307495
#
# CVFOLD:  1
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Kcnip2' 'Pde1a' 'Phactr1' 'Atp1a3' 'Pdyn' 'Lingo2' 'Kcnc2' 'Enpp2'
#  'Thsd7a' 'Gabrd' 'Fxyd6' 'Galnt14' 'Elmo1' 'Htr3a' 'Plch2' 'Cplx1' 'Ndn'
#  'Erbb4' 'Gm49948' 'Tac2' 'Lamp5' 'Gad1' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4739954471588135
# Test R^2 before unfreezing:  0.4046570658683777
# Train R^2 after unfreezing:  0.5033937096595764
# Test R^2 after unfreezing:  0.45595651865005493
# Train R^2 after unfreezing and pruning:  0.46950429677963257
# Test R^2 after unfreezing and pruning:  0.44014793634414673
#
# CVFOLD:  2
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Kcnc2' 'Cxcl14' 'Fxyd6' 'Satb1' 'Gm49948' 'Sparcl1' 'Ndst3' 'Gabra1'
#  'Elfn1' 'Enpp2' 'Cbln2' 'Htr3a' 'Cplx1' 'Npy' 'Galnt14' 'Thsd7a' 'Unc13c'
#  'Ndn' 'Erbb4' 'Gad1' 'Tac2' 'Lamp5' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.465053915977478
# Test R^2 before unfreezing:  0.343349814414978
# Train R^2 after unfreezing:  0.4793083071708679
# Test R^2 after unfreezing:  0.41351479291915894
# Train R^2 after unfreezing and pruning:  0.46984565258026123
# Test R^2 after unfreezing and pruning:  0.41879427433013916
#
# CVFOLD:  3
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Gas7' 'Cck' 'Gabra1' 'Mas1' 'Lingo2' 'Elmo1' 'Gm49948' 'Afap1' 'Erbb4'
#  'Cbln2' 'Cplx1' 'Tac2' 'Enpp2' 'Ndn' 'Lamp5' 'Fxyd6' 'Galnt14' 'Pdyn'
#  'Ndst3' 'Thsd7a' 'Htr3a' 'Sst' 'Gad1' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.48361116647720337
# Test R^2 before unfreezing:  0.3992483615875244
# Train R^2 after unfreezing:  0.5011844336986542
# Test R^2 after unfreezing:  0.4489162564277649
# Train R^2 after unfreezing and pruning:  0.4695670008659363
# Test R^2 after unfreezing and pruning:  0.4263859987258911
#
# CVFOLD:  4
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Col24a1' 'Enpp2' 'Coro6' 'Cxcl14' 'Plch2' 'Gabra1' 'Elmo1' 'Pamr1'
#  'Gm49948' 'Atp1a3' 'Thsd7a' 'Galnt14' 'Tafa1' 'Ndst3' 'Ndn' 'Erbb4'
#  'Cplx1' 'Cbln2' 'Calb1' 'Htr3a' 'Lamp5' 'Gad1' 'Vip' 'Sst' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4984232187271118
# Test R^2 before unfreezing:  0.4205175042152405
# Train R^2 after unfreezing:  0.5090925991535187
# Test R^2 after unfreezing:  0.44150376319885254
# Train R^2 after unfreezing and pruning:  0.47944629192352295
# Test R^2 after unfreezing and pruning:  0.4461103081703186
#
# CVFOLD:  5
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Cck' 'Fxyd6' 'Reln' 'Enpp2' 'Foxred1' 'Coro6' 'Npy' 'Plch2' 'Gm49948'
#  'Kcnc2' 'Cxcl14' 'Slc6a1' 'Ndst3' 'Chat' 'Lamp5' 'Cplx1' 'Galnt14' 'Gad1'
#  'Tac2' 'Htr3a' 'Erbb4' 'Ndn' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4810309410095215
# Test R^2 before unfreezing:  0.3819783329963684
# Train R^2 after unfreezing:  0.5021086037158966
# Test R^2 after unfreezing:  0.4248879551887512
# Train R^2 after unfreezing and pruning:  0.4769202470779419
# Test R^2 after unfreezing and pruning:  0.38318562507629395
#
# CVFOLD:  6
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Atp1a3' 'Afap1' 'Gabrd' 'Pcdh7' 'Cdh13' 'Galnt14' 'Pik3r5' 'Tac2'
#  'Gm49948' 'Cplx1' 'Cplx3' 'Elmo1' 'Fxyd6' 'Calb1' 'Cbln2' 'Enpp2' 'Htr3a'
#  'Ndn' 'Erbb4' 'Ndst3' 'Gad1' 'Lamp5' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.45131832361221313
# Test R^2 before unfreezing:  0.36073189973831177
# Train R^2 after unfreezing:  0.5129768252372742
# Test R^2 after unfreezing:  0.44795727729797363
# Train R^2 after unfreezing and pruning:  0.47178345918655396
# Test R^2 after unfreezing and pruning:  0.4241349697113037
#
# CVFOLD:  7
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Calb1' 'Mical2' 'Chrnb3' 'Afap1' 'Npy1r' 'Lingo2' 'Sparcl1' 'Atp1a3'
#  'Gm49948' 'Phactr1' 'Enpp2' 'Elmo1' 'Ndst3' 'Fxyd6' 'Htr3a' 'Cplx1'
#  'Tac2' 'Lamp5' 'Galnt14' 'Erbb4' 'Ndn' 'Gad1' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.45242971181869507
# Test R^2 before unfreezing:  0.3540414571762085
# Train R^2 after unfreezing:  0.4975619912147522
# Test R^2 after unfreezing:  0.46653592586517334
# Train R^2 after unfreezing and pruning:  0.4716110825538635
# Test R^2 after unfreezing and pruning:  0.45860445499420166
#
# CVFOLD:  8
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Pde1a' 'Cxcl14' 'Elmo1' 'Tac2' 'Afap1' 'Erbb4' 'Gabra1' 'Gm49948'
#  'Thsd7a' 'Chrnb3' 'Enpp2' 'Calb1' 'Lamp5' 'Gabrd' 'Cbln2' 'Ndst3' 'Cplx1'
#  'Pdyn' 'Htr3a' 'Sst' 'Ndn' 'Galnt14' 'Gad1' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4635109305381775
# Test R^2 before unfreezing:  0.3670450448989868
# Train R^2 after unfreezing:  0.49031633138656616
# Test R^2 after unfreezing:  0.4309723377227783
# Train R^2 after unfreezing and pruning:  0.47941309213638306
# Test R^2 after unfreezing and pruning:  0.4019090533256531
#
# CVFOLD:  9
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Mas1' 'Thsd7a' 'Reln' 'Pamr1' 'Gabra1' 'Atp1a3' 'Plch2' 'Calb1' 'Ndst3'
#  'Tac2' 'Galnt14' 'Enpp2' 'Pdyn' 'Cplx1' 'Npy' 'Ndn' 'Cbln2' 'Fxyd6'
#  'Htr3a' 'Erbb4' 'Lamp5' 'Gad1' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4550028443336487
# Test R^2 before unfreezing:  0.3472493886947632
# Train R^2 after unfreezing:  0.5163717567920685
# Test R^2 after unfreezing:  0.4535292387008667
# Train R^2 after unfreezing and pruning:  0.46528273820877075
# Test R^2 after unfreezing and pruning:  0.41009825468063354
# Bottleneck with 8 nodes
#
# CVFOLD:  0
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Tafa1' 'Elmo1' 'Ndnf' 'Sparcl1' 'Calb1' 'Scg2' 'Gabra1' 'Gm49948' 'Gpc3'
#  'Cbln2' 'Atp1a3' 'Enpp2' 'Galnt14' 'Htr3a' 'Fxyd6' 'Thsd7a' 'Lamp5' 'Ndn'
#  'Tac2' 'Erbb4' 'Cplx1' 'Gad1' 'Sst' 'Vip' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.47494661808013916
# Test R^2 before unfreezing:  0.4171813726425171
# Train R^2 after unfreezing:  0.4930551052093506
# Test R^2 after unfreezing:  0.47801220417022705
# Train R^2 after unfreezing and pruning:  0.47224318981170654
# Test R^2 after unfreezing and pruning:  0.4589442014694214
#
# CVFOLD:  1
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Coro6' 'Ndst3' 'Galnt14' 'Gabra1' 'Lingo2' 'Reln' 'Plch2' 'Cbln2'
#  'Cplx1' 'Ndn' 'Gm43670' 'Htr3a' 'Atp1a3' 'Gm49948' 'Elmo1' 'Npy' 'Fxyd6'
#  'Erbb4' 'Enpp2' 'Tac2' 'Sst' 'Lamp5' 'Gad1' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4776516556739807
# Test R^2 before unfreezing:  0.38364285230636597
# Train R^2 after unfreezing:  0.4906173348426819
# Test R^2 after unfreezing:  0.4546438455581665
# Train R^2 after unfreezing and pruning:  0.4709377884864807
# Test R^2 after unfreezing and pruning:  0.4350373148918152
#
# CVFOLD:  2
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Pamr1' 'Phactr1' 'Cbln2' 'Gm49948' 'Fxyd6' 'Kcnc2' 'Gabra1' 'Thsd7a'
#  'Atp1a3' 'Elfn1' 'Cxcl14' 'Enpp2' 'Pdyn' 'Htr3a' 'Unc13c' 'Galnt14'
#  'Cplx1' 'Erbb4' 'Ndn' 'Tac2' 'Sst' 'Lamp5' 'Gad1' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.5044629573822021
# Test R^2 before unfreezing:  0.3934682607650757
# Train R^2 after unfreezing:  0.5079914033412933
# Test R^2 after unfreezing:  0.41068869829177856
# Train R^2 after unfreezing and pruning:  0.4743708372116089
# Test R^2 after unfreezing and pruning:  0.4066714644432068
#
# CVFOLD:  3
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Sparcl1' 'Cbln2' 'Afap1' 'Pdyn' 'Erbb4' 'Galnt14' 'Reln' 'Lingo2'
#  'Gm49948' 'Gabra1' 'Tac2' 'Fxyd6' 'Enpp2' 'Thsd7a' 'Ndn' 'Cplx1' 'Elmo1'
#  'Lamp5' 'Htr3a' 'Calb1' 'Ndst3' 'Sst' 'Pvalb' 'Vip' 'Gad1']
# [INFO] training network...
# Train R^2 before unfreezing:  0.49562740325927734
# Test R^2 before unfreezing:  0.4352419972419739
# Train R^2 after unfreezing:  0.5054943859577179
# Test R^2 after unfreezing:  0.44264113903045654
# Train R^2 after unfreezing and pruning:  0.479306161403656
# Test R^2 after unfreezing and pruning:  0.4304403066635132
#
# CVFOLD:  4
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Ncald' 'Thsd7a' 'Enpp2' 'Elmo1' 'Fxyd6' 'Gabra1' 'Pde1a' 'Gm49948'
#  'Ndst3' 'Tac2' 'Npy' 'Galnt14' 'Coro6' 'Cplx1' 'Tafa1' 'Pamr1' 'Phactr1'
#  'Erbb4' 'Htr3a' 'Ndn' 'Lamp5' 'Gad1' 'Sst' 'Vip' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4909994602203369
# Test R^2 before unfreezing:  0.38079196214675903
# Train R^2 after unfreezing:  0.4868382215499878
# Test R^2 after unfreezing:  0.4299784302711487
# Train R^2 after unfreezing and pruning:  0.4772832989692688
# Test R^2 after unfreezing and pruning:  0.43334078788757324
#
# CVFOLD:  5
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Tafa1' 'Pde1a' 'Ak5' 'Slc6a1' 'Gm49948' 'Plch2' 'Kcnc2' 'Thsd7a'
#  'Cxcl14' 'Pdyn' 'Chat' 'Fxyd6' 'Reln' 'Galnt14' 'Cplx1' 'Erbb4' 'Tac2'
#  'Calb1' 'Ndn' 'Gad1' 'Lamp5' 'Htr3a' 'Pvalb' 'Sst' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.48957252502441406
# Test R^2 before unfreezing:  0.37835150957107544
# Train R^2 after unfreezing:  0.4918166399002075
# Test R^2 after unfreezing:  0.4236915707588196
# Train R^2 after unfreezing and pruning:  0.4831313490867615
# Test R^2 after unfreezing and pruning:  0.41539502143859863
#
# CVFOLD:  6
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Coro6' 'Arhgap32' 'Col24a1' 'Ndnf' 'Pamr1' 'Tiam2' 'Unc13c' 'Magel2'
#  'Chat' 'Lingo2' 'Galnt14' 'Ndn' 'Cplx1' 'Fxyd6' 'Enpp2' 'Atp1a3' 'Ndst3'
#  'Tac2' 'Erbb4' 'Htr3a' 'Gad1' 'Lamp5' 'Pvalb' 'Vip' 'Sst']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4844343662261963
# Test R^2 before unfreezing:  0.37983113527297974
# Train R^2 after unfreezing:  0.5103184282779694
# Test R^2 after unfreezing:  0.4416477084159851
# Train R^2 after unfreezing and pruning:  0.4714086055755615
# Test R^2 after unfreezing and pruning:  0.4161716103553772
#
# CVFOLD:  7
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Plch2' 'Chrnb3' 'Slc5a7' 'Phactr1' 'Thsd7a' 'Mical2' 'Gm49948' 'Fxyd6'
#  'Chat' 'Tafa1' 'Ndst3' 'Cck' 'Atp1a3' 'Cplx1' 'Enpp2' 'Ndn' 'Erbb4'
#  'Tac2' 'Galnt14' 'Htr3a' 'Gad1' 'Lamp5' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4918721318244934
# Test R^2 before unfreezing:  0.4104999303817749
# Train R^2 after unfreezing:  0.495225191116333
# Test R^2 after unfreezing:  0.46650445461273193
# Train R^2 after unfreezing and pruning:  0.4721791744232178
# Test R^2 after unfreezing and pruning:  0.4693877696990967
#
# CVFOLD:  8
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Npy' 'Elmo1' 'Erbb4' 'Syt1' 'Fxyd6' 'Gabra1' 'Gabrd' 'Ndst3' 'Tac2'
#  'Thsd7a' 'Cbln2' 'Reln' 'Enpp2' 'Calb1' 'Pdyn' 'Gm49948' 'Cplx1' 'Htr3a'
#  'Galnt14' 'Lamp5' 'Sst' 'Pvalb' 'Ndn' 'Gad1' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4929240345954895
# Test R^2 before unfreezing:  0.3583058714866638
# Train R^2 after unfreezing:  0.4991375207901001
# Test R^2 after unfreezing:  0.4234549403190613
# Train R^2 after unfreezing and pruning:  0.47855281829833984
# Test R^2 after unfreezing and pruning:  0.40464597940444946
#
# CVFOLD:  9
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Atp1a3' 'Scg2' 'Npy' 'Gabra1' 'Fxyd6' 'Reln' 'Pde1a' 'Satb1' 'Thsd7a'
#  'Elmo1' 'Galnt14' 'Cplx1' 'Coro6' 'Pamr1' 'Tac2' 'Plch2' 'Erbb4' 'Ndn'
#  'Htr3a' 'Pdyn' 'Lamp5' 'Gad1' 'Pvalb' 'Sst' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.467689573764801
# Test R^2 before unfreezing:  0.39991146326065063
# Train R^2 after unfreezing:  0.5149269998073578
# Test R^2 after unfreezing:  0.44602882862091064
# Train R^2 after unfreezing and pruning:  0.4800705909729004
# Test R^2 after unfreezing and pruning:  0.4118685722351074
# Bottleneck with 10 nodes
#
# CVFOLD:  0
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Pcdh7' 'Gm43670' 'Gm11549' 'Gabra1' 'Cbln2' 'Gm49948' 'Pamr1' 'Elmo1'
#  'Ndst3' 'Atp1a3' 'Fxyd6' 'Pdyn' 'Htr3a' 'Enpp2' 'Ndn' 'Thsd7a' 'Erbb4'
#  'Galnt14' 'Lamp5' 'Cplx1' 'Tac2' 'Sst' 'Gad1' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4854303002357483
# Test R^2 before unfreezing:  0.42420703172683716
# Train R^2 after unfreezing:  0.5112215578556061
# Test R^2 after unfreezing:  0.47600817680358887
# Train R^2 after unfreezing and pruning:  0.4766654968261719
# Test R^2 after unfreezing and pruning:  0.4651910662651062
#
# CVFOLD:  1
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Galnt14' 'Chrnb3' 'Elmo1' 'Gabra1' 'Pde1a' 'Thsd7a' 'Phactr1' 'Gm43670'
#  'Htr3a' 'Lingo2' 'Gm49948' 'Fxyd6' 'Plch2' 'Cplx1' 'Enpp2' 'Atp1a3'
#  'Kcnc2' 'Erbb4' 'Ndn' 'Tac2' 'Sst' 'Lamp5' 'Gad1' 'Vip' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.49801135063171387
# Test R^2 before unfreezing:  0.4178023934364319
# Train R^2 after unfreezing:  0.5169212520122528
# Test R^2 after unfreezing:  0.4526793956756592
# Train R^2 after unfreezing and pruning:  0.4768184423446655
# Test R^2 after unfreezing and pruning:  0.4264286160469055
#
# CVFOLD:  2
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Gabra1' 'Tmem44' 'Npy' 'Ndst3' 'Col24a1' 'Unc13c' 'Sparcl1' 'Pamr1'
#  'Phactr1' 'Htr3a' 'Galnt14' 'Cxcl14' 'Lingo2' 'Enpp2' 'Mybpc1' 'Cbln2'
#  'Erbb4' 'Tac2' 'Cplx1' 'Gad1' 'Ndn' 'Sst' 'Lamp5' 'Vip' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.5035943984985352
# Test R^2 before unfreezing:  0.38261204957962036
# Train R^2 after unfreezing:  0.5009875893592834
# Test R^2 after unfreezing:  0.4172888398170471
# Train R^2 after unfreezing and pruning:  0.46941351890563965
# Test R^2 after unfreezing and pruning:  0.3852958083152771
#
# CVFOLD:  3
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Pde1a' 'Gm49948' 'Cbln2' 'Plch2' 'Reln' 'Tac2' 'Enpp2' 'Elmo1' 'Kcnc2'
#  'Gabra1' 'Fxyd6' 'Erbb4' 'Pdyn' 'Galnt14' 'Ndn' 'Thsd7a' 'Calb1' 'Cplx1'
#  'Htr3a' 'Ndst3' 'Lamp5' 'Pvalb' 'Gad1' 'Vip' 'Sst']
# [INFO] training network...
# Train R^2 before unfreezing:  0.5008496642112732
# Test R^2 before unfreezing:  0.426347017288208
# Train R^2 after unfreezing:  0.5233005285263062
# Test R^2 after unfreezing:  0.44646120071411133
# Train R^2 after unfreezing and pruning:  0.4846115708351135
# Test R^2 after unfreezing and pruning:  0.4418221116065979
#
# CVFOLD:  4
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Gabra1' 'Npy' 'Cbln2' 'Kcnc2' 'Tac2' 'Phactr1' 'Gas7' 'Fxyd6' 'Pde1a'
#  'Thsd7a' 'Pdyn' 'Ndst3' 'Pamr1' 'Tafa1' 'Gm49948' 'Cplx1' 'Galnt14' 'Ndn'
#  'Erbb4' 'Lamp5' 'Htr3a' 'Gad1' 'Sst' 'Vip' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4870743155479431
# Test R^2 before unfreezing:  0.390325665473938
# Train R^2 after unfreezing:  0.5049058198928833
# Test R^2 after unfreezing:  0.43411147594451904
# Train R^2 after unfreezing and pruning:  0.473488450050354
# Test R^2 after unfreezing and pruning:  0.4178714156150818
#
# CVFOLD:  5
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Cck' 'Chrnb3' 'Enpp2' 'Lingo2' 'Pde1a' 'Chat' 'Ndst3' 'Phactr1' 'Fxyd6'
#  'Plch2' 'Pdyn' 'Kcnc2' 'Slc6a1' 'Gm49948' 'Galnt14' 'Ndn' 'Cplx1' 'Erbb4'
#  'Lamp5' 'Htr3a' 'Tac2' 'Gad1' 'Sst' 'Vip' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4980517029762268
# Test R^2 before unfreezing:  0.4016329050064087
# Train R^2 after unfreezing:  0.522284746170044
# Test R^2 after unfreezing:  0.426754891872406
# Train R^2 after unfreezing and pruning:  0.4590870141983032
# Test R^2 after unfreezing and pruning:  0.3918052315711975
#
# CVFOLD:  6
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Sparcl1' 'Afap1' 'Cdh13' 'Col24a1' 'Lingo2' 'Tafa1' 'Galnt14' 'Cbln2'
#  'Atp1a3' 'Pdyn' 'Cplx1' 'Enpp2' 'Fxyd6' 'Elmo1' 'Tac2' 'Calb1' 'Ndn'
#  'Ndst3' 'Erbb4' 'Htr3a' 'Gad1' 'Lamp5' 'Pvalb' 'Sst' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4936996102333069
# Test R^2 before unfreezing:  0.3911195993423462
# Train R^2 after unfreezing:  0.5199171602725983
# Test R^2 after unfreezing:  0.4406498074531555
# Train R^2 after unfreezing and pruning:  0.4889776110649109
# Test R^2 after unfreezing and pruning:  0.42985910177230835
#
# CVFOLD:  7
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Pamr1' 'Nell1' 'Atp1a3' 'Fxyd6' 'Thsd7a' 'Cck' 'Enpp2' 'Pdyn' 'Plch2'
#  'Chat' 'Gm49948' 'Cplx1' 'Ndst3' 'Elmo1' 'Htr3a' 'Kcnc2' 'Ndn' 'Erbb4'
#  'Galnt14' 'Tac2' 'Sst' 'Lamp5' 'Gad1' 'Vip' 'Pvalb']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4893275499343872
# Test R^2 before unfreezing:  0.3827494978904724
# Train R^2 after unfreezing:  0.5233786404132843
# Test R^2 after unfreezing:  0.4737047553062439
# Train R^2 after unfreezing and pruning:  0.4766926169395447
# Test R^2 after unfreezing and pruning:  0.47221559286117554
#
# CVFOLD:  8
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Elmo1' 'Syt1' 'Foxred1' 'Calb1' 'Enpp2' 'Kcnc2' 'Pdyn' 'Thsd7a' 'Gabra1'
#  'Fxyd6' 'Erbb4' 'Gabrd' 'Ndst3' 'Tafa1' 'Tac2' 'Cplx1' 'Gm49948' 'Lamp5'
#  'Htr3a' 'Galnt14' 'Ndn' 'Sst' 'Pvalb' 'Gad1' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.4836857318878174
# Test R^2 before unfreezing:  0.35674989223480225
# Train R^2 after unfreezing:  0.5202333629131317
# Test R^2 after unfreezing:  0.4345073103904724
# Train R^2 after unfreezing and pruning:  0.4840177297592163
# Test R^2 after unfreezing and pruning:  0.39411330223083496
#
# CVFOLD:  9
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Gabra1' 'Gm49948' 'Gpc3' 'Kcnc2' 'Pamr1' 'Plch2' 'Scg2' 'Enpp2' 'Reln'
#  'Cbln2' 'Ndst3' 'Galnt14' 'Tac2' 'Cplx1' 'Ndn' 'Fxyd6' 'Calb1' 'Erbb4'
#  'Htr3a' 'Lamp5' 'Pdyn' 'Gad1' 'Sst' 'Pvalb' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.47417908906936646
# Test R^2 before unfreezing:  0.3829360008239746
# Train R^2 after unfreezing:  0.5175437033176422
# Test R^2 after unfreezing:  0.4573664665222168
# Train R^2 after unfreezing and pruning:  0.4641934633255005
# Test R^2 after unfreezing and pruning:  0.40709686279296875
# Time: 0.0h 34m 35s

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_pre_tr_and_freeze_unfreeze_lasso_multiple_nodes.pickle', 'wb') as f:
    pickle.dump([r2_before_unfreezing, r2_before_unfreezing_tr, \
                 r2_after_unfreezing, r2_after_unfreezing_tr, \
                 r2_after_unfreezing_ap, r2_after_unfreezing_ap_tr, \
                 r2_freeze_unfreeze_hist, r2_freeze_unfreeze_hist_tr], f)

# %%
with open('KerasSavedModels/scala_2020/Bottleneck_r2_pre_tr_and_freeze_unfreeze_lasso_multiple_nodes.pickle', 'rb') as f:
    r2_before_unfreezing, r2_before_unfreezing_tr, \
    r2_after_unfreezing, r2_after_unfreezing_tr, \
    r2_after_unfreezing_ap, r2_after_unfreezing_ap_tr, \
    r2_freeze_unfreeze_hist, r2_freeze_unfreeze_hist_tr = pickle.load(f)

# %%
# The learning curves for our favourite model: pre-tr + train last 4 layers only + train all + prune
linewidth = 2

# suppressing "mean of empty slice" warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    n_rank2 = np.nanmean(nonzero_rank2, axis=0)[0, :]
    r_rank2_r = np.nanmean(r2_sRRR_relaxed_rank2, axis=0)[0, :]
    n_rank16 = np.nanmean(nonzero_rank16, axis=0)[0, :]
    r_rank16_r = np.nanmean(r2_sRRR_relaxed_rank16, axis=0)[0, :]

epochs_used = 200
fig = plt.figure(figsize = (16, 4.5))
ax = fig.add_subplot(111)
colours = ['#99d8c9', '#66c2a4', '#41ae76', '#238b45', '#005824']
for u,f in enumerate(range(2,12,2)):
    ax.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist_tr, axis = (1, 2))[u, 0, :], \
             '--', c = colours[u], linewidth=linewidth, label=None)
    ax.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist, axis = (1, 2))[u, 0, :], \
             c = colours[u], linewidth=linewidth, label='{} nodes'.format(f))
ax.hlines(r_rank16_r[np.isclose(n_rank16, 25, atol=3)], xmin = 0, xmax = epochs_used, \
            colors = np.array([0, 0, 0])/256, linewidth=linewidth)
ax.hlines(r_rank2_r[np.isclose(n_rank2, 25, atol=3)], xmin = 0, xmax = epochs_used, \
            colors = np.array([0, 0, 0])/256, linewidth=linewidth)
ax.annotate('RRR, r=16', (180, r_rank16_r[np.isclose(n_rank16, 25, atol=3)]+0.005), fontsize=15)
ax.annotate('RRR, r=2', (180, r_rank2_r[np.isclose(n_rank2, 25, atol=3)]+0.005), fontsize=15)
ax.vlines(x=50, ymin=ax.get_ylim()[0], ymax=ax.get_ylim()[1], linestyles='dashed')
ax.vlines(x=100, ymin=ax.get_ylim()[0], ymax=ax.get_ylim()[1], linestyles='dashed')
ax.set_ylim([0.3, 0.49])
ax.set_xlim([0, 200])
ax.set_title('Training and validation set R^2 scores', fontsize = 19)
ax.set_xlabel('Epoch', fontsize = 17)
ax.set_ylabel('R^2', fontsize = 17)
ax.legend(loc='lower right', ncol=5, fontsize = 15)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.tick_params(axis='both', which='minor', labelsize=15)
sns.despine()

plt.savefig('figures/Lasso_training_curves_different_nodes.pdf', bbox_inches='tight',
    pad_inches=0)
plt.savefig('figures/Lasso_training_curves_different_nodes.png', bbox_inches='tight',
    pad_inches=0)
