# %% [markdown]
# # Cross-validation of models for Gouwens et al.

# %%
# Import packages
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib
import seaborn as sns
import sparseRRR
import matplotlib
import matplotlib.pyplot as plt
import importlib

import bottleneck_networks

import time
import pickle
import warnings

dtype = tf.float32

def sns_styleset():
    sns.set_style('ticks', {'axes.linewidth': .75, "xtick.major.size":4, "ytick.major.size":4})

# %% [markdown]
# # Loading data

# %%
gouwens = pickle.load(open('data/gouwens_2020/gouwens2020.pickle', 'rb'))
genes=gouwens['X']
ephys=gouwens['Y']
gene_names=gouwens['gene_names']
cell_types=gouwens['celltypes']
cell_id_to_cell_type=gouwens['map']
ephys_names=gouwens['ephys_features']
colors=gouwens['colors']

# %% [markdown]
# Let us find K-mean clusters to perform pre-training. One could also pre-train on celltype classification. This has actually improved performance even more but could be argued to be biasing the results too much. K-means allows for an unsupervised more general setting.

# %%
# You can cluster according to amounts of classes or amounts of celltypes. Change the argument of n_clusters accordingly.
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=20, random_state=17, n_init=1000).fit(ephys)

# %%
clusters = kmeans.labels_

# %%
amount_of_cells_in_clusters = {cluster_id: sum(clusters==cluster_id) for cluster_id in np.unique(clusters)}
for_every_cell_number_of_cells_of_their_cluster = np.array([amount_of_cells_in_clusters[cell] for cell in clusters])
ind_pre_training_clusters = for_every_cell_number_of_cells_of_their_cluster >= 10

# %% [markdown]
# # Keras initialisations

# %%
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import metrics
from tensorflow.keras.losses import CategoricalCrossentropy

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
import tensorflow.keras.backend as K

# %%
# You should assume you get two TensorFlow variables as input
y_actual = tf.placeholder(dtype = tf.float32)
y_predicted = tf.placeholder(dtype = tf.float32)
def r2_score(y_truth, y_pred):
    residual = tf.add(y_truth, -y_pred, name='residual')
    return 1-tf.reduce_sum(tf.square(residual)) / tf.reduce_sum(tf.square(y_truth))
r2_score_result = r2_score(y_actual, y_predicted)

# %%
class ElasticNet(tf.keras.regularizers.Regularizer): 
    def __init__(self, l1=1e-8, l2=1.0): 
        self.l1 = l1
        self.l2 = l2

    def __call__(self, x): 
        return self.l2*tf.math.reduce_sum(tf.math.square(x)) + \
                             self.l1*tf.reduce_sum(tf.norm(x, ord = 2, axis = 1))

    def get_config(self): 
        return {'l1': float(self.l1), 'l2': float(self.l2)}

# %% [markdown]
# # Ridge only, test different models w.r.t. reduced-rank-regression

# %% [markdown]
# Running all the following models can take up time (~10minutes). One can also simpy load the trained models in the following section. You can jump right into the group lasso + ridge setting in the next section.

# %% [markdown]
# Our ridge penalty only straight regression (no pre-training) model.

# %%
from bottleneck_networks import StraightRegression

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([0])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs

r2_straight_regr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_straight_regr_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_straight_regr_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
r2_straight_regr_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
MSE_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
MSE_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
train_ephys = []
test_ephys = []
train_ephys_predict = []
test_ephys_predict = []

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]


# CV folds
for cvfold in range(folds):
    print('CVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    train_ephys.append(y_train)
    test_ephys.append(y_test)
    
    input_dim = x_train.shape[1]
    output_dim = y_train.shape[1]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)
            BN_StraightRegression = StraightRegression(l1=l1, l2=l2, lr=lr, act=act, \
                                                       input_dim=input_dim, output_dim=output_dim)
            train_ephys_pred, test_ephys_pred, \
                r2_train, r2_test, train_hist, test_hist, \
                MSE_tr, MSE_test = BN_StraightRegression.train(x_train=x_train, y_train=y_train, \
                                                                                   x_test=x_test, y_test=y_test, \
                                                                                   epochs=epochs, bs=bs, patience=patience, \
                                                                                   cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                                   verbose=0)
            train_ephys_predict.append(train_ephys_pred)
            test_ephys_predict.append(test_ephys_pred)
            r2_straight_regr[cvfold, j, i] = r2_test
            r2_straight_regr_tr[cvfold, j, i] = r2_train
            r2_straight_regr_hist[cvfold, j, i] = test_hist
            r2_straight_regr_hist_tr[cvfold, j, i] = train_hist
            MSE_hist[cvfold, j, i] = MSE_test
            MSE_hist_tr[cvfold, j, i] = MSE_tr
            #print('Test R^2 score (straight regression, no pre-tr): ', r2_straight_regr[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# [INFO] training network...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train R^2:  0.2954866290092468
# Test R^2:  0.27036017179489136
# CVFOLD:  1
# [INFO] training network...
# Train R^2:  0.28641408681869507
# Test R^2:  0.2510087490081787
# CVFOLD:  2
# [INFO] training network...
# Train R^2:  0.2970789074897766
# Test R^2:  0.24351531267166138
# CVFOLD:  3
# [INFO] training network...
# Train R^2:  0.3040401339530945
# Test R^2:  0.2525940537452698
# CVFOLD:  4
# [INFO] training network...
# Train R^2:  0.3052824139595032
# Test R^2:  0.21607059240341187
# CVFOLD:  5
# [INFO] training network...
# Train R^2:  0.295149028301239
# Test R^2:  0.24529969692230225
# CVFOLD:  6
# [INFO] training network...
# Train R^2:  0.3212377429008484
# Test R^2:  0.25705868005752563
# CVFOLD:  7
# [INFO] training network...
# Train R^2:  0.2936553955078125
# Test R^2:  0.24811094999313354
# CVFOLD:  8
# [INFO] training network...
# Train R^2:  0.2940882444381714
# Test R^2:  0.2331230640411377
# CVFOLD:  9
# [INFO] training network...
# Train R^2:  0.30586951971054077
# Test R^2:  0.23276221752166748
# Time: 0.0h  4m 48s

# %%
# First visualisation of the data.
fig, axes = plt.subplots(2, folds, figsize=(2*folds, 4))
for i in range(folds):
    axes[0, i].scatter(train_ephys[i], train_ephys_predict[i], s=2)
    axes[0, i].annotate('r2={:.4f}'.format(r2_straight_regr_tr[i, 0, 0]), \
                    xy=(0.5*axes[0, i].get_xlim()[1], 0.8*axes[0, i].get_ylim()[1]))
    axes[0, i].set_title('fold: {}'.format(i))
    axes[1, i].scatter(test_ephys[i], test_ephys_predict[i], s=2)
    axes[1, i].annotate('r2={:.4f}'.format(r2_straight_regr[i, 0, 0]), \
                    xy=(0.5*axes[1, i].get_xlim()[1], 0.8*axes[1, i].get_ylim()[1]))
axes[0, 1].set_xlabel('true ephys, training')
axes[0, 0].set_ylabel('predicted ephys, training')
axes[1, 1].set_xlabel('true ephys, test')
axes[1, 0].set_ylabel('predicted ephys, test')
fig.suptitle('# epochs={}'.format(epochs), fontsize=15, y=1.05)
plt.tight_layout()

# %%
fig, axes = plt.subplots(2, folds, figsize=(2*folds, 4))
for i in range(folds):
    axes[0, i].hist((train_ephys[i]-train_ephys_predict[i])[:, 0]**2, bins=30, alpha=0.5, zorder=1, label='MSE')
    axes[0, i].hist(train_ephys[i][:, 0]**2, bins=30, zorder=0, label='denominator')
    axes[0, i].annotate('r2: {:.4f}'.format(r2_straight_regr_tr[i, 0, 0]), \
                        xy=(0.6*axes[0, i].get_xlim()[1], 0.8*axes[0, i].get_ylim()[1]))
    axes[0, i].set_title('fold: {}'.format(i))
    axes[1, i].hist((test_ephys[i]-test_ephys_predict[i])[:, 0]**2, bins=30, alpha=0.5, zorder=1, label='MSE')
    axes[1, i].hist(test_ephys[i][:, 0]**2, bins=30, zorder=0, label='denominator')
    axes[1, i].annotate('r2={:.4f}'.format(r2_straight_regr[i, 0, 0]), \
                        xy=(0.6*axes[1, i].get_xlim()[1], 0.8*axes[1, i].get_ylim()[1]))
fig.suptitle('# epochs={}'.format(epochs), fontsize=15, y=1.05)
axes[0, 2].legend(loc='right')
axes[0, 1].set_xlabel('MSE terms, train')
axes[1, 1].set_xlabel('MSE terms, test')
plt.tight_layout()

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_straight_regr.pickle', 'wb') as f:
    pickle.dump([r2_straight_regr, r2_straight_regr_tr, \
                 r2_straight_regr_hist, r2_straight_regr_hist_tr], f)

# %% [markdown]
# Our ridge penalty only classification pre-training model.

# %%
from bottleneck_networks import ClassificationPreTrain

# %%
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([0])

act='elu'
folds=10
seed=42
lr=0.0001
epochs=50
bs=32
patience=epochs


t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]
clusters_ = clusters[ind]
ind_pre_train = ind_pre_training_clusters[ind]

CE_loss = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
CE_loss_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
pre_tr_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
pre_tr_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    clusters_train = np.copy(clusters_[indtrain])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    clusters_test = np.copy(clusters_[indtest])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean

    # In our training set we now look for a 'pretraining' training and test data set that we can use
    # for pretraing a classification network, i.e. picking the best model will be done with a seperate val set in our
    # training set for regression.

    x_train_pre_tr = x_train[ind_pre_train[indtrain], :]
    clusters_train_pre_tr = clusters_train[ind_pre_train[indtrain]]
    
    pre_train_size = 0.6
    train_cnt = round(x_train_pre_tr.shape[0]*pre_train_size)
    x_train_pre_tr_ = x_train_pre_tr[:train_cnt, :]
    x_test_pre_tr_ = x_train_pre_tr[train_cnt:, :]
    clusters_train_pre_tr_ = clusters_train_pre_tr[:train_cnt]
    clusters_test_pre_tr_ = clusters_train_pre_tr[train_cnt:]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)


            input_dim = x_train.shape[1]
            output_dim = to_categorical(clusters_train_pre_tr).shape[1]
            BN_Classification = ClassificationPreTrain(l1=l1, l2=l2, lr=lr, act=act, input_dim=input_dim, \
                                                       output_dim=output_dim)
            CE_train, CE_test, train_hist, test_hist = BN_Classification.train(x_train=x_train_pre_tr_, \
                                                                               cluster_train=clusters_train_pre_tr_, \
                                                                               x_test=x_test_pre_tr_, \
                                                                               cluster_test=clusters_test_pre_tr_, \
                                                                               epochs=epochs, bs=bs, patience=patience, \
                                                                               cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                               verbose=0)
            CE_loss[cvfold, j, i] = CE_test
            CE_loss_tr[cvfold, j, i] = CE_train
            pre_tr_hist[cvfold, j, i] = test_hist
            pre_tr_hist_tr[cvfold, j, i] = train_hist
            #print('Test CE loss (pre-trainin): ', CE_loss[cvfold, j, i])
            
t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# 1834/1834 [==============================] - 0s 120us/sample - loss: 1.6439 - categorical_crossentropy: 1.6439
# 1222/1222 [==============================] - 0s 84us/sample - loss: 1.8845 - categorical_crossentropy: 1.8845
#
# CVFOLD:  1
# [INFO] training network...
# 1834/1834 [==============================] - 0s 125us/sample - loss: 1.5247 - categorical_crossentropy: 1.5247
# 1222/1222 [==============================] - 0s 71us/sample - loss: 1.8587 - categorical_crossentropy: 1.8587
#
# CVFOLD:  2
# [INFO] training network...
# 1834/1834 [==============================] - 0s 124us/sample - loss: 1.5730 - categorical_crossentropy: 1.5730
# 1222/1222 [==============================] - 0s 79us/sample - loss: 1.9062 - categorical_crossentropy: 1.9062
#
# CVFOLD:  3
# [INFO] training network...
# 1834/1834 [==============================] - 0s 132us/sample - loss: 1.6460 - categorical_crossentropy: 1.6460
# 1222/1222 [==============================] - 0s 80us/sample - loss: 1.8693 - categorical_crossentropy: 1.8693
#
# CVFOLD:  4
# [INFO] training network...
# 1834/1834 [==============================] - 0s 133us/sample - loss: 1.5967 - categorical_crossentropy: 1.5967
# 1222/1222 [==============================] - 0s 78us/sample - loss: 1.9046 - categorical_crossentropy: 1.9046
#
# CVFOLD:  5
# [INFO] training network...
# 1834/1834 [==============================] - 0s 121us/sample - loss: 1.4822 - categorical_crossentropy: 1.4822
# 1222/1222 [==============================] - 0s 70us/sample - loss: 1.9914 - categorical_crossentropy: 1.9914
#
# CVFOLD:  6
# [INFO] training network...
# 1834/1834 [==============================] - 0s 128us/sample - loss: 1.4598 - categorical_crossentropy: 1.4598
# 1222/1222 [==============================] - 0s 85us/sample - loss: 1.8214 - categorical_crossentropy: 1.8214
#
# CVFOLD:  7
# [INFO] training network...
# 1834/1834 [==============================] - 0s 122us/sample - loss: 1.5118 - categorical_crossentropy: 1.5118
# 1222/1222 [==============================] - 0s 93us/sample - loss: 1.8811 - categorical_crossentropy: 1.8811
#
# CVFOLD:  8
# [INFO] training network...
# 1834/1834 [==============================] - 0s 125us/sample - loss: 1.5209 - categorical_crossentropy: 1.5209
# 1222/1222 [==============================] - 0s 92us/sample - loss: 1.8591 - categorical_crossentropy: 1.8591
#
# CVFOLD:  9
# [INFO] training network...
# 1834/1834 [==============================] - 0s 126us/sample - loss: 1.5458 - categorical_crossentropy: 1.5458
# 1222/1222 [==============================] - 0s 81us/sample - loss: 1.9500 - categorical_crossentropy: 1.9500
# Time: 0.0h  3m 52s

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_pre_tr.pickle', 'wb') as f:
    pickle.dump([CE_loss, CE_loss_tr, pre_tr_hist, pre_tr_hist_tr], f)

# %% [markdown]
# Our ridge penalty only pre-train and regression model.

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([0])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs
pre_trained_weights=True

r2_pretr_straight_regr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_pretr_straight_regr_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_pretr_straight_regr_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
r2_pretr_straight_regr_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    input_dim = x_train.shape[1]
    output_dim = y_train.shape[1]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)
            
            pre_trained_weights_h5 = 'KerasSavedModels/Classification_weights_{}_{}_{}.h5'.format(cvfold, j, i)
            
            BN_PreTrStraightRegression = StraightRegression(l1=l1, l2=l2, lr=lr, act=act, \
                                            input_dim=input_dim, output_dim=output_dim, \
                                            pre_trained_weights=pre_trained_weights, \
                                            pre_trained_weights_h5=pre_trained_weights_h5)
            _, _, r2_train, r2_test, train_hist, test_hist, _, _ = BN_PreTrStraightRegression.train(x_train=x_train, y_train=y_train, \
                                                                                   x_test=x_test, y_test=y_test, \
                                                                                   epochs=epochs, bs=bs, patience=patience, \
                                                                                   cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                                   verbose=0)
            r2_pretr_straight_regr[cvfold, j, i] = r2_test
            r2_pretr_straight_regr_tr[cvfold, j, i] = r2_train
            r2_pretr_straight_regr_hist[cvfold, j, i] = test_hist
            r2_pretr_straight_regr_hist_tr[cvfold, j, i] = train_hist
            #print('Test R^2 score (regression, after pre-tr): ', r2_pretr_straight_regr[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# Train R^2:  0.29537564516067505
# Test R^2:  0.2737046480178833
#
# CVFOLD:  1
# [INFO] training network...
# Train R^2:  0.31493324041366577
# Test R^2:  0.25129204988479614
#
# CVFOLD:  2
# [INFO] training network...
# Train R^2:  0.29706627130508423
# Test R^2:  0.2468230128288269
#
# CVFOLD:  3
# [INFO] training network...
# Train R^2:  0.29729336500167847
# Test R^2:  0.25333869457244873
#
# CVFOLD:  4
# [INFO] training network...
# Train R^2:  0.31884485483169556
# Test R^2:  0.2313109040260315
#
# CVFOLD:  5
# [INFO] training network...
# Train R^2:  0.2908056378364563
# Test R^2:  0.230515718460083
#
# CVFOLD:  6
# [INFO] training network...
# Train R^2:  0.29499512910842896
# Test R^2:  0.25751954317092896
#
# CVFOLD:  7
# [INFO] training network...
# Train R^2:  0.3257659077644348
# Test R^2:  0.2561138868331909
#
# CVFOLD:  8
# [INFO] training network...
# Train R^2:  0.28797173500061035
# Test R^2:  0.23909300565719604
#
# CVFOLD:  9
# [INFO] training network...
# Train R^2:  0.3132207989692688
# Test R^2:  0.22675371170043945
# Time: 0.0h  5m  4s

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_straight_regr.pickle', 'wb') as f:
    pickle.dump([r2_pretr_straight_regr, r2_pretr_straight_regr_tr, \
                 r2_pretr_straight_regr_hist, r2_pretr_straight_regr_hist_tr], f)

# %% [markdown]
# Our ridge penalty only pre-train + freeze the first 2 layers + unfreeze model.

# %%
from bottleneck_networks import FreezeUnfreeze

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([0])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs
pre_trained_weights=True
unfreeze = [False, False, True, True, True, True] # last 4 layers can be trained only first


r2_before_unfreezing = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_before_unfreezing_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_freeze_unfreeze_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 2*epochs))
r2_freeze_unfreeze_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 2*epochs))

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    input_dim = x_train.shape[1]
    output_dim = y_train.shape[1]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)
            
            pre_trained_weights_h5 = 'KerasSavedModels/Classification_weights_{}_{}_{}.h5'.format(cvfold, j, i)
            input_dim = x_train.shape[1]
            output_dim = y_train.shape[1]
            BN_PreTrFreezeUnfreeze = FreezeUnfreeze(l1=l1, l2=l2, lr=lr, act=act, input_dim=input_dim, output_dim=output_dim, \
                                                       unfreeze = unfreeze, \
                                                       pre_trained_weights=pre_trained_weights, \
                                                       pre_trained_weights_h5=pre_trained_weights_h5)
            r2_before_unfreezing_train, r2_before_unfreezing_test, \
                r2_after_unfreezing_train, r2_after_unfreezing_test, \
                train_hist, test_hist = BN_PreTrFreezeUnfreeze.train(x_train=x_train, y_train=y_train, \
                                                                    x_test=x_test, y_test=y_test, \
                                                                    epochs=epochs, bs=bs, patience=patience, \
                                                                    cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                    verbose=0)
            r2_before_unfreezing[cvfold, j, i] = r2_before_unfreezing_test
            r2_before_unfreezing_tr[cvfold, j, i] = r2_before_unfreezing_train
            r2_after_unfreezing[cvfold, j, i] = r2_after_unfreezing_test
            r2_after_unfreezing_tr[cvfold, j, i] = r2_after_unfreezing_train
            r2_freeze_unfreeze_hist[cvfold, j, i] = test_hist
            r2_freeze_unfreeze_hist_tr[cvfold, j, i] = train_hist
            #print('Test R^2 score (before unfreezing): ', r2_before_unfreezing[cvfold, j, i])
            #print('Test R^2 score (after unfreezing): ', r2_after_unfreezing[cvfold, j, i])
            
t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.27260851860046387
# Test R^2 before unfreezing:  0.2804098129272461
# Train R^2 after unfreezing:  0.3173149824142456
# Test R^2 after unfreezing:  0.2950966954231262
#
# CVFOLD:  1
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.2796868681907654
# Test R^2 before unfreezing:  0.2676529288291931
# Train R^2 after unfreezing:  0.32301580905914307
# Test R^2 after unfreezing:  0.2811216711997986
#
# CVFOLD:  2
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.2679446339607239
# Test R^2 before unfreezing:  0.24846845865249634
# Train R^2 after unfreezing:  0.3045540452003479
# Test R^2 after unfreezing:  0.2655577063560486
#
# CVFOLD:  3
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.27461379766464233
# Test R^2 before unfreezing:  0.2593858242034912
# Train R^2 after unfreezing:  0.32986927032470703
# Test R^2 after unfreezing:  0.277896523475647
#
# CVFOLD:  4
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.27987754344940186
# Test R^2 before unfreezing:  0.23059815168380737
# Train R^2 after unfreezing:  0.3230865001678467
# Test R^2 after unfreezing:  0.24211657047271729
#
# CVFOLD:  5
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.28339678049087524
# Test R^2 before unfreezing:  0.2600988745689392
# Train R^2 after unfreezing:  0.31800758838653564
# Test R^2 after unfreezing:  0.2698099613189697
#
# CVFOLD:  6
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.2814623713493347
# Test R^2 before unfreezing:  0.2670801281929016
# Train R^2 after unfreezing:  0.3181353807449341
# Test R^2 after unfreezing:  0.2779046297073364
#
# CVFOLD:  7
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.27725738286972046
# Test R^2 before unfreezing:  0.26004552841186523
# Train R^2 after unfreezing:  0.3412167429924011
# Test R^2 after unfreezing:  0.27555710077285767
#
# CVFOLD:  8
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.2852581739425659
# Test R^2 before unfreezing:  0.25845593214035034
# Train R^2 after unfreezing:  0.3208134174346924
# Test R^2 after unfreezing:  0.26856619119644165
#
# CVFOLD:  9
# [INFO] training network...
# [INFO] training network...
# Train R^2 before unfreezing:  0.2775236964225769
# Test R^2 before unfreezing:  0.2524474859237671
# Train R^2 after unfreezing:  0.34204667806625366
# Test R^2 after unfreezing:  0.2641356587409973
# Time: 0.0h  8m 45s

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_freeze_unfreeze.pickle', 'wb') as f:
    pickle.dump([r2_before_unfreezing, r2_before_unfreezing_tr, \
                 r2_after_unfreezing, r2_after_unfreezing_tr, \
                 r2_freeze_unfreeze_hist, r2_freeze_unfreeze_hist_tr], f)

# %% [markdown]
# In the next section we perform reduced-rank regression cross validation (rank = 2 and full rank).

# %%
# CV sRRR rank = 2

lambdas = np.concatenate([np.arange(.1,2,.1), np.arange(2,8)])
alphas = np.array([0])

rank = 2
folds = 10
seed = 42

r2_sRRR_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_rank2_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank2_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
nonzero_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
corrs_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))
corrs_relaxed_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))

# Uncomment if one lambda only
train_ephys = []
test_ephys = []
train_ephys_predict = []
test_ephys_predict = []

t = time.time()

np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    x_train = x_train.astype('float64')
    y_train = y_train.astype('float64')
    x_test = x_test.astype('float64')
    y_test = y_test.astype('float64')
    
    train_ephys.append(y_train)
    test_ephys.append(y_test)
    for i,a in enumerate(lambdas):
        #print('Lambdau: ', a)
        for j, b in enumerate(alphas):
            #print('Alpha: ', b)
            vx,vy = sparseRRR.elastic_rrr(x_train, y_train, lambdau=a, alpha=b, rank=rank, sparsity='row-wise')

            nz = np.sum(np.abs(vx), axis=1) != 0
            if np.sum(nz) < rank:
                nonzero_rank2[cvfold, j, i] = np.nan
                continue

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank2[cvfold, j, i] = np.nan
                continue

            nonzero_rank2[cvfold, j, i] = np.sum(nz)
            r2_sRRR_rank2[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum((y_test-np.mean(y_test))**2)
            r2_sRRR_rank2_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum((y_train-np.mean(y_train, axis=0))**2)
            for r in range(rank):
                corrs_rank2[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]

            # Relaxation
            vx[nz,:],vy = sparseRRR.elastic_rrr(x_train[:,nz], y_train, lambdau=a, alpha=0, rank=rank, sparsity='row-wise')

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank2[cvfold, j, i] = np.nan
                continue

            r2_sRRR_relaxed_rank2[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum((y_test-np.mean(y_test))**2)
            r2_sRRR_relaxed_rank2_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum((y_train-np.mean(y_train, axis=0))**2)
            for r in range(rank):
                corrs_relaxed_rank2[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]
            
            train_ephys_predict.append(x_train@vx@vy.T)
            test_ephys_predict.append(x_test@vx@vy.T)
            #print(r2_sRRR_relaxed_rank2[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
#
# CVFOLD:  1
#
# CVFOLD:  2
#
# CVFOLD:  3
#
# CVFOLD:  4
#
# CVFOLD:  5
#
# CVFOLD:  6
#
# CVFOLD:  7
#
# CVFOLD:  8
#
# CVFOLD:  9
# Time: 0.0h 10m 56s

# %%
with open('KerasSavedModels/gouwens_2020/sRRR_vs_Bottleneck_rank2_CV.pickle', 'wb') as f:
    pickle.dump([r2_sRRR_rank2, r2_sRRR_relaxed_rank2, r2_sRRR_rank2_tr, r2_sRRR_relaxed_rank2_tr, \
                nonzero_rank2, corrs_rank2, corrs_relaxed_rank2], f)

# %%
# CV sRRR rank=16

lambdas = np.concatenate([np.arange(.1,2,.1), np.arange(2,8)])
alphas = np.array([0])

rank = 16
folds = 10
seed = 42

r2_sRRR_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_rank16_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank16_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
nonzero_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
corrs_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))
corrs_relaxed_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))


t = time.time()

np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    x_train = x_train.astype('float64')
    y_train = y_train.astype('float64')
    x_test = x_test.astype('float64')
    y_test = y_test.astype('float64')
    
    for i,a in enumerate(lambdas):
        #print('Labmdau: ', a)
        for j, b in enumerate(alphas):
            #print('Alpha: ', b)
            vx,vy = sparseRRR.elastic_rrr(x_train, y_train, lambdau=a, alpha=b, rank=rank, sparsity='row-wise')

            nz = np.sum(np.abs(vx), axis=1) != 0
            if np.sum(nz) < rank:
                nonzero_rank16[cvfold, j, i] = np.nan
                continue

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank16[cvfold, j, i] = np.nan
                continue

            nonzero_rank16[cvfold, j, i] = np.sum(nz)
            r2_sRRR_rank16[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum((y_test-np.mean(y_test))**2)
            r2_sRRR_rank16_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum((y_train-np.mean(y_train, axis=0))**2)
            for r in range(rank):
                corrs_rank16[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]

            # Relaxation
            vx[nz,:],vy = sparseRRR.elastic_rrr(x_train[:,nz], y_train, lambdau=a, alpha=0, rank=rank, sparsity='row-wise')

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank16[cvfold, j, i] = np.nan
                continue

            r2_sRRR_relaxed_rank16[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum((y_test-np.mean(y_test))**2)
            r2_sRRR_relaxed_rank16_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum((y_train-np.mean(y_train, axis=0))**2)
            for r in range(rank):
                corrs_relaxed_rank16[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]
            #print(r2_sRRR_relaxed_rank16_tr[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
#
# CVFOLD:  1
#
# CVFOLD:  2
#
# CVFOLD:  3
#
# CVFOLD:  4
#
# CVFOLD:  5
#
# CVFOLD:  6
#
# CVFOLD:  7
#
# CVFOLD:  8
#
# CVFOLD:  9
# Time: 0.0h 10m 55s

# %%
with open('KerasSavedModels/gouwens_2020/sRRR_vs_Bottleneck_rank16_CV.pickle', 'wb') as f:
    pickle.dump([r2_sRRR_rank16, r2_sRRR_relaxed_rank16, r2_sRRR_rank16_tr, r2_sRRR_relaxed_rank16_tr, \
                nonzero_rank16, corrs_rank16, corrs_relaxed_rank16], f)

# %% [markdown]
# We now have cross validated results for all the ridge penalty models we care about. Let us now analyse and compare the training curves.

# %%
lambdas = np.concatenate([np.arange(.1,2,.1), np.arange(2,10)])

# %%
with open('KerasSavedModels/gouwens_2020/sRRR_vs_Bottleneck_rank2_CV.pickle', 'rb') as f:
    r2_sRRR_rank2, r2_sRRR_relaxed_rank2, r2_sRRR_rank2_tr, r2_sRRR_relaxed_rank2_tr, \
                nonzero_rank2, corrs_rank2, corrs_relaxed_rank2 = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/sRRR_vs_Bottleneck_rank16_CV.pickle', 'rb') as f:
    r2_sRRR_rank16, r2_sRRR_relaxed_rank16, r2_sRRR_rank16_tr, r2_sRRR_relaxed_rank16_tr, \
                nonzero_rank16, corrs_rank16, corrs_relaxed_rank16 = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_pre_tr.pickle', 'rb') as f:
    CE_loss, CE_loss_tr, pre_tr_hist, pre_tr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_straight_regr.pickle', 'rb') as f:
    r2_straight_regr, r2_straight_regr_tr, \
                 r2_straight_regr_hist, r2_straight_regr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_straight_regr.pickle', 'rb') as f:
    r2_pretr_straight_regr, r2_pretr_straight_regr_tr, \
                 r2_pretr_straight_regr_hist, r2_pretr_straight_regr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_freeze_unfreeze.pickle', 'rb') as f:
    r2_before_unfreezing, r2_before_unfreezing_tr, \
                 r2_after_unfreezing, r2_after_unfreezing_tr, \
                 r2_freeze_unfreeze_hist, r2_freeze_unfreeze_hist_tr = pickle.load(f)

# %%
np.max(np.mean(r2_sRRR_relaxed_rank2, axis=0))
# Out:
# 0.20557825748452796

# %%
np.max(np.mean(r2_sRRR_relaxed_rank16, axis=0))
# Out:
# 0.3283334237414588

# %%
np.mean(r2_straight_regr)
# Out:
# 0.24499034881591797

# %%
np.mean(r2_pretr_straight_regr)
# Out:
# 0.2466465175151825

# %%
np.mean(r2_before_unfreezing)
# Out:
# 0.25846431255340574

# %%
np.mean(r2_after_unfreezing)
# Out:
# 0.27177627086639405

# %%
linewidth = 2
sns_styleset()

r2_sRRR_relaxed_rank2[r2_sRRR_relaxed_rank2==0]=np.nan
r2_sRRR_relaxed_rank2_ =  np.nanmean(r2_sRRR_relaxed_rank2, axis = 0)
r2_sRRR_relaxed_rank16[r2_sRRR_relaxed_rank16==0]=np.nan
r2_sRRR_relaxed_rank16_ =  np.nanmean(r2_sRRR_relaxed_rank16, axis = 0)


# All together in one plot for the paper
fig = plt.figure(figsize=(19, 4.5))
widths = [1, 1, 2]
heights = [1]
spec = fig.add_gridspec(ncols=3, nrows=1, width_ratios=widths,
                          height_ratios=heights)
ax1 = fig.add_subplot(spec[0, 0])
ax1.plot(lambdas[np.nonzero(r2_sRRR_relaxed_rank16_[0, :])], \
             r2_sRRR_relaxed_rank16_[0, :][np.nonzero(r2_sRRR_relaxed_rank16_[0, :])], '.-', \
             c = np.array([0, 0, 0]) / 256, linewidth = linewidth, \
             label = 'r=16')
ax1.plot(lambdas[np.nonzero(r2_sRRR_relaxed_rank2_[0, :])], \
             r2_sRRR_relaxed_rank2_[0, :][np.nonzero(r2_sRRR_relaxed_rank2_[0, :])], '.-', \
             c = np.array([0, 0, 0])/256, linewidth = linewidth, \
             label = 'r=2')
ax1.annotate('RRR, r=16', (5, np.max(r2_sRRR_relaxed_rank16_)+0.0002), fontsize=15)
ax1.annotate('RRR, r=2', (5, np.max(r2_sRRR_relaxed_rank2_)+0.0002), fontsize=15)
ax1.set_xlabel(r'Ridge regularization parameter $\lambda$', fontsize = 17)
ax1.set_ylabel(r'Cross validated test $R^2$', fontsize = 17)
ax1.set_title('Reduced-rank regression', fontsize = 19, y=1.02)
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.tick_params(axis='both', which='minor', labelsize=15)
ax1.set_ylim([0.1,0.7])

ax2 = fig.add_subplot(spec[0, 1])
ax2.plot(range(50), np.mean(pre_tr_hist_tr, axis=(0, 1, 2)), \
         '--', c = 'k', linewidth=linewidth)
ax2.plot(range(50), np.mean(pre_tr_hist, axis=(0, 1, 2)), \
         c = 'k', linewidth=linewidth)
ax2.set_title('Pretraining', fontsize = 19, y=1.02)
ax2.set_xlabel('Epoch', fontsize = 17)
ax2.set_ylabel('Cross entropy loss', fontsize = 17)
ax2.tick_params(axis='both', which='major', labelsize=15)
ax2.tick_params(axis='both', which='minor', labelsize=15)
ax2.set_ylim([0, ax2.get_ylim()[1]])
ax2.annotate('Training', (40, 0.22), fontsize=15)
ax2.annotate('Test', (40, 6.3), fontsize=15)
ax2.set_xticks(np.arange(0, 60, 10))

ax3 = fig.add_subplot(spec[0, 2])
ax3.plot(range(100), np.mean(r2_freeze_unfreeze_hist_tr, axis=(0, 1, 2)), \
         '--', c = '#1b9e77', linewidth=linewidth)
ax3.plot(range(100), np.mean(r2_freeze_unfreeze_hist, axis=(0, 1, 2)), \
         c = '#1b9e77', linewidth=linewidth, label='Pre-training + freezing + unfreezing')
ax3.plot(range(50), np.mean(r2_pretr_straight_regr_hist_tr, axis=(0, 1, 2)), \
         '--', c = '#d95f02', linewidth=linewidth)
ax3.plot(range(50), np.mean(r2_pretr_straight_regr_hist, axis=(0, 1, 2)), \
         c = '#d95f02', linewidth=linewidth, label='Pre-training + no freezing')
ax3.plot(range(50), np.mean(r2_straight_regr_hist_tr, axis=(0, 1, 2)), \
         '--', c = '#7570b3', linewidth=linewidth)
ax3.plot(range(50), np.mean(r2_straight_regr_hist, axis=(0, 1, 2)), \
         c = '#7570b3', linewidth=linewidth, label='No pre-training')
ax3.hlines(np.max(r2_sRRR_relaxed_rank2_), xmin = 0, xmax = 120, \
            colors = np.array([0,0,0])/256)
ax3.annotate('RRR, r=2', (85, np.max(r2_sRRR_relaxed_rank2_)+0.005), fontsize=15)
ax3.hlines(np.max(r2_sRRR_relaxed_rank16_), xmin = 0, xmax = 120, \
           colors = np.array([0,0,0])/256)
ax3.annotate('RRR, r=16', (85, np.max(r2_sRRR_relaxed_rank16_)+0.005), fontsize=15)
ax3.legend(loc = 'upper right', fontsize=15)
ax3.set_ylim([0.1,0.7])
ax3.set_xlim([0,100])
ax3.set_title('Bottleneck neural network', fontsize = 19, y=1.02)
ax3.set_xlabel('Epoch', fontsize = 17)
ax3.set_ylabel(r'$R^2$', fontsize = 17)
ax3.tick_params(axis='both', which='major', labelsize=15)
ax3.tick_params(axis='both', which='minor', labelsize=15)
ax3.set_xticks(np.arange(0, 110, 10))
ax3.vlines(50, ymin=0, ymax=ax3.get_ylim()[1], linestyle='dashed')

plt.text(-0.22, 1.04, 'a', transform = ax1.transAxes, fontsize=25, fontweight='bold')
plt.text(-0.16, 1.04, 'b', transform = ax2.transAxes, fontsize=25, fontweight='bold')
plt.text(-0.12, 1.04, 'c', transform = ax3.transAxes, fontsize=25, fontweight='bold')
sns.despine()
plt.savefig('figures/Allen_Ridge_training_curves.pdf', bbox_inches = 'tight',
    pad_inches = 0)
plt.savefig('figures/Allen_Ridge_training_curves.png', bbox_inches = 'tight',
    pad_inches = 0)

# %% [markdown]
# # Add lasso

# %% [markdown]
# It seems that pre-train - train 4 last layers - train all layers is a good bottleneck non-linear model. Let us add a lasso group penalty now and investigate which genes the model would select. After the usual training as above we also prune the bottleneck further. In essence we pick the 25 genes that correspond to highest L2 row norm for the first kernel/weight of the input layer and perform the same regression task but with this reduced new 25 nodes input layer. No lasso, just ridge for this pruned network. We investigate which genes are selected, visualise the latent space and compare to a well-known sparse reduced-rank model for this dataset. Again, one can skip the training and go direct to visualization for already trained models.

# %% [markdown]
# Our ridge + lasso penalty straight regression (no pre-training) model.

# %%
from bottleneck_networks import StraightRegression

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([1e-1])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
prune=True
patience=epochs

r2_straight_regr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_straight_regr_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_straight_regr_ap = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_straight_regr_ap_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_straight_regr_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))
r2_straight_regr_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

nodes_list=[512,128,2,128,512]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    input_dim = x_train.shape[1]
    output_dim = y_train.shape[1]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)
            BN_StraightRegression = StraightRegression(l1=l1, l2=l2, lr=lr, act=act, \
                                                       input_dim=input_dim, output_dim=output_dim, nodes_list=nodes_list)
            r2_train, r2_test, \
                r2_ap_train, r2_ap_test, \
                train_hist, test_hist = BN_StraightRegression.train(x_train=x_train, y_train=y_train, \
                                                                                   x_test=x_test, y_test=y_test, \
                                                                                   epochs=epochs, bs=bs, patience=patience, \
                                                                                   cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                                   prune=prune, geneNames=gene_names, \
                                                                                   verbose=0)
            r2_straight_regr[cvfold, j, i] = r2_test
            r2_straight_regr_tr[cvfold, j, i] = r2_train
            r2_straight_regr_ap[cvfold, j, i] = r2_ap_test
            r2_straight_regr_ap_tr[cvfold, j, i] = r2_ap_train
            r2_straight_regr_hist[cvfold, j, i] = test_hist
            r2_straight_regr_hist_tr[cvfold, j, i] = train_hist
            #print('Test R^2 score (straight regression, no pre-tr): ', r2_straight_regr[cvfold, j, i])
            #print('Test R^2 score after pruning (straight regression, no pre-tr): ', r2_straight_regr_ap[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# [INFO] training network...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# The 25 genes that make it:  ['Ptchd2' 'Cacna1e' 'Sema3a' 'Cdh12' 'Kctd8' 'Igf1' 'Gabrb2' 'Cplx3'
#  'Kcnc2' 'Kcns3' 'Pou3f3' 'Pde11a' 'Kit' 'Nell1' 'Runx2' 'Grm1' 'Crtac1'
#  'Pvalb' 'Cacna2d3' 'Alcam' 'Trhde' 'Vip' 'Lamp5' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.2560656666755676
# Test R^2 after pruning:  0.27255910634994507
# Train R^2 after pruning:  0.2618006467819214
# Test R^2 after pruning:  0.2735479474067688
#
# CVFOLD:  1
# [INFO] training network...
# The 25 genes that make it:  ['Cacna2d1' 'Grm7' 'Gabrb2' 'Kcnd3' 'Pcp4l1' 'Alcam' 'Trhde' 'Gpr126'
#  'Cacna1e' 'Pde11a' 'Runx2' 'Chodl' 'Man1a' 'Akr1c18' 'Gabrd' 'Grm1'
#  'Igf1' 'Lamp5' 'Cplx3' 'Kcnc2' 'Vip' 'Pvalb' 'Cacna2d3' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.2542896270751953
# Test R^2 after pruning:  0.251853883266449
# Train R^2 after pruning:  0.25698208808898926
# Test R^2 after pruning:  0.25102663040161133
#
# CVFOLD:  2
# [INFO] training network...
# The 25 genes that make it:  ['Alcam' 'March1' 'Sema5a' 'Crispld1' 'Kcnab3' 'Galnt14' 'Chodl' 'Akr1c18'
#  'Sema3c' 'Gabrb2' 'Pde11a' 'Lamp5' 'Grm1' 'Igf1' 'Grm7' 'Kit' 'Runx2'
#  'Cplx3' 'Pvalb' 'Kcnc2' 'Vip' 'Trhde' 'Cacna2d3' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.2542523145675659
# Test R^2 after pruning:  0.25463002920150757
# Train R^2 after pruning:  0.26382094621658325
# Test R^2 after pruning:  0.2633558511734009
#
# CVFOLD:  3
# [INFO] training network...
# The 25 genes that make it:  ['Alcam' 'Grm1' 'Igsf11' 'Ovol2' 'Gpr125' 'Slit2' 'Dlx1' 'Cacna1e' 'Fstl4'
#  'Syt2' 'Sema3c' 'Grm7' 'Lamp5' 'Metrnl' 'Cpne5' 'Trhde' 'Runx2' 'Pde11a'
#  'Igf1' 'Kcnc2' 'Pvalb' 'Vip' 'Cacna2d3' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.24918252229690552
# Test R^2 after pruning:  0.2491675615310669
# Train R^2 after pruning:  0.2542017102241516
# Test R^2 after pruning:  0.24648112058639526
#
# CVFOLD:  4
# [INFO] training network...
# The 25 genes that make it:  ['Kit' 'Shisa6' 'Gabrd' 'Lamp5' 'Alcam' 'Sema3a' 'Trhde' 'Nell1' 'Runx2'
#  'Igf1' 'Cplx3' 'Crtac1' 'Cacna2d1' 'Kcns3' 'Chodl' 'Kctd8' 'Grm7'
#  'Pde11a' 'Vip' 'Kcnc2' 'Pvalb' 'Grm1' 'Cacna2d3' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.2570449113845825
# Test R^2 after pruning:  0.22272861003875732
# Train R^2 after pruning:  0.2662426829338074
# Test R^2 after pruning:  0.22599643468856812
#
# CVFOLD:  5
# [INFO] training network...
# The 25 genes that make it:  ['Kctd8' 'Cacna1e' 'Coro6' 'Pcdh7' 'Kcns3' 'Igf1' 'Grm7' 'Crtac1' 'Gabrb2'
#  'Kit' 'Nell1' 'Cplx3' 'Lamp5' 'Crispld1' 'Kcnc2' 'Runx2' 'Trhde'
#  'Cacna2d3' 'Alcam' 'Grm1' 'Pvalb' 'Vip' 'Pde11a' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.2535949945449829
# Test R^2 after pruning:  0.2532225251197815
# Train R^2 after pruning:  0.25939589738845825
# Test R^2 after pruning:  0.2525532841682434
#
# CVFOLD:  6
# [INFO] training network...
# The 25 genes that make it:  ['Dab1' 'Zfp536' 'Slc6a1' 'Slc35g2' 'Man1a' 'Sox5' 'Cacna1e' 'Kcnab3'
#  'Sema3c' 'Plxna2' 'Cplx3' 'Kit' 'Trhde' 'Chodl' 'Nell1' 'Grm1' 'Igf1'
#  'Pvalb' 'Pde11a' 'Lamp5' 'Cacna2d3' 'Kcnc2' 'Vip' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.2539042830467224
# Test R^2 after pruning:  0.25123029947280884
# Train R^2 after pruning:  0.2585674524307251
# Test R^2 after pruning:  0.25020933151245117
#
# CVFOLD:  7
# [INFO] training network...
# The 25 genes that make it:  ['Pcdh18' 'Cacna2d1' 'Scube1' 'Galnt14' 'Grm7' 'Gpr139' 'Tcf4' 'Kit'
#  'Cplx3' 'Crtac1' 'Kcns3' 'Igf1' 'Alcam' 'Vip' 'Grm1' 'Lamp5' 'Chodl'
#  'Trhde' 'Pde11a' 'Kcnc2' 'Kctd8' 'Pvalb' 'Cacna2d3' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.25350838899612427
# Test R^2 after pruning:  0.2455531358718872
# Train R^2 after pruning:  0.25602781772613525
# Test R^2 after pruning:  0.2449420690536499
#
# CVFOLD:  8
# [INFO] training network...
# The 25 genes that make it:  ['Rasgrf1' 'Sox5' 'Flt3' 'Ppapdc1a' 'Sema3c' 'March1' 'Nell1' 'Sema3a'
#  'Igf1' 'Crtac1' 'Grm7' 'Chodl' 'Lamp5' 'Zfp536' 'Ptchd2' 'Cplx3' 'Pvalb'
#  'Grm1' 'Runx2' 'Cacna2d3' 'Kcnc2' 'Vip' 'Trhde' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.2565310597419739
# Test R^2 after pruning:  0.24784785509109497
# Train R^2 after pruning:  0.26448380947113037
# Test R^2 after pruning:  0.24891966581344604
#
# CVFOLD:  9
# [INFO] training network...
# The 25 genes that make it:  ['Trpc6' 'Adamtsl5' 'Pradc1' 'Grm7' 'Galnt14' 'Zfp536' 'Npy' 'Cacna2d3'
#  'Il1rap' 'Akr1c18' 'Kcnd3' 'Ppapdc1a' 'Kcnc2' 'Nefh' 'Cplx3' 'Lamp5'
#  'Fxyd6' 'Grm1' 'Slit2' 'Alk' 'Cntn4' 'Igf1' 'Pvalb' 'Synpr' 'Vip']
# [INFO] training network...
# Train R^2 before pruning:  0.240683913230896
# Test R^2 after pruning:  0.2212257981300354
# Train R^2 after pruning:  0.2503367066383362
# Test R^2 after pruning:  0.23225319385528564
# Time: 0.0h 16m 23s

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_straight_regr_lasso.pickle', 'wb') as f:
    pickle.dump([r2_straight_regr, r2_straight_regr_tr, \
                 r2_straight_regr_ap, r2_straight_regr_ap_tr, \
                 r2_straight_regr_hist, r2_straight_regr_hist_tr], f)

# %% [markdown]
# Our ridge + lasso penalty classification pre-training model.

# %%
from bottleneck_networks import ClassificationPreTrain

# %%
# Immediately for different penalties, but we'll be only interested in the 1e-1 penalty (for now), i.e. see extensions later
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([1e-4, 1e-2, 1e-1, 1])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs


t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]
clusters_ = clusters[ind]
ind_pre_train = ind_pre_training_clusters[ind]

CE_loss = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
CE_loss_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
pre_tr_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))
pre_tr_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], epochs))

nodes_list=[512,128,2,128,512]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    clusters_train = np.copy(clusters_[indtrain])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    clusters_test = np.copy(clusters_[indtest])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean

    # In our training set we now look for a 'pretraining' training and test data set that we can use
    # for pretraing a classification network, i.e. picking the best model will be dones with a seperate val set in our
    # training set for regression.

    x_train_pre_tr = x_train[ind_pre_train[indtrain], :]
    clusters_train_pre_tr = clusters_train[ind_pre_train[indtrain]]
    
    pre_train_size = 0.6
    train_cnt = round(x_train_pre_tr.shape[0]*pre_train_size)
    x_train_pre_tr_ = x_train_pre_tr[:train_cnt, :]
    x_test_pre_tr_ = x_train_pre_tr[train_cnt:, :]
    clusters_train_pre_tr_ = clusters_train_pre_tr[:train_cnt]
    clusters_test_pre_tr_ = clusters_train_pre_tr[train_cnt:]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)


            input_dim = x_train.shape[1]
            output_dim = to_categorical(clusters_train_pre_tr).shape[1]
            BN_Classification = ClassificationPreTrain(l1=l1, l2=l2, lr=lr, act=act, input_dim=input_dim, \
                                                       output_dim=output_dim, nodes_list=nodes_list)
            CE_train, CE_test, train_hist, test_hist = BN_Classification.train(x_train=x_train_pre_tr_, \
                                                                               cluster_train=clusters_train_pre_tr_, \
                                                                               x_test=x_test_pre_tr_, \
                                                                               cluster_test=clusters_test_pre_tr_, \
                                                                               epochs=epochs, bs=bs, patience=patience, \
                                                                               cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                               verbose=0)
            CE_loss[cvfold, j, i] = CE_test
            CE_loss_tr[cvfold, j, i] = CE_train
            pre_tr_hist[cvfold, j, i] = test_hist
            pre_tr_hist_tr[cvfold, j, i] = train_hist
            #print('Test CE loss (pre-trainin): ', CE_loss[cvfold, j, i])
            
t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# 1834/1834 [==============================] - 0s 119us/sample - loss: 1.7066 - categorical_crossentropy: 1.6113
# 1222/1222 [==============================] - 0s 83us/sample - loss: 1.9842 - categorical_crossentropy: 1.8889
# [INFO] training network...
# 1834/1834 [==============================] - 0s 144us/sample - loss: 8.4206 - categorical_crossentropy: 1.5968
# 1222/1222 [==============================] - 0s 85us/sample - loss: 8.8041 - categorical_crossentropy: 1.9803
# [INFO] training network...
# 1834/1834 [==============================] - 0s 152us/sample - loss: 2.1675 - categorical_crossentropy: 1.6940
# 1222/1222 [==============================] - 0s 86us/sample - loss: 2.2992 - categorical_crossentropy: 1.8258
# [INFO] training network...
# 1834/1834 [==============================] - 0s 122us/sample - loss: 3.2690 - categorical_crossentropy: 1.9237
# 1222/1222 [==============================] - 0s 79us/sample - loss: 3.3331 - categorical_crossentropy: 1.9877
#
# CVFOLD:  1
# [INFO] training network...
# 1834/1834 [==============================] - 0s 129us/sample - loss: 1.6733 - categorical_crossentropy: 1.5779
# 1222/1222 [==============================] - 0s 96us/sample - loss: 1.9468 - categorical_crossentropy: 1.8515
# [INFO] training network...
# 1834/1834 [==============================] - 0s 148us/sample - loss: 8.8900 - categorical_crossentropy: 1.6266
# 1222/1222 [==============================] - 0s 101us/sample - loss: 9.1735 - categorical_crossentropy: 1.9100
# [INFO] training network...
# 1834/1834 [==============================] - 0s 128us/sample - loss: 2.1183 - categorical_crossentropy: 1.6918
# 1222/1222 [==============================] - 0s 86us/sample - loss: 2.2885 - categorical_crossentropy: 1.8619
# [INFO] training network...
# 1834/1834 [==============================] - 0s 125us/sample - loss: 134.4400 - categorical_crossentropy: 1.8369
# 1222/1222 [==============================] - 0s 104us/sample - loss: 134.5122 - categorical_crossentropy: 1.9091
#
# CVFOLD:  2
# [INFO] training network...
# 1834/1834 [==============================] - 0s 117us/sample - loss: 1.6730 - categorical_crossentropy: 1.5776
# 1222/1222 [==============================] - 0s 74us/sample - loss: 1.9853 - categorical_crossentropy: 1.8899
# [INFO] training network...
# 1834/1834 [==============================] - 0s 119us/sample - loss: 8.8436 - categorical_crossentropy: 1.5947
# 1222/1222 [==============================] - 0s 82us/sample - loss: 9.1166 - categorical_crossentropy: 1.8677
# [INFO] training network...
# 1834/1834 [==============================] - 0s 117us/sample - loss: 2.0946 - categorical_crossentropy: 1.6207
# 1222/1222 [==============================] - 0s 72us/sample - loss: 2.3201 - categorical_crossentropy: 1.8463
# [INFO] training network...
# 1834/1834 [==============================] - 0s 132us/sample - loss: 3.2645 - categorical_crossentropy: 1.9087
# 1222/1222 [==============================] - 0s 90us/sample - loss: 3.3420 - categorical_crossentropy: 1.9862
#
# CVFOLD:  3
# [INFO] training network...
# 1834/1834 [==============================] - 0s 146us/sample - loss: 1.6471 - categorical_crossentropy: 1.5516
# 1222/1222 [==============================] - 0s 97us/sample - loss: 1.9687 - categorical_crossentropy: 1.8732
# [INFO] training network...
# 1834/1834 [==============================] - 0s 122us/sample - loss: 9.0677 - categorical_crossentropy: 1.6940
# 1222/1222 [==============================] - 0s 82us/sample - loss: 9.4941 - categorical_crossentropy: 2.1203
# [INFO] training network...
# 1834/1834 [==============================] - 0s 153us/sample - loss: 2.1169 - categorical_crossentropy: 1.6752
# 1222/1222 [==============================] - 0s 84us/sample - loss: 2.2922 - categorical_crossentropy: 1.8506
# [INFO] training network...
# 1834/1834 [==============================] - 0s 116us/sample - loss: 134.6659 - categorical_crossentropy: 1.8530
# 1222/1222 [==============================] - 0s 79us/sample - loss: 134.7477 - categorical_crossentropy: 1.9348
#
# CVFOLD:  4
# [INFO] training network...
# 1834/1834 [==============================] - 0s 129us/sample - loss: 1.6820 - categorical_crossentropy: 1.5865
# 1222/1222 [==============================] - 0s 88us/sample - loss: 1.9804 - categorical_crossentropy: 1.8849
# [INFO] training network...
# 1834/1834 [==============================] - 0s 123us/sample - loss: 8.9517 - categorical_crossentropy: 1.6528
# 1222/1222 [==============================] - 0s 94us/sample - loss: 9.2620 - categorical_crossentropy: 1.9631
# [INFO] training network...
# 1834/1834 [==============================] - 0s 139us/sample - loss: 2.1079 - categorical_crossentropy: 1.6036
# 1222/1222 [==============================] - 0s 95us/sample - loss: 2.3160 - categorical_crossentropy: 1.8117
# [INFO] training network...
# 1834/1834 [==============================] - 0s 117us/sample - loss: 231.0486 - categorical_crossentropy: 1.7905
# 1222/1222 [==============================] - 0s 80us/sample - loss: 231.1579 - categorical_crossentropy: 1.8999
#
# CVFOLD:  5
# [INFO] training network...
# 1834/1834 [==============================] - 0s 128us/sample - loss: 1.6382 - categorical_crossentropy: 1.5428
# 1222/1222 [==============================] - 0s 84us/sample - loss: 1.9533 - categorical_crossentropy: 1.8580
# [INFO] training network...
# 1834/1834 [==============================] - 0s 142us/sample - loss: 8.7295 - categorical_crossentropy: 1.6185
# 1222/1222 [==============================] - 0s 84us/sample - loss: 8.9993 - categorical_crossentropy: 1.8883
# [INFO] training network...
# 1834/1834 [==============================] - 0s 140us/sample - loss: 2.0996 - categorical_crossentropy: 1.6640
# 1222/1222 [==============================] - 0s 101us/sample - loss: 2.2837 - categorical_crossentropy: 1.8481
# [INFO] training network...
# 1834/1834 [==============================] - 0s 144us/sample - loss: 3.2548 - categorical_crossentropy: 1.8424
# 1222/1222 [==============================] - 0s 82us/sample - loss: 3.3214 - categorical_crossentropy: 1.9089
#
# CVFOLD:  6
# [INFO] training network...
# 1834/1834 [==============================] - 0s 122us/sample - loss: 1.6452 - categorical_crossentropy: 1.5499
# 1222/1222 [==============================] - 0s 82us/sample - loss: 1.9659 - categorical_crossentropy: 1.8705
# [INFO] training network...
# 1834/1834 [==============================] - 0s 116us/sample - loss: 9.4384 - categorical_crossentropy: 1.7223
# 1222/1222 [==============================] - 0s 83us/sample - loss: 9.6475 - categorical_crossentropy: 1.9314
# [INFO] training network...
# 1834/1834 [==============================] - 0s 128us/sample - loss: 2.1056 - categorical_crossentropy: 1.6562
# 1222/1222 [==============================] - 0s 88us/sample - loss: 2.2846 - categorical_crossentropy: 1.8352
# [INFO] training network...
# 1834/1834 [==============================] - 0s 122us/sample - loss: 231.9232 - categorical_crossentropy: 1.8932
# 1222/1222 [==============================] - 0s 84us/sample - loss: 231.9829 - categorical_crossentropy: 1.9529
#
# CVFOLD:  7
# [INFO] training network...
# 1834/1834 [==============================] - 0s 121us/sample - loss: 1.5796 - categorical_crossentropy: 1.4841
# 1222/1222 [==============================] - 0s 77us/sample - loss: 2.0075 - categorical_crossentropy: 1.9120
# [INFO] training network...
# 1834/1834 [==============================] - 0s 119us/sample - loss: 8.2443 - categorical_crossentropy: 1.5392
# 1222/1222 [==============================] - 0s 80us/sample - loss: 8.6204 - categorical_crossentropy: 1.9152
# [INFO] training network...
# 1834/1834 [==============================] - 0s 150us/sample - loss: 2.0799 - categorical_crossentropy: 1.6435
# 1222/1222 [==============================] - 0s 97us/sample - loss: 2.2361 - categorical_crossentropy: 1.7996
# [INFO] training network...
# 1834/1834 [==============================] - 0s 121us/sample - loss: 3.1712 - categorical_crossentropy: 1.8663
# 1222/1222 [==============================] - 0s 79us/sample - loss: 3.2171 - categorical_crossentropy: 1.9122
#
# CVFOLD:  8
# [INFO] training network...
# 1834/1834 [==============================] - 0s 151us/sample - loss: 1.6360 - categorical_crossentropy: 1.5406
# 1222/1222 [==============================] - 0s 103us/sample - loss: 2.0734 - categorical_crossentropy: 1.9780
# [INFO] training network...
# 1834/1834 [==============================] - 0s 112us/sample - loss: 8.0358 - categorical_crossentropy: 1.5532
# 1222/1222 [==============================] - 0s 74us/sample - loss: 8.4214 - categorical_crossentropy: 1.9388
# [INFO] training network...
# 1834/1834 [==============================] - 0s 116us/sample - loss: 2.0665 - categorical_crossentropy: 1.6434
# 1222/1222 [==============================] - 0s 71us/sample - loss: 2.2666 - categorical_crossentropy: 1.8436
# [INFO] training network...
# 1834/1834 [==============================] - 0s 148us/sample - loss: 134.2481 - categorical_crossentropy: 1.8124
# 1222/1222 [==============================] - 0s 87us/sample - loss: 134.3612 - categorical_crossentropy: 1.9255
#
# CVFOLD:  9
# [INFO] training network...
# 1834/1834 [==============================] - 0s 122us/sample - loss: 1.5651 - categorical_crossentropy: 1.4697
# 1222/1222 [==============================] - 0s 76us/sample - loss: 1.9781 - categorical_crossentropy: 1.8827
# [INFO] training network...
# 1834/1834 [==============================] - 0s 120us/sample - loss: 8.1348 - categorical_crossentropy: 1.4802
# 1222/1222 [==============================] - 0s 80us/sample - loss: 8.5282 - categorical_crossentropy: 1.8736
# [INFO] training network...
# 1834/1834 [==============================] - 0s 135us/sample - loss: 2.1167 - categorical_crossentropy: 1.6413
# 1222/1222 [==============================] - 0s 92us/sample - loss: 2.3708 - categorical_crossentropy: 1.8953
# [INFO] training network...
# 1834/1834 [==============================] - 0s 136us/sample - loss: 3.3391 - categorical_crossentropy: 1.9286
# 1222/1222 [==============================] - 0s 91us/sample - loss: 3.4355 - categorical_crossentropy: 2.0250
# Time: 0.0h 15m 30s

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_pre_tr_lasso.pickle', 'wb') as f:
    pickle.dump([CE_loss, CE_loss_tr, pre_tr_hist, pre_tr_hist_tr], f)

# %% [markdown]
# Our lasso + ridge penalty pre-train and regression model.

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([1e-1])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs
pre_trained_weights=True
prune=True

r2_pretr_straight_regr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_pretr_straight_regr_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_pretr_straight_regr_ap = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_pretr_straight_regr_ap_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_pretr_straight_regr_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))
r2_pretr_straight_regr_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

nodes_list=[512,128,2,128,512]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    input_dim = x_train.shape[1]
    output_dim = y_train.shape[1]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)
            
            pre_trained_weights_h5 = 'KerasSavedModels/Classification_last_weights_{}_{}_{}.h5'.format(cvfold, 2, i)
            
            BN_PreTrStraightRegression = StraightRegression(l1=l1, l2=l2, lr=lr, act=act, \
                                            input_dim=input_dim, output_dim=output_dim, \
                                            pre_trained_weights=pre_trained_weights, \
                                            pre_trained_weights_h5=pre_trained_weights_h5, nodes_list=nodes_list)
            r2_train, r2_test, \
                r2_train_ap, r2_test_ap, \
                train_hist, test_hist = BN_PreTrStraightRegression.train(x_train=x_train, y_train=y_train, \
                                                                                   x_test=x_test, y_test=y_test, \
                                                                                   epochs=epochs, bs=bs, patience=patience, \
                                                                                   cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                                   prune=prune, geneNames=gene_names, \
                                                                                   verbose=0)
            r2_pretr_straight_regr[cvfold, j, i] = r2_test
            r2_pretr_straight_regr_tr[cvfold, j, i] = r2_train
            r2_pretr_straight_regr_ap[cvfold, j, i] = r2_test_ap
            r2_pretr_straight_regr_ap_tr[cvfold, j, i] = r2_train_ap            
            r2_pretr_straight_regr_hist[cvfold, j, i] = test_hist
            r2_pretr_straight_regr_hist_tr[cvfold, j, i] = train_hist
            #print('Test R^2 score (regression, after pre-tr): ', r2_pretr_straight_regr[cvfold, j, i])
            #print('Test R^2 score (regression, after pre-tr), after pruning: ', r2_pretr_straight_regr_ap[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# The 25 genes that make it:  ['Ptchd2' 'Cacna1e' 'Grm1' 'Grm7' 'Kctd8' 'Cplx3' 'Crtac1' 'Pou3f3'
#  'Kcns3' 'Nell1' 'Gabrb2' 'March1' 'Pde11a' 'Runx2' 'Kcnc2' 'Cacna2d3'
#  'Lamp5' 'Pvalb' 'Sema3a' 'Alcam' 'Trhde' 'Kit' 'Vip' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.2644490599632263
# Test R^2 after pruning:  0.2820713520050049
# Train R^2 after pruning:  0.2651769518852234
# Test R^2 after pruning:  0.27562224864959717
#
# CVFOLD:  1
# [INFO] training network...
# The 25 genes that make it:  ['Rgs9' 'Nell1' 'Nxph1' 'Grm7' 'Runx2' 'Cplx3' 'Grm1' 'Trhde' 'Gabrd'
#  'Man1a' 'Igf1' 'Hpse' 'Col11a1' 'Egfem1' 'Akr1c18' 'Lamp5' 'Penk' 'Kcnc2'
#  'Ptpru' 'Pvalb' 'Cacna2d3' 'Pdyn' 'Fxyd6' 'Vip' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.26310980319976807
# Test R^2 after pruning:  0.26241666078567505
# Train R^2 after pruning:  0.2657850980758667
# Test R^2 after pruning:  0.25901782512664795
#
# CVFOLD:  2
# [INFO] training network...
# The 25 genes that make it:  ['Crtac1' 'Kcnc1' 'March1' 'Zfp536' 'Kcnab3' 'Galnt14' 'Penk' 'Akr1c18'
#  'Sema3c' 'Pde11a' 'Gabrb2' 'Chodl' 'Kit' 'Grm1' 'Kcnc2' 'Runx2' 'Cplx3'
#  'Grm7' 'Igf1' 'Pvalb' 'Trhde' 'Vip' 'Cacna2d3' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.25736725330352783
# Test R^2 after pruning:  0.2567426562309265
# Train R^2 after pruning:  0.26746588945388794
# Test R^2 after pruning:  0.26624614000320435
#
# CVFOLD:  3
# [INFO] training network...
# The 25 genes that make it:  ['A830018L16Rik' 'March1' 'Kctd8' 'Nkain3' 'Tmem132d' 'Dlx1' 'Runx2'
#  'Alcam' 'Lamp5' 'Cplx3' 'Igf1' 'Sema3c' 'Zmat4' 'Metrnl' 'Sema3a' 'Pvalb'
#  'Kit' 'Grm7' 'Kcnc2' 'Pde11a' 'Trhde' 'Vip' 'Cacna2d3' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.26174360513687134
# Test R^2 after pruning:  0.25976747274398804
# Train R^2 after pruning:  0.2681177854537964
# Test R^2 after pruning:  0.258889377117157
#
# CVFOLD:  4
# [INFO] training network...
# The 25 genes that make it:  ['Cbln2' 'Cplx3' 'Pdyn' 'Akr1c18' 'Nefh' 'Hpse' 'Ptprt' 'Cdh7' 'Lamp5'
#  'Kcnh7' 'Slit2' 'Galntl6' 'Ppapdc1a' 'Ano4' 'Igf1' 'Grm1' 'Cntn4'
#  'Cacna2d3' 'Egfem1' 'Penk' 'Fxyd6' 'Adra1a' 'Pvalb' 'Synpr' 'Vip']
# [INFO] training network...
# Train R^2 before pruning:  0.25105148553848267
# Test R^2 after pruning:  0.22266852855682373
# Train R^2 after pruning:  0.2703315019607544
# Test R^2 after pruning:  0.23437613248825073
#
# CVFOLD:  5
# [INFO] training network...
# The 25 genes that make it:  ['Npy' 'March1' 'Gabrb2' 'Nell1' 'Crtac1' 'Igf1' 'Lamp5' 'Kcnc2' 'Kctd8'
#  'Grm7' 'Tmem132d' 'Pcdh7' 'Cplx3' 'Runx2' 'Crispld1' 'Kit' 'Pvalb' 'Grm1'
#  'Trhde' 'Alcam' 'Cacna2d3' 'Pde11a' 'Vip' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.2582215666770935
# Test R^2 after pruning:  0.2571258544921875
# Train R^2 after pruning:  0.26419663429260254
# Test R^2 after pruning:  0.2584940791130066
#
# CVFOLD:  6
# [INFO] training network...
# The 25 genes that make it:  ['Hpse' 'Kctd8' 'Sema3c' 'Slc35g2' 'Kcnab3' 'Gpr139' 'Nell1' 'Zmat4'
#  'Cplx3' 'Dab1' 'Tmem132d' 'Sema3a' 'Chodl' 'Igf1' 'Grm7' 'Lamp5' 'March1'
#  'Pde11a' 'Trhde' 'Kcnc2' 'Kit' 'Cacna2d3' 'Vip' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.26035892963409424
# Test R^2 after pruning:  0.2603731155395508
# Train R^2 after pruning:  0.26513952016830444
# Test R^2 after pruning:  0.2594572901725769
#
# CVFOLD:  7
# [INFO] training network...
# The 25 genes that make it:  ['Pcdh18' 'Alcam' 'Nell1' 'Sema3c' 'Kit' 'Cplx3' 'Grm7' 'Penk' 'Crtac1'
#  'Fstl4' 'Kctd8' 'Kcns3' 'Necab1' 'Lamp5' 'Igf1' 'Grm1' 'Vip' 'Trhde'
#  'Kcnc2' 'Chodl' 'Pvalb' 'Pde11a' 'Cacna2d3' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.25610578060150146
# Test R^2 after pruning:  0.24901193380355835
# Train R^2 after pruning:  0.2601875066757202
# Test R^2 after pruning:  0.25019216537475586
#
# CVFOLD:  8
# [INFO] training network...
# The 25 genes that make it:  ['Tmem132d' 'Flt3' 'Ppapdc1a' 'Nell1' 'Zfp536' 'Sema3c' 'Crtac1' 'Kit'
#  'Chodl' 'Sema3a' 'Lamp5' 'Igf1' 'March1' 'Pvalb' 'Grm1' 'Grm7' 'Ptchd2'
#  'Cplx3' 'Runx2' 'Cacna2d3' 'Kcnc2' 'Vip' 'Trhde' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before pruning:  0.25911980867385864
# Test R^2 after pruning:  0.2501930594444275
# Train R^2 after pruning:  0.2673819065093994
# Test R^2 after pruning:  0.25411635637283325
#
# CVFOLD:  9
# [INFO] training network...
# The 25 genes that make it:  ['Cntn4' 'Cd7' 'Grm7' 'Trhde' 'Cnr1' 'Nefh' 'Col11a1' 'Slit2' 'Akr1c18'
#  'Egfem1' 'Nxph1' 'Cacna2d3' 'Cpne7' 'Igf1' 'Grm1' 'Lamp5' 'Kcnc2' 'Pvalb'
#  'Hpse' 'Fxyd6' 'Ptpru' 'Pdyn' 'Penk' 'Synpr' 'Vip']
# [INFO] training network...
# Train R^2 before pruning:  0.26240313053131104
# Test R^2 after pruning:  0.23814493417739868
# Train R^2 after pruning:  0.2651558518409729
# Test R^2 after pruning:  0.24721848964691162
# Time: 0.0h 16m 19s

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_straight_regr_lasso.pickle', 'wb') as f:
    pickle.dump([r2_pretr_straight_regr, r2_pretr_straight_regr_tr, \
                 r2_pretr_straight_regr_ap, r2_pretr_straight_regr_ap_tr, \
                 r2_pretr_straight_regr_hist, r2_pretr_straight_regr_hist_tr], f)

# %% [markdown]
# Our lasso + ridge penalty pre-train + freeze the first 2 layers + unfreeze model.

# %%
from bottleneck_networks import FreezeUnfreeze

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([1e-4, 1e-2, 1e-1, 1])

act = 'elu'
folds = 10
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs
pre_trained_weights=True
unfreeze = [False, False, True, True, True, True] # last 4 layers can be trained only first
prune=True

r2_before_unfreezing = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_before_unfreezing_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_ap = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_ap_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_freeze_unfreeze_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))
r2_freeze_unfreeze_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

nodes_list=[512,128,2,128,512]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    input_dim = x_train.shape[1]
    output_dim = y_train.shape[1]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)
            
            pre_trained_weights_h5 = 'KerasSavedModels/Classification_last_weights_{}_{}_{}.h5'.format(cvfold, j, i)
            input_dim = x_train.shape[1]
            output_dim = y_train.shape[1]
            BN_PreTrFreezeUnfreeze = FreezeUnfreeze(l1=l1, l2=l2, lr=lr, act=act, input_dim=input_dim, output_dim=output_dim, \
                                                       unfreeze = unfreeze, \
                                                       pre_trained_weights=pre_trained_weights, \
                                                       pre_trained_weights_h5=pre_trained_weights_h5, nodes_list=nodes_list)
            r2_before_unfreezing_train, r2_before_unfreezing_test, \
                r2_after_unfreezing_train, r2_after_unfreezing_test, \
                r2_after_unfreezing_train_ap, r2_after_unfreezing_test_ap, \
                train_hist, test_hist = BN_PreTrFreezeUnfreeze.train(x_train=x_train, y_train=y_train, \
                                                                    x_test=x_test, y_test=y_test, \
                                                                    epochs=epochs, bs=bs, patience=patience, \
                                                                    cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                    prune=prune, geneNames=gene_names, \
                                                                    verbose=0)
            r2_before_unfreezing[cvfold, j, i] = r2_before_unfreezing_test
            r2_before_unfreezing_tr[cvfold, j, i] = r2_before_unfreezing_train
            r2_after_unfreezing[cvfold, j, i] = r2_after_unfreezing_test
            r2_after_unfreezing_tr[cvfold, j, i] = r2_after_unfreezing_train
            r2_after_unfreezing_ap[cvfold, j, i] = r2_after_unfreezing_test_ap
            r2_after_unfreezing_ap_tr[cvfold, j, i] = r2_after_unfreezing_train_ap
            r2_freeze_unfreeze_hist[cvfold, j, i] = test_hist
            r2_freeze_unfreeze_hist_tr[cvfold, j, i] = train_hist
            #print('Test R^2 score (before unfreezing): ', r2_before_unfreezing[cvfold, j, i])
            #print('Test R^2 score (after unfreezing): ', r2_after_unfreezing[cvfold, j, i])
            #print('Test R^2 score (after unfreezing and after pruning): ', r2_after_unfreezing_ap[cvfold, j, i])
            
t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Camk1d' 'Slc10a4' 'Pde7b' 'Map3k5' 'Tmem215' 'Cpne5' 'Lppr3' 'Nefh'
#  'Crhbp' 'Grik3' 'Drd1' 'Ryr3' 'Cd164l2' 'C630043F03Rik' 'Kctd12' 'Timp2'
#  'Myh3' 'Rtn4rl2' 'Stard5' 'Ndst3' 'Adamtsl5' 'Myh7' '1700019D03Rik'
#  'Zdbf2' 'Mybpc1']
# [INFO] training network...
# Train R^2 before unfreezing:  0.29499518871307373
# Test R^2 before unfreezing:  0.2221301794052124
# Train R^2 after unfreezing:  0.3252711296081543
# Test R^2 after unfreezing:  0.23813188076019287
# Train R^2 after unfreezing and pruning:  0.19486892223358154
# Test R^2 after unfreezing and pruning:  0.18908566236495972
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Fam135b' 'Cnr1' 'Cntnap5a' '5730522E02Rik' 'Prkcg' 'Nrsn2' 'Crhbp'
#  'Rgs6' 'Igf1' 'Cacna1e' 'Adarb2' 'Ndst4' 'Cplx3' 'Pde11a' 'Lrp1b'
#  'Lingo2' 'Pvalb' 'Cpne7' 'Pdyn' 'Lamp5' 'Sst' 'Erbb4' 'Mybpc1' 'Vip'
#  'Chodl']
# [INFO] training network...
# Train R^2 before unfreezing:  0.26302534341812134
# Test R^2 before unfreezing:  0.2109779715538025
# Train R^2 after unfreezing:  0.2907748222351074
# Test R^2 after unfreezing:  0.2874528169631958
# Train R^2 after unfreezing and pruning:  0.2731732130050659
# Test R^2 after unfreezing and pruning:  0.2881487011909485
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Galnt14' 'Kcnab1' 'Cacna2d1' 'Cacna2d3' 'Pcp4l1' 'Lrp1b' 'Ptpru' 'Kcns3'
#  'Crtac1' 'Grm1' 'Akr1c18' 'Slit2' 'Runx2' 'Trhde' 'Chrm2' 'Hpse' 'Egfem1'
#  'Pvalb' 'Nell1' 'Kcnc2' 'Lamp5' 'Pdyn' 'Fxyd6' 'Vip' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2530288100242615
# Test R^2 before unfreezing:  0.26838940382003784
# Train R^2 after unfreezing:  0.26363807916641235
# Test R^2 after unfreezing:  0.27920418977737427
# Train R^2 after unfreezing and pruning:  0.27090251445770264
# Test R^2 after unfreezing and pruning:  0.2864167094230652
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Zfp467' 'Sox5' 'Uchl1' 'Meis2' 'Cpne5' 'Cacna1e' 'Csgalnact1' 'Kcnc2'
#  'Miat' 'Gng4' 'Pxdn' 'Mitf' 'Kcns3' 'Nefh' 'Hapln4' 'Grm1' 'Casz1'
#  'Camk1' 'Rtn4rl2' 'Pvalb' 'Ptger3' 'Crtac1' 'Grm7' 'Lman1l' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2139512300491333
# Test R^2 before unfreezing:  0.2326897382736206
# Train R^2 after unfreezing:  0.22149044275283813
# Test R^2 after unfreezing:  0.24149638414382935
# Train R^2 after unfreezing and pruning:  0.23615074157714844
# Test R^2 after unfreezing and pruning:  0.24580609798431396
#
# CVFOLD:  1
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Dlk2' 'Vwc2' 'E530001K10Rik' 'Agbl4' 'Ypel1' 'Baiap2l2' 'Adam11'
#  'Gpr125' 'Cd164l2' 'Grp' 'Adcyap1' 'Slc17a7' 'Lamp5' '2900026A02Rik'
#  'Fgf10' 'Steap2' 'St6gal2' 'Cartpt' 'Tmem132d' 'Shd' 'Fmo1' 'Hspa2'
#  'Nwd2' 'Mybpc1' 'LOC102632463']
# [INFO] training network...
# Train R^2 before unfreezing:  0.26661646366119385
# Test R^2 before unfreezing:  0.19092810153961182
# Train R^2 after unfreezing:  0.3392465114593506
# Test R^2 after unfreezing:  0.19836151599884033
# Train R^2 after unfreezing and pruning:  0.20128560066223145
# Test R^2 after unfreezing and pruning:  0.19011199474334717
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Stxbp2' 'Fam135b' 'Ntrk3' 'Akr1c18' 'Galntl6' 'Sema5a' 'Sst' 'Tox'
#  'Crhbp' 'Nkain3' 'Cacna1e' 'Lamp5' 'Chrm2' 'Kctd8' 'Pde11a' 'Igf1' 'Npy'
#  'Caln1' 'Hpse' 'Cplx3' 'Erbb4' 'Pvalb' 'Mybpc1' 'Pdyn' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.26148998737335205
# Test R^2 before unfreezing:  0.2253282070159912
# Train R^2 after unfreezing:  0.2866940498352051
# Test R^2 after unfreezing:  0.28366565704345703
# Train R^2 after unfreezing and pruning:  0.28009361028671265
# Test R^2 after unfreezing and pruning:  0.27798348665237427
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Ptchd2' 'A830018L16Rik' 'Tmem178' 'Kcnc2' 'Kcns3' 'Wnt7a' 'Kit'
#  'Cacna2d1' 'Chodl' 'Nell1' 'Grm1' 'Runx2' 'Igf1' 'Tmem44' 'Zmat4' 'Lamp5'
#  'Pvalb' 'Vip' 'Sema3a' 'Cplx3' 'Grm7' 'Trhde' 'Cacna2d3' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2555781602859497
# Test R^2 before unfreezing:  0.2540780305862427
# Train R^2 after unfreezing:  0.26141929626464844
# Test R^2 after unfreezing:  0.2602747082710266
# Train R^2 after unfreezing and pruning:  0.26505666971206665
# Test R^2 after unfreezing and pruning:  0.2594422698020935
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Thy1' 'Cplx3' 'Sv2b' 'Egr4' 'Pde11a' 'Grm1' 'Hapln4' 'Galnt14' 'Kcns3'
#  'Lynx1' 'Kcnab3' 'Shisa6' 'Ngb' 'Dclk3' 'Cpne9' 'Runx2' 'Grm7' 'Pvalb'
#  'Zfp536' 'Lamp5' 'Atp6ap1l' 'Fxyd6' 'Tnnt1' 'Cacna2d3' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.23487645387649536
# Test R^2 before unfreezing:  0.23065274953842163
# Train R^2 after unfreezing:  0.23039793968200684
# Test R^2 after unfreezing:  0.23115527629852295
# Train R^2 after unfreezing and pruning:  0.24557846784591675
# Test R^2 after unfreezing and pruning:  0.23891359567642212
#
# CVFOLD:  2
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Myh14' 'Lman1l' '1700019D03Rik' 'Slc35f4' 'LOC105244192' 'Mrap2'
#  'Igsf21' 'Mybpc1' 'Glcci1' 'Syt2' 'A930029G22Rik' 'Grik1' 'Bhlhe40'
#  'Lamp5' 'Mn1' 'Gadd45a' 'Pip5k1b' 'Elfn1' 'Lmo7' 'Crhbp' 'Slc17a8'
#  'Sertad1' 'Ptgs2' 'Pacsin3' 'Ptpn3']
# [INFO] training network...
# Train R^2 before unfreezing:  0.27143990993499756
# Test R^2 before unfreezing:  0.18733340501785278
# Train R^2 after unfreezing:  0.34571343660354614
# Test R^2 after unfreezing:  0.20286816358566284
# Train R^2 after unfreezing and pruning:  0.22316056489944458
# Test R^2 after unfreezing and pruning:  0.20603442192077637
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Ntrk3' 'Cacna1e' 'Col24a1' 'Erbb4' 'Egfem1' 'Pvalb' 'Kctd8' 'Sst' 'Syt2'
#  'Chodl' 'Npy' 'Tox' 'Kit' 'Lrp1b' 'Igf1' 'Hpse' 'Nkain3' 'Lamp5' 'Pde11a'
#  'Mgat4c' 'Mybpc1' 'Cnr1' 'Pdyn' 'Adarb2' 'Cplx3']
# [INFO] training network...
# Train R^2 before unfreezing:  0.27620190382003784
# Test R^2 before unfreezing:  0.20035123825073242
# Train R^2 after unfreezing:  0.3018243908882141
# Test R^2 after unfreezing:  0.27632254362106323
# Train R^2 after unfreezing and pruning:  0.28460586071014404
# Test R^2 after unfreezing and pruning:  0.2733883261680603
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Ak5' 'Myl4' 'Erbb4' 'Ptprt' 'Cd7' 'Pip5k1b' 'Chodl' 'Pde11a' 'Nkain3'
#  'Ntrk3' 'Cacna1e' 'Lamp5' 'Npy' 'Zfp536' 'Pnoc' 'Galntl6' 'Igf1'
#  'Zfp804a' 'Pvalb' 'Cplx3' 'Kctd8' 'Cpne7' 'Mybpc1' 'Adarb2' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.25718259811401367
# Test R^2 before unfreezing:  0.24948889017105103
# Train R^2 after unfreezing:  0.25588393211364746
# Test R^2 after unfreezing:  0.25187140703201294
# Train R^2 after unfreezing and pruning:  0.2657715678215027
# Test R^2 after unfreezing and pruning:  0.2598912715911865
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Rspo1' 'Tcf4' 'Sec14l2' 'Kcnab3' 'Adamtsl5' 'Coro6' 'Hrh1' 'Vip' 'Grm2'
#  'Fgf11' 'Mitf' 'Cnr1' 'Akr1c18' 'Thy1' 'Ppapdc1a' 'Runx2' 'Lamp5' 'Slit2'
#  'Grm7' 'C030013G03Rik' 'Slc17a8' 'Fxyd6' 'Cplx3' 'Pvalb' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.22184300422668457
# Test R^2 before unfreezing:  0.22626984119415283
# Train R^2 after unfreezing:  0.21289288997650146
# Test R^2 after unfreezing:  0.2105698585510254
# Train R^2 after unfreezing and pruning:  0.24368637800216675
# Test R^2 after unfreezing and pruning:  0.24127274751663208
#
# CVFOLD:  3
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Rtn4rl2' 'Rasl11b' 'Gadd45a' 'Lamp5' 'Mtcl1' 'Epb4.1' '1110018N20Rik'
#  'Ypel1' 'Baiap2l2' 'Prr5' 'Cecr6' 'Zdbf2' 'Nxph2' 'Adra1a' 'Sgcz' 'Eps8'
#  'Dlk2' 'Fam163a' 'Rassf2' 'Crhbp' 'Mybpc1' 'Fxyd6' 'Pip5k1b' 'Cartpt'
#  'Oprm1']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2725285291671753
# Test R^2 before unfreezing:  0.20912706851959229
# Train R^2 after unfreezing:  0.3494643568992615
# Test R^2 after unfreezing:  0.2295096516609192
# Train R^2 after unfreezing and pruning:  0.22845274209976196
# Test R^2 after unfreezing and pruning:  0.20001089572906494
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Brinp3' 'Pde11a' 'Fam135b' 'Kcnip2' 'Npy' 'Kit' 'Cbln2' 'Adcy2' 'Nxph1'
#  'Chat' 'Rgs6' 'Pvalb' 'Sema3c' 'Crhbp' 'Cnr1' 'Lamp5' 'Fxyd6' 'Mybpc1'
#  'Synpr' 'Adarb2' 'Cpne7' 'Cacna2d3' 'Penk' 'Chodl' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2735063433647156
# Test R^2 before unfreezing:  0.2151041030883789
# Train R^2 after unfreezing:  0.29687750339508057
# Test R^2 after unfreezing:  0.2796800136566162
# Train R^2 after unfreezing and pruning:  0.2780730128288269
# Test R^2 after unfreezing and pruning:  0.2596018314361572
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Pde11a' 'Lamp5' 'Nacc2' 'Ntrk3' 'Sez6' 'Pcp4l1' 'Slit2' 'Cdh13' 'Caln1'
#  'Pdyn' 'Galntl6' 'Adarb2' 'Zfp804a' 'Srrm4' 'Cacna1e' 'Chodl' 'Igf1'
#  'Egfem1' 'Cpne7' 'Pvalb' 'Erbb4' 'Mybpc1' 'Nxph1' 'Sst' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.25388455390930176
# Test R^2 before unfreezing:  0.2439526915550232
# Train R^2 after unfreezing:  0.26395905017852783
# Test R^2 after unfreezing:  0.2514801025390625
# Train R^2 after unfreezing and pruning:  0.27404505014419556
# Test R^2 after unfreezing and pruning:  0.26167380809783936
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Cacna1e' 'Lrrtm4' 'Runx2' 'Sorcs1' 'Cacna2d3' 'Caln1' 'Gabrd' 'Pbx3'
#  'Shisa6' 'Syt2' 'Pde11a' 'Fstl4' 'Popdc3' 'Lor' 'Nefl' 'Gpr150' 'Igf1'
#  'Scn4b' 'Igsf11' 'Pradc1' 'Pvalb' 'Cplx3' 'Tnnt1' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.23774313926696777
# Test R^2 before unfreezing:  0.23909986019134521
# Train R^2 after unfreezing:  0.22307205200195312
# Test R^2 after unfreezing:  0.2361619472503662
# Train R^2 after unfreezing and pruning:  0.24864763021469116
# Test R^2 after unfreezing and pruning:  0.23990243673324585
#
# CVFOLD:  4
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Hspb3' 'Calb2' 'Crhr1' 'Ptgs2' 'Lamp5' 'Bok' 'Gpr176' 'Alk' 'Ifit1'
#  'Glt8d2' 'Arhgap15' 'Dgki' 'Adora1' 'Sowahb' 'Scube1' 'Mrap2' 'Metrnl'
#  'Pou3f3' 'Pcbd1' 'Pcdh20' 'Ckmt1' 'Camk1d' 'Cmya5' 'Tpd52l1' 'Adra1a']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2594383955001831
# Test R^2 before unfreezing:  0.1804521083831787
# Train R^2 after unfreezing:  0.3268328905105591
# Test R^2 after unfreezing:  0.18437981605529785
# Train R^2 after unfreezing and pruning:  0.18777090311050415
# Test R^2 after unfreezing and pruning:  0.15139591693878174
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Ptpru' 'Kctd8' 'Npas3' 'Nkain3' 'Kcnc2' 'Zfp536' 'Nr3c2' 'Zmat4' 'Pvalb'
#  'Tmem91' 'Igf1' 'Rgs6' 'Slc24a3' 'Cntn4' 'Bace2' 'Fam135b' 'Zfp804a'
#  'Cplx3' 'Penk' 'Npy' 'Lamp5' 'Mybpc1' 'Vip' 'Adarb2' 'Chodl']
# [INFO] training network...
# Train R^2 before unfreezing:  0.25535738468170166
# Test R^2 before unfreezing:  0.17040926218032837
# Train R^2 after unfreezing:  0.294960618019104
# Test R^2 after unfreezing:  0.2451997995376587
# Train R^2 after unfreezing and pruning:  0.2819303274154663
# Test R^2 after unfreezing and pruning:  0.23333197832107544
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Cidea' 'Cit' 'Flt3' 'Ptprt' 'Sez6' 'Cplx3' 'Lynx1' 'Stxbp2' 'Pde11a'
#  'Pvalb' 'Cacna1e' 'Srrm4' 'Adarb2' 'Zfp804a' 'Lamp5' 'Chodl' 'Galntl6'
#  'Egfem1' 'Nxph1' 'Pdyn' 'Mybpc1' 'Cpne7' 'Erbb4' 'Sst' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2709586024284363
# Test R^2 before unfreezing:  0.23967397212982178
# Train R^2 after unfreezing:  0.2725755572319031
# Test R^2 after unfreezing:  0.24136823415756226
# Train R^2 after unfreezing and pruning:  0.27699804306030273
# Test R^2 after unfreezing and pruning:  0.24210798740386963
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Itgav' 'Mitf' 'Ifitm10' 'Grm2' 'Nenf' 'Pou3f2' 'Gap43' 'Slc30a3'
#  'Camk1d' 'Crispld1' '6530403H02Rik' 'Rab26' 'Arhgap15' 'Plch2'
#  '9930014A18Rik' 'Ak3l2-ps' 'Runx2' 'Camk2n2' 'Ngb' 'Cplx3' 'LOC102634502'
#  'Grm1' 'Cacna2d3' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.21018671989440918
# Test R^2 before unfreezing:  0.18677747249603271
# Train R^2 after unfreezing:  0.23383033275604248
# Test R^2 after unfreezing:  0.20330947637557983
# Train R^2 after unfreezing and pruning:  0.23941010236740112
# Test R^2 after unfreezing and pruning:  0.20507460832595825
#
# CVFOLD:  5
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Fam49a' 'Map3k5' 'Prr13' 'Pxdc1' 'Adamtsl5' '9930014A18Rik' 'Vat1'
#  'Zfp57' 'Cdca7' 'Lhx2' 'Nacc2' 'Slc36a1' 'Hsd11b1' 'Ptpn3' 'Flt3'
#  'Stard5' 'Osbpl10' 'Myh8' 'Trpc4' 'Kcnmb4' 'Slc6a7' 'Skap1' 'Grin3a'
#  'Mybpc1' 'Gng7']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2791164517402649
# Test R^2 before unfreezing:  0.2087380290031433
# Train R^2 after unfreezing:  0.31895798444747925
# Test R^2 after unfreezing:  0.21439921855926514
# Train R^2 after unfreezing and pruning:  0.17738598585128784
# Test R^2 after unfreezing and pruning:  0.17529380321502686
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Adamtsl5' 'Igf1' 'Cplx3' 'Gpr126' 'Kctd8' 'Gabrb2' 'Cnr1' 'Htr1f'
#  'Sema3a' 'Lrp1b' 'Pcdh7' 'Man1a' 'Necab1' 'Crtac1' 'Nell1' 'Chodl' 'Kit'
#  'Zmat4' 'Mybpc1' 'Fxyd6' 'Ptprt' 'Cacna2d3' 'Synpr' 'Sst' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.27986419200897217
# Test R^2 before unfreezing:  0.2190173864364624
# Train R^2 after unfreezing:  0.29241931438446045
# Test R^2 after unfreezing:  0.27642786502838135
# Train R^2 after unfreezing and pruning:  0.2834615111351013
# Test R^2 after unfreezing and pruning:  0.2704785466194153
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Tmem132d' 'Runx2' 'Sema3c' 'Lamp5' 'Crispld1' 'March1' 'Chodl' 'Grm1'
#  'Galnt14' 'Nell1' 'Ptchd2' 'Grm7' 'Zmat4' 'Alcam' 'Pde11a' 'Zfp536'
#  'Pvalb' 'Kcnc2' 'Kit' 'Sema3a' 'Trhde' 'Cacna2d3' 'Vip' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.25396889448165894
# Test R^2 before unfreezing:  0.2536084055900574
# Train R^2 after unfreezing:  0.26207906007766724
# Test R^2 after unfreezing:  0.25941598415374756
# Train R^2 after unfreezing and pruning:  0.27008986473083496
# Test R^2 after unfreezing and pruning:  0.2628796696662903
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Atp6ap1l' '1500009L16Rik' 'BC006965' 'Plxna2' 'Fmnl1' 'Akr1c18' 'Runx2'
#  'Cacna2d3' 'Smad3' 'Sema3a' 'Kcnab1' 'Rln1' 'Fxyd6' 'Sv2c' 'LOC105242710'
#  'Cplx3' 'Pvalb' 'Pcp4l1' 'Trhde' 'Pde11a' 'Mdga1' 'Grm1' 'Lamp5' 'Shisa6'
#  'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2350572943687439
# Test R^2 before unfreezing:  0.23571258783340454
# Train R^2 after unfreezing:  0.237207293510437
# Test R^2 after unfreezing:  0.23767584562301636
# Train R^2 after unfreezing and pruning:  0.2483806014060974
# Test R^2 after unfreezing and pruning:  0.24309277534484863
#
# CVFOLD:  6
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Poc1a' 'Gpr26' 'Cpne5' 'Gucy1a3' 'Ndst3' '1700007K13Rik' 'Sptbn5'
#  'Nptx2' 'Egln3' 'Ramp3' 'Col14a1' 'Tcrb' 'Tenm3' 'Zdbf2' 'Enpp2'
#  'Wbscr17' '5730522E02Rik' 'Gldn' 'Gabrb1' 'Fam49a' 'Dusp18' 'Nptxr'
#  'Fxyd7' 'Dlx6' 'Ptchd4']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2846258878707886
# Test R^2 before unfreezing:  0.2054215669631958
# Train R^2 after unfreezing:  0.3269517421722412
# Test R^2 after unfreezing:  0.21976709365844727
# Train R^2 after unfreezing and pruning:  0.1487399935722351
# Test R^2 after unfreezing and pruning:  0.13526225090026855
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Man1a' 'Pde11a' 'Chat' 'Penk' 'Brinp3' 'Nell1' 'Slc6a1' 'Syt2'
#  'Cacna2d3' 'Chodl' 'Pde1a' 'Tmem108' 'Pvalb' 'Lrp1b' 'Fxyd6' 'Nxph1'
#  'Ptprm' 'Cntn5' 'Lamp5' 'Sst' 'Hpse' 'Pdyn' 'Mybpc1' 'Synpr' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2693400979042053
# Test R^2 before unfreezing:  0.2074286937713623
# Train R^2 after unfreezing:  0.29130440950393677
# Test R^2 after unfreezing:  0.27111732959747314
# Train R^2 after unfreezing and pruning:  0.281297504901886
# Test R^2 after unfreezing and pruning:  0.2658913731575012
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Pcp4l1' 'B230216N24Rik' 'Cdca7' 'Npy' 'Nos1' 'Cpne7' 'Lamp5' 'Galntl6'
#  'Kcnab1' 'Miat' 'Nxph1' 'Pvalb' 'Cacna1e' 'Pde11a' 'Cplx3' 'Chodl' 'Igf1'
#  'Sema3a' 'Kctd8' 'Zfp804a' 'Zfp536' 'Sst' 'Mybpc1' 'Adarb2' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2572801113128662
# Test R^2 before unfreezing:  0.257432222366333
# Train R^2 after unfreezing:  0.2607295513153076
# Test R^2 after unfreezing:  0.26090723276138306
# Train R^2 after unfreezing and pruning:  0.270923376083374
# Test R^2 after unfreezing and pruning:  0.26931363344192505
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['5330416C01Rik' 'Tmsb10' 'LOC105243282' 'Crtac1' 'Nr4a3' 'Socs2' 'Htr1f'
#  'Alk' 'Frem1' 'Ppapdc1a' 'Kcns3' 'Lynx1' 'Gpr125' 'Col19a1' 'Runx2'
#  'Nefh' 'Ankrd33b' 'Vip' 'Igsf11' 'Dock4' 'Cplx3' 'Grm7' 'LOC105245487'
#  'Pvalb' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.21674370765686035
# Test R^2 before unfreezing:  0.22414207458496094
# Train R^2 after unfreezing:  0.2130730152130127
# Test R^2 after unfreezing:  0.21813100576400757
# Train R^2 after unfreezing and pruning:  0.24234843254089355
# Test R^2 after unfreezing and pruning:  0.24473577737808228
#
# CVFOLD:  7
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Sult2b1' 'Kcnd3' 'Efna1' 'Dlx5' 'Zdhhc23' 'Skil' 'Spint2' 'Zfp941'
#  'Cd164l2' 'Barx2' 'Epb4.1' 'Arhgap12' 'Gnaz' 'LOC105244192' 'Rnd3'
#  'Fxyd6' 'Tmem150c' 'Eps8' 'Ptgs2' 'Cnih3' 'Grm8' 'Nog' 'Ntn5' 'Dclk3'
#  'Fgf1']
# [INFO] training network...
# Train R^2 before unfreezing:  0.29553085565567017
# Test R^2 before unfreezing:  0.20445013046264648
# Train R^2 after unfreezing:  0.32049447298049927
# Test R^2 after unfreezing:  0.21491432189941406
# Train R^2 after unfreezing and pruning:  0.17250758409500122
# Test R^2 after unfreezing and pruning:  0.16721826791763306
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Grin2a' 'Cdh9' 'Gabrb2' 'Syndig1l' 'Hpse' 'Chrm2' 'Egfem1' 'Grm7'
#  'Pde1a' 'Kcnc2' 'Crhbp' 'Alcam' 'Pdyn' 'Mybpc1' 'Trhde' 'Zmat4' 'Nell1'
#  'Lamp5' 'Sst' 'Kit' 'Fxyd6' 'Cacna2d3' 'Chodl' 'Synpr' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2675827741622925
# Test R^2 before unfreezing:  0.19889014959335327
# Train R^2 after unfreezing:  0.29920023679733276
# Test R^2 after unfreezing:  0.27935415506362915
# Train R^2 after unfreezing and pruning:  0.2780000567436218
# Test R^2 after unfreezing and pruning:  0.26442229747772217
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Sema3c' 'Runx2' 'Igf1' 'March1' 'Crtac1' 'Pvalb' 'Pcp4l1' 'Pde11a'
#  'Cplx3' 'Nell1' 'Lamp5' 'Kctd8' 'Zfp536' 'Cacna2d1' 'Sema3a' 'Trhde'
#  'Chodl' 'Kcns3' 'Alcam' 'Kcnc2' 'Kit' 'Vip' 'Cacna2d3' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2541377544403076
# Test R^2 before unfreezing:  0.24746209383010864
# Train R^2 after unfreezing:  0.2612771987915039
# Test R^2 after unfreezing:  0.2556527256965637
# Train R^2 after unfreezing and pruning:  0.26833921670913696
# Test R^2 after unfreezing and pruning:  0.2568156123161316
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Ptchd2' 'Crtac1' 'Itgav' 'Grik4' 'Gprin3' 'Syt2' 'Kcnab1' 'Lamp5'
#  'Esrrg' 'Kctd8' 'Scube1' 'Gjd2' 'A830018L16Rik' 'Cacna2d1' 'Tgfb3' 'Grm1'
#  'Pde11a' 'Cplx3' 'Galnt14' 'Igsf11' 'Runx2' 'Pvalb' 'Cacna2d3' 'Fxyd6'
#  'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.242539644241333
# Test R^2 before unfreezing:  0.23698550462722778
# Train R^2 after unfreezing:  0.23524534702301025
# Test R^2 after unfreezing:  0.22989851236343384
# Train R^2 after unfreezing and pruning:  0.25407928228378296
# Test R^2 after unfreezing and pruning:  0.23949408531188965
#
# CVFOLD:  8
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Ifit1' 'Egr4' 'Glra3' 'Wbscr17' 'Myh14' 'Mapk4' 'Brinp3' 'Cartpt'
#  'Vwc2l' 'Fam150b' 'Ldb2' 'LOC100503338' 'Lmo1' 'Dgki' 'Nr3c2' 'Nefm'
#  'Nptx2' 'Gadd45a' 'Ptgs2' 'Synpr' 'Elfn1' 'Kcna1' 'Tmem163' 'Hopx' 'Pygm']
# [INFO] training network...
# Train R^2 before unfreezing:  0.27528244256973267
# Test R^2 before unfreezing:  0.17273539304733276
# Train R^2 after unfreezing:  0.33204352855682373
# Test R^2 after unfreezing:  0.1878790259361267
# Train R^2 after unfreezing and pruning:  0.20918458700180054
# Test R^2 after unfreezing and pruning:  0.1909247636795044
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Ptpre' 'Zfp536' 'Zfp804a' 'Syt2' 'Mgat4c' 'Hpse' 'Kit' 'Cbln2' 'Pde11a'
#  'Gria1' 'Nxph1' 'Kcnt2' 'Chrm2' 'Npy' 'Cntn4' 'Egfem1' 'Pvalb' 'Lamp5'
#  'Mybpc1' 'Erbb4' 'Trhde' 'Cplx3' 'Pdyn' 'Adarb2' 'Sst']
# [INFO] training network...
# Train R^2 before unfreezing:  0.26066702604293823
# Test R^2 before unfreezing:  0.18781816959381104
# Train R^2 after unfreezing:  0.2939751148223877
# Test R^2 after unfreezing:  0.269626259803772
# Train R^2 after unfreezing and pruning:  0.28165340423583984
# Test R^2 after unfreezing and pruning:  0.2663692831993103
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Kcnab1' 'Kctd8' 'Pvalb' 'Crtac1' 'Kcns3' 'Galnt14' 'Igf1' 'Kit' 'Grm1'
#  'Cplx3' 'Ptchd2' 'Alcam' 'Chodl' 'Grm7' 'Runx2' 'Zmat4' 'Nell1'
#  'Cacna2d3' 'Sema3a' 'Trhde' 'Zfp536' 'Kcnc2' 'Vip' 'Fxyd6' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2576792240142822
# Test R^2 before unfreezing:  0.24546688795089722
# Train R^2 after unfreezing:  0.2634713649749756
# Test R^2 after unfreezing:  0.25571906566619873
# Train R^2 after unfreezing and pruning:  0.2700265645980835
# Test R^2 after unfreezing and pruning:  0.2562553286552429
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Lamp5' 'Il1rap' 'Trhde' 'Sertm1' 'Lhfpl5' 'Cacna2d1' 'Slc24a3' 'Fam163a'
#  'Sox5' 'Igsf11' 'Crtac1' '2610100L16Rik' 'Akr1c18' 'Col19a1' 'Crispld1'
#  'Pvalb' 'Dlx1' 'Satb1' 'Adssl1' 'Cacna2d3' 'Gabra5' 'Grm1' 'Runx2'
#  'Slc6a1' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.23012202978134155
# Test R^2 before unfreezing:  0.2274841070175171
# Train R^2 after unfreezing:  0.23717325925827026
# Test R^2 after unfreezing:  0.23361331224441528
# Train R^2 after unfreezing and pruning:  0.24830186367034912
# Test R^2 after unfreezing and pruning:  0.23724353313446045
#
# CVFOLD:  9
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['LOC105244192' 'Ptprf' 'Slc35f1' 'Samd3' 'Nell1' 'Kcnmb2' 'Gng7'
#  'Syndig1l' 'Nefl' 'Nwd2' 'Rtn4rl2' 'Ramp3' 'Ephx4' 'Egln3' 'Barx2'
#  'Gprin3' 'Oxtr' '1700007K13Rik' 'Tspan17' 'Cckbr' 'Satb2' 'Mybpc1' 'Gad2'
#  'Scn7a' 'Fxyd6']
# [INFO] training network...
# Train R^2 before unfreezing:  0.28413331508636475
# Test R^2 before unfreezing:  0.19956427812576294
# Train R^2 after unfreezing:  0.31213897466659546
# Test R^2 after unfreezing:  0.216302752494812
# Train R^2 after unfreezing and pruning:  0.20330768823623657
# Test R^2 after unfreezing and pruning:  0.16613006591796875
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Trhde' 'Egfem1' 'Runx2' 'Hpse' 'Nov' 'Nxph1' 'Akr1c18' 'Gabrb2' 'Cdh9'
#  'Caln1' 'Nell1' 'Grm7' 'Pcp4l1' 'Lamp5' 'Fxyd6' 'Kit' 'Ptpru' 'Mybpc1'
#  'Chrm2' 'Kcnc2' 'Chodl' 'Pdyn' 'Sst' 'Synpr' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.27667099237442017
# Test R^2 before unfreezing:  0.2045995593070984
# Train R^2 after unfreezing:  0.302761435508728
# Test R^2 after unfreezing:  0.2724224925041199
# Train R^2 after unfreezing and pruning:  0.2820250391960144
# Test R^2 after unfreezing and pruning:  0.2671416401863098
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Cux2' '5730522E02Rik' 'Ptprt' 'Pip5k1b' 'Miat' 'Syt6' 'Gpr150' 'Galnt14'
#  'Ece2' 'Slc6a1' 'Grik1' 'Gabrb2' 'Cntn4' 'Pvalb' 'Pcp4l1' 'Nell1' 'Runx2'
#  'Chodl' 'Cplx3' 'Mybpc1' 'Zfp804a' 'Fxyd6' 'Lamp5' 'Synpr' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2609419822692871
# Test R^2 before unfreezing:  0.23830187320709229
# Train R^2 after unfreezing:  0.26621222496032715
# Test R^2 after unfreezing:  0.24899530410766602
# Train R^2 after unfreezing and pruning:  0.26914703845977783
# Test R^2 after unfreezing and pruning:  0.24723148345947266
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Nr3c2' 'Fhl2' 'Oprm1' 'F730043M19Rik' 'Ppp1r14c' 'Sorcs1' 'Syt16'
#  'Man1c1' 'Pvalb' 'Hapln4' 'Atp6ap1l' 'Flt3' 'Ly6g6e' 'Kcnmb4os2'
#  'Ppp2r5a' '4933412E12Rik' 'Dynll2' 'LOC105244376' 'Tgm3' 'Fxyd6' 'Cntn4'
#  'Cplx3' 'Lamp5' 'Vip' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.23110294342041016
# Test R^2 before unfreezing:  0.21354496479034424
# Train R^2 after unfreezing:  0.23135125637054443
# Test R^2 after unfreezing:  0.2197590470314026
# Train R^2 after unfreezing and pruning:  0.2472991943359375
# Test R^2 after unfreezing and pruning:  0.2231934666633606
# Time: 1.0h  3m  5s

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_freeze_unfreeze_lasso.pickle', 'wb') as f:
    pickle.dump([r2_before_unfreezing, r2_before_unfreezing_tr, \
                 r2_after_unfreezing, r2_after_unfreezing_tr, \
                 r2_after_unfreezing_ap, r2_after_unfreezing_ap_tr, \
                 r2_freeze_unfreeze_hist, r2_freeze_unfreeze_hist_tr], f)

# %% [markdown]
# In the next section we perform reduced-rank regression cross validation (rank = 2 and full rank).

# %%
# CV sRRR rank = 2

lambdas = np.arange(.5,3,.1)
alphas = np.array([1])

rank = 2
folds = 10
seed = 42

r2_sRRR_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_rank2_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank2_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
nonzero_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
corrs_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))
corrs_relaxed_rank2 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))


t = time.time()

np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    x_train = x_train.astype('float64')
    y_train = y_train.astype('float64')
    x_test = x_test.astype('float64')
    y_test = y_test.astype('float64')
    
    for i,a in enumerate(lambdas):
        #print('Lambdau: ', a)
        for j, b in enumerate(alphas):
            #print('Alpha: ', b)
            vx,vy = sparseRRR.elastic_rrr(x_train, y_train, lambdau=a, alpha=b, rank=rank, sparsity='row-wise')

            nz = np.sum(np.abs(vx), axis=1) != 0
            if np.sum(nz) < rank:
                nonzero_rank2[cvfold, j, i] = np.nan
                continue

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank2[cvfold, j, i] = np.nan
                continue

            nonzero_rank2[cvfold, j, i] = np.sum(nz)
            r2_sRRR_rank2[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum(y_test**2)
            r2_sRRR_rank2_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum(y_train**2)
            for r in range(rank):
                corrs_rank2[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]

            # Relaxation
            vx[nz,:],vy = sparseRRR.elastic_rrr(x_train[:,nz], y_train, lambdau=a, alpha=0, rank=rank, sparsity='row-wise')

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank2[cvfold, j, i] = np.nan
                continue

            r2_sRRR_relaxed_rank2[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum(y_test**2)
            r2_sRRR_relaxed_rank2_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum(y_train**2)
            for r in range(rank):
                corrs_relaxed_rank2[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]
            #print(r2_sRRR_relaxed_rank2[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
#
# CVFOLD:  1
#
# CVFOLD:  2
#
# CVFOLD:  3
#
# CVFOLD:  4
#
# CVFOLD:  5
#
# CVFOLD:  6
#
# CVFOLD:  7
#
# CVFOLD:  8
#
# CVFOLD:  9
# Time: 0.0h  3m 40s

# %%
with open('KerasSavedModels/gouwens_2020/sRRR_vs_Bottleneck_rank2_CV_lasso.pickle', 'wb') as f:
    pickle.dump([r2_sRRR_rank2, r2_sRRR_relaxed_rank2, r2_sRRR_rank2_tr, r2_sRRR_relaxed_rank2_tr, \
                nonzero_rank2, corrs_rank2, corrs_relaxed_rank2], f)

# %%
# CV sRRR full rank

lambdas = np.arange(.5,3,.1)
#lambdas = np.array([.8,.9,1])
alphas = np.array([1])

rank = 16
folds = 10
seed = 42

r2_sRRR_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_rank16_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
r2_sRRR_relaxed_rank16_tr = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
nonzero_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0]))
corrs_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))
corrs_relaxed_rank16 = np.zeros((folds, alphas.shape[0], lambdas.shape[0], rank))


t = time.time()

np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    x_train = x_train.astype('float64')
    y_train = y_train.astype('float64')
    x_test = x_test.astype('float64')
    y_test = y_test.astype('float64')
    
    for i,a in enumerate(lambdas):
        #print('Labmdau: ', a)
        for j, b in enumerate(alphas):
            #print('Alpha: ', b)
            vx,vy = sparseRRR.elastic_rrr(x_train, y_train, lambdau=a, alpha=b, rank=rank, sparsity='row-wise')

            nz = np.sum(np.abs(vx), axis=1) != 0
            if np.sum(nz) < rank:
                nonzero_rank16[cvfold, j, i] = np.nan
                continue

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank16[cvfold, j, i] = np.nan
                continue
            nonzero_rank16[cvfold, j, i] = np.sum(nz)
            r2_sRRR_rank16[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum(y_test**2)
            r2_sRRR_rank16_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum(y_train**2)
            for r in range(rank):
                corrs_rank16[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]

            # Relaxation
            vx[nz,:],vy = sparseRRR.elastic_rrr(x_train[:,nz], y_train, lambdau=a, alpha=0, rank=rank, sparsity='row-wise')

            if np.allclose(np.std(x_test @ vx, axis=0), 0):
                nonzero_rank16[cvfold, j, i] = np.nan
                continue

            r2_sRRR_relaxed_rank16[cvfold, j, i] = 1 - np.sum((y_test - x_test @ vx @ vy.T)**2) / np.sum(y_test**2)
            r2_sRRR_relaxed_rank16_tr[cvfold, j, i] = 1 - np.sum((y_train - x_train @ vx @ vy.T)**2) / np.sum(y_train**2)
            for r in range(rank):
                corrs_relaxed_rank16[cvfold, j, i, r] = np.corrcoef(x_test @ vx[:,r], y_test @ vy[:,r], rowvar=False)[0,1]
            #print(r2_sRRR_relaxed_rank16[cvfold, j, i])

t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
#
# CVFOLD:  1
#
# CVFOLD:  2
#
# CVFOLD:  3
#
# CVFOLD:  4
#
# CVFOLD:  5
#
# CVFOLD:  6
#
# CVFOLD:  7
#
# CVFOLD:  8
#
# CVFOLD:  9
# Time: 0.0h  6m 42s

# %%
with open('KerasSavedModels/gouwens_2020/sRRR_vs_Bottleneck_rank16_CV_lasso.pickle', 'wb') as f:
    pickle.dump([r2_sRRR_rank16, r2_sRRR_relaxed_rank16, r2_sRRR_rank16_tr, r2_sRRR_relaxed_rank16_tr, \
                nonzero_rank16, corrs_rank16, corrs_relaxed_rank16], f)

# %% [markdown]
# Let us now analyse and visualise the differences.

# %%
lambdas = np.arange(.5,3,.1)
alphas = np.array([1])

# %%
with open('KerasSavedModels/gouwens_2020/sRRR_vs_Bottleneck_rank2_CV_lasso.pickle', 'rb') as f:
    r2_sRRR_rank2, r2_sRRR_relaxed_rank2, r2_sRRR_rank2_tr, r2_sRRR_relaxed_rank2_tr, \
                nonzero_rank2, corrs_rank2, corrs_relaxed_rank2 = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/sRRR_vs_Bottleneck_rank16_CV_lasso.pickle', 'rb') as f:
    r2_sRRR_rank16, r2_sRRR_relaxed_rank16, r2_sRRR_rank16_tr, r2_sRRR_relaxed_rank16_tr, \
                nonzero_rank16, corrs_rank16, corrs_relaxed_rank16 = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_pre_tr_lasso.pickle', 'rb') as f:
    CE_loss, CE_loss_tr, pre_tr_hist, pre_tr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_straight_regr_lasso.pickle', 'rb') as f:
    r2_straight_regr, r2_straight_regr_tr, \
    r2_straight_regr_ap, r2_straight_regr_ap_tr, \
    r2_straight_regr_hist, r2_straight_regr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_straight_regr_lasso.pickle', 'rb') as f:
    r2_pretr_straight_regr, r2_pretr_straight_regr_tr, \
    r2_pretr_straight_regr_ap, r2_pretr_straight_regr_ap_tr, \
    r2_pretr_straight_regr_hist, r2_pretr_straight_regr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_freeze_unfreeze_lasso.pickle', 'rb') as f:
    r2_before_unfreezing, r2_before_unfreezing_tr, \
    r2_after_unfreezing, r2_after_unfreezing_tr, \
    r2_after_unfreezing_ap, r2_after_unfreezing_ap_tr, \
    r2_freeze_unfreeze_hist, r2_freeze_unfreeze_hist_tr = pickle.load(f)

# %%
# Select closest to 25 genes value
# suppressing "mean of empty slice" warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    n_rank2 = np.nanmean(nonzero_rank2, axis=0)[0, :]
    r_rank2_r = np.nanmean(r2_sRRR_relaxed_rank2, axis=0)[0, :]
    n_rank16 = np.nanmean(nonzero_rank16, axis=0)[0, :]
    r_rank16_r = np.nanmean(r2_sRRR_relaxed_rank16, axis=0)[0, :]

# %%
print(r_rank16_r[np.isclose(n_rank16, 25, atol=4)][0], '+/-',
      np.nanstd(r2_sRRR_relaxed_rank16, axis=0)[0, :][np.isclose(n_rank16, 25, atol=4)][0])
# Out:
# 0.24761962866026271 +/- 0.011715595929091108

# %%
print(r_rank2_r[np.isclose(n_rank2, 25, atol=3)][0], '+/-',
      np.nanstd(r2_sRRR_relaxed_rank2, axis=0)[0, :][np.isclose(n_rank2, 25, atol=3)][0])
# Out:
# 0.18829585093268397 +/- 0.009288457086591801

# %%
print(np.mean(r2_freeze_unfreeze_hist,axis=0)[2,0,-1], '+/-', np.std(r2_freeze_unfreeze_hist,axis=0)[2,0,-1])
# Out:
# 0.25898462235927583 +/- 0.010064644924369955

# %%
print(np.mean(r2_straight_regr_hist,axis=0)[0,0,-1], '+/-', np.std(r2_straight_regr_hist,axis=0)[0,0,-1])
# Out:
# 0.24738019406795503 +/- 0.011924815000367675

# %%
# # All together in one plot
# linewidth = 2
# sns_styleset()

# # suppressing "mean of empty slice" warnings
# with warnings.catch_warnings():
#     warnings.simplefilter("ignore", category=RuntimeWarning)
#     n_2 = np.nanmean(nonzero_rank2, axis=0)[0, :]
#     cr_2 = np.nanmean(r2_sRRR_relaxed_rank2, axis=0)[0, :]
#     n_16 = np.nanmean(nonzero_rank16, axis=0)[0, :]
#     cr_16= np.nanmean(r2_sRRR_relaxed_rank16, axis=0)[0, :]
    
    

# # suppressing "mean of empty slice" warnings
# with warnings.catch_warnings():
#     warnings.simplefilter("ignore", category=RuntimeWarning)
#     n_rank2 = np.nanmean(nonzero_rank2, axis=0)[0, :]
#     r_rank2_r = np.nanmean(r2_sRRR_relaxed_rank2, axis=0)[0, :]
#     n_rank16 = np.nanmean(nonzero_rank16, axis=0)[0, :]
#     r_rank16_r = np.nanmean(r2_sRRR_relaxed_rank16, axis=0)[0, :]

# # All together in one plot for the paper
# fig = plt.figure(figsize=(19, 4.5))
# widths = [1, 1, 2]
# heights = [1]
# spec = fig.add_gridspec(ncols=3, nrows=1, width_ratios=widths,
#                           height_ratios=heights)
# ax1 = fig.add_subplot(spec[0, 0])
# ax1.plot(n_2, cr_2, '.-', c = np.array([0, 0, 0])/256, linewidth=2)
# ax1.plot(n_16[1:], cr_16[1:], '.-', c = np.array([0, 0, 0]) / 256, linewidth=2)
# ax1.set_ylim([0.1,0.32])
# ax1.set_xlabel('Number of selected genes', fontsize = 17)
# ax1.set_ylabel(r'Cross validated $R^2$', fontsize = 17)
# ax1.set_title('Sparse reduced-rank regression', fontsize = 20, y=1.02)
# ax1.tick_params(axis='both', which='major', labelsize=15)
# ax1.tick_params(axis='both', which='minor', labelsize=15)
# ax1.vlines(x=25, ymin=ax1.get_ylim()[0], ymax=ax1.get_ylim()[1], linestyles='dashed')
# ax1.annotate('sRRR, r=16', (70, np.max(cr_16)+0.0003), fontsize=15)
# ax1.annotate('sRRR, r=2', (55, np.max(cr_2)+0.0003), fontsize=15)


# ax2 = fig.add_subplot(spec[0, 1])
# ax2.plot(range(50), np.mean(pre_tr_hist_tr, axis=(0, 2))[2, :], \
#          '--', c = 'k', linewidth=linewidth)
# ax2.plot(range(50), np.mean(pre_tr_hist, axis=(0, 2))[2, :], \
#          c = 'k', linewidth=linewidth)
# ax2.set_title('Pretraining', fontsize = 19, y=1.02)
# ax2.set_xlabel('Epoch', fontsize = 17)
# ax2.set_ylabel('Cross entropy loss', fontsize = 17)
# ax2.tick_params(axis='both', which='major', labelsize=15)
# ax2.tick_params(axis='both', which='minor', labelsize=15)
# ax2.set_ylim([1, ax2.get_ylim()[1]])
# ax2.annotate('Training', (35, 1.65), fontsize=15)
# ax2.annotate('Test', (35, 1.9), fontsize=15)
# ax2.set_xticks(np.arange(0, 60, 10))

# epochs_used=200
# ax3 = fig.add_subplot(spec[0, 2])
# ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist_tr, axis=(0))[2,0,:], \
#          '--', c = '#1b9e77', linewidth=linewidth)
# ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist, axis=(0))[2,0,:], \
#          c = '#1b9e77', linewidth=linewidth, label='Pre-training + freezing + unfreezing')
# ax3.plot(range(epochs_used), np.mean(r2_pretr_straight_regr_hist_tr, axis=(0))[0,0,:], \
#          '--', c = '#d95f02', linewidth=linewidth)
# ax3.plot(range(epochs_used), np.mean(r2_pretr_straight_regr_hist, axis=(0))[0,0,:], \
#          c = '#d95f02', linewidth=linewidth, label='Pre-training + no freezing')
# ax3.plot(range(epochs_used), np.mean(r2_straight_regr_hist_tr, axis=(0))[0,0,:], \
#          '--', c = '#7570b3', linewidth=linewidth)
# ax3.plot(range(epochs_used), np.mean(r2_straight_regr_hist, axis=(0))[0,0,:], \
#          c = '#7570b3', linewidth=linewidth, label='No pre-training')
# ax3.hlines(r_rank16_r[np.isclose(n_rank16, 25, atol=4)], xmin = 0, xmax = epochs_used, \
#             colors = np.array([0, 0, 0])/256, linewidth=linewidth)
# ax3.hlines(r_rank2_r[np.isclose(n_rank2, 25, atol=2)], xmin = 0, xmax = epochs_used, \
#             colors = np.array([0, 0, 0])/256, linewidth=linewidth)
# ax3.set_ylim([0.1,0.32])
# ax3.set_xlim([0,200])
# ax3.set_xticks(np.arange(0, 225, 25))
# ax3.annotate('RRR, r=16', (178, r_rank16_r[np.isclose(n_rank16, 25, atol=4)][0]-0.02), fontsize=15)
# ax3.annotate('RRR, r=2', (178, r_rank2_r[np.isclose(n_rank2, 25, atol=2)][0]+0.003), fontsize=15)
# ax3.set_title('Bottleneck neural network', fontsize = 19, y=1.02)
# ax3.set_xlabel('Epoch', fontsize = 17)
# ax3.set_ylabel(r'$R^2$', fontsize = 17)
# ax3.tick_params(axis='both', which='major', labelsize=15)
# ax3.tick_params(axis='both', which='minor', labelsize=15)
# ax3.legend(loc='lower right', fontsize=15)
# ax3.vlines(x=50, ymin=ax3.get_ylim()[0], ymax=ax3.get_ylim()[1], linestyles='dashed')
# ax3.vlines(x=100, ymin=ax3.get_ylim()[0], ymax=ax3.get_ylim()[1], linestyles='dashed')

# plt.text(-0.25, 1.04, 'a', transform = ax1.transAxes, fontsize=25, fontweight='bold')
# plt.text(-0.11, 1.04, 'b', transform = ax2.transAxes, fontsize=25, fontweight='bold')
# plt.text(-0.13, 1.04, 'c', transform = ax3.transAxes, fontsize=25, fontweight='bold')
# sns.despine()

# plt.savefig('figures/Allen_Lasso_training_curves.pdf', bbox_inches='tight',
#     pad_inches=0)
# plt.savefig('figures/Allen_Lasso_training_curves.png', bbox_inches='tight',
#     pad_inches=0)

# %%
# All together in one plot
linewidth = 2
sns_styleset()

# suppressing "mean of empty slice" warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    n_2 = np.nanmean(nonzero_rank2, axis=0)[0, :]
    cr_2 = np.nanmean(r2_sRRR_relaxed_rank2, axis=0)[0, :]
    n_16 = np.nanmean(nonzero_rank16, axis=0)[0, :]
    cr_16= np.nanmean(r2_sRRR_relaxed_rank16, axis=0)[0, :]
    
    

# suppressing "mean of empty slice" warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    n_rank2 = np.nanmean(nonzero_rank2, axis=0)[0, :]
    r_rank2_r = np.nanmean(r2_sRRR_relaxed_rank2, axis=0)[0, :]
    n_rank16 = np.nanmean(nonzero_rank16, axis=0)[0, :]
    r_rank16_r = np.nanmean(r2_sRRR_relaxed_rank16, axis=0)[0, :]

# All together in one plot for the paper
fig = plt.figure(figsize=(19, 4.5))
widths = [1, 1, 2]
heights = [1]
spec = fig.add_gridspec(ncols=3, nrows=1, width_ratios=widths,
                          height_ratios=heights)
ax1 = fig.add_subplot(spec[0, 0])
ax1.plot(n_2, cr_2, '.-', c = np.array([0, 0, 0])/256, linewidth=2)
ax1.plot(n_16[1:], cr_16[1:], '.-', c = np.array([0, 0, 0]) / 256, linewidth=2)
ax1.set_ylim([0.1,0.32])
ax1.set_xlabel('Number of selected genes', fontsize = 17)
ax1.set_ylabel(r'Cross validated $R^2$', fontsize = 17)
ax1.set_title('Sparse reduced-rank regression', fontsize = 20, y=1.02)
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.tick_params(axis='both', which='minor', labelsize=15)
ax1.vlines(x=25, ymin=ax1.get_ylim()[0], ymax=ax1.get_ylim()[1], linestyles='dashed')
ax1.annotate('sRRR, r=16', (70, np.max(cr_16)+0.0003), fontsize=15)
ax1.annotate('sRRR, r=2', (55, np.max(cr_2)+0.0003), fontsize=15)


ax2 = fig.add_subplot(spec[0, 1])
ax2.plot(range(50), np.mean(pre_tr_hist_tr, axis=(0, 2))[2, :], \
         '--', c = 'k', linewidth=linewidth)
ax2.plot(range(50), np.mean(pre_tr_hist, axis=(0, 2))[2, :], \
         c = 'k', linewidth=linewidth)
ax2.set_title('Pretraining', fontsize = 19, y=1.02)
ax2.set_xlabel('Epoch', fontsize = 17)
ax2.set_ylabel('Cross entropy loss', fontsize = 17)
ax2.tick_params(axis='both', which='major', labelsize=15)
ax2.tick_params(axis='both', which='minor', labelsize=15)
ax2.set_ylim([1, ax2.get_ylim()[1]])
ax2.annotate('Training', (35, 1.65), fontsize=15)
ax2.annotate('Test', (35, 1.9), fontsize=15)
ax2.set_xticks(np.arange(0, 60, 10))

epochs_used=200
ax3 = fig.add_subplot(spec[0, 2])
ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist_tr, axis=(0))[2,0,:], \
         '--', c = '#1b9e77', linewidth=linewidth)
ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist, axis=(0))[2,0,:], \
         c = '#1b9e77', linewidth=linewidth, label='With pre-training')
# ax3.plot(range(epochs_used), np.mean(r2_pretr_straight_regr_hist_tr, axis=(0))[0,0,:], \
#          '--', c = '#d95f02', linewidth=linewidth)
# ax3.plot(range(epochs_used), np.mean(r2_pretr_straight_regr_hist, axis=(0))[0,0,:], \
#          c = '#d95f02', linewidth=linewidth, label='Pre-training + no freezing')
ax3.plot(range(epochs_used), np.mean(r2_straight_regr_hist_tr, axis=(0))[0,0,:], \
         '--', c = '#d95f02', linewidth=linewidth)
ax3.plot(range(epochs_used), np.mean(r2_straight_regr_hist, axis=(0))[0,0,:], \
         c = '#d95f02', linewidth=linewidth, label='No pre-training')
ax3.hlines(r_rank16_r[np.isclose(n_rank16, 25, atol=4)], xmin = 0, xmax = epochs_used, \
            colors = np.array([0, 0, 0])/256, linewidth=linewidth)
ax3.hlines(r_rank2_r[np.isclose(n_rank2, 25, atol=2)], xmin = 0, xmax = epochs_used, \
            colors = np.array([0, 0, 0])/256, linewidth=linewidth)
ax3.set_ylim([0.1,0.32])
ax3.set_xlim([0,200])
ax3.set_xticks(np.arange(0, 225, 25))
ax3.annotate('sRRR, r=16', (178, r_rank16_r[np.isclose(n_rank16, 25, atol=4)][0]-0.02), fontsize=15)
ax3.annotate('sRRR, r=2', (178, r_rank2_r[np.isclose(n_rank2, 25, atol=2)][0]+0.003), fontsize=15)
ax3.set_title('Bottleneck neural network', fontsize = 19, y=1.02)
ax3.set_xlabel('Epoch', fontsize = 17)
ax3.set_ylabel(r'$R^2$', fontsize = 17)
ax3.tick_params(axis='both', which='major', labelsize=15)
ax3.tick_params(axis='both', which='minor', labelsize=15)
ax3.legend(loc='lower right', fontsize=15)
ax3.vlines(x=50, ymin=ax3.get_ylim()[0], ymax=ax3.get_ylim()[1], linestyles='dashed')
ax3.vlines(x=100, ymin=ax3.get_ylim()[0], ymax=ax3.get_ylim()[1], linestyles='dashed')

plt.text(-0.25, 1.04, 'a', transform = ax1.transAxes, fontsize=25, fontweight='bold')
plt.text(-0.11, 1.04, 'b', transform = ax2.transAxes, fontsize=25, fontweight='bold')
plt.text(-0.13, 1.04, 'c', transform = ax3.transAxes, fontsize=25, fontweight='bold')
sns.despine()

plt.savefig('figures/Allen_Lasso_training_curves.pdf', bbox_inches='tight',
    pad_inches=0)
plt.savefig('figures/Allen_Lasso_training_curves.png', bbox_inches='tight',
    pad_inches=0)

# %% [markdown]
# # Different # layers frozen

# %%
from bottleneck_networks import FreezeUnfreeze

# %%
# Settings
l2_params = np.logspace(-10, -10, num=1)
l1_params = np.array([1e-1])

act = 'elu'
folds = 5
seed = 42
lr=0.0001
epochs=50
bs=32
patience=epochs
pre_trained_weights=True
unfreeze = [False, True, True, True, True, True] # last 1 layer can be trained only first
prune=True

r2_before_unfreezing = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_before_unfreezing_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_ap = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_after_unfreezing_ap_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0]))
r2_freeze_unfreeze_hist = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))
r2_freeze_unfreeze_hist_tr = np.zeros((folds, l1_params.shape[0], l2_params.shape[0], 4*epochs))

t = time.time()
np.random.seed(seed)
n = genes.shape[0]
ind = np.random.permutation(n)
X = genes[ind,:]
Y = ephys[ind,:]

nodes_list=[512,128,2,128,512]

# CV folds
for cvfold in range(folds):
    print('\nCVFOLD: ', cvfold)
    indtest  = np.arange(cvfold*int(n/folds), (cvfold+1)*int(n/folds))
    indtrain = np.setdiff1d(np.arange(n), indtest)
    x_train = np.copy(X[indtrain,:])
    y_train = np.copy(Y[indtrain,:])
    x_test = np.copy(X[indtest,:])
    y_test = np.copy(Y[indtest,:])

    # Mean centering (like sRRR)
    X_mean = np.mean(x_train, axis=0)
    x_train -= X_mean
    x_test -= X_mean
    Y_mean = np.mean(y_train, axis=0)
    y_train -= Y_mean
    y_test -= Y_mean
    
    input_dim = x_train.shape[1]
    output_dim = y_train.shape[1]
    
    for i, l2 in enumerate(l2_params):
        #print('Ridge penalty: ', l2)
        for j, l1 in enumerate(l1_params):
            #print('Lasso penalty: ', l1)
            
            pre_trained_weights_h5 = 'KerasSavedModels/Classification_last_weights_{}_{}_{}.h5'.format(cvfold, 2, i)
            input_dim = x_train.shape[1]
            output_dim = y_train.shape[1]
            BN_PreTrFreezeUnfreeze = FreezeUnfreeze(l1=l1, l2=l2, lr=lr, act=act, input_dim=input_dim, output_dim=output_dim, \
                                                       unfreeze = unfreeze, \
                                                       pre_trained_weights=pre_trained_weights, \
                                                       pre_trained_weights_h5=pre_trained_weights_h5, nodes_list=nodes_list)
            r2_before_unfreezing_train, r2_before_unfreezing_test, \
                r2_after_unfreezing_train, r2_after_unfreezing_test, \
                r2_after_unfreezing_train_ap, r2_after_unfreezing_test_ap, \
                train_hist, test_hist = BN_PreTrFreezeUnfreeze.train(x_train=x_train, y_train=y_train, \
                                                                    x_test=x_test, y_test=y_test, \
                                                                    epochs=epochs, bs=bs, patience=patience, \
                                                                    cvfold_id=cvfold, l1_id=j, l2_id=i, \
                                                                    prune=prune, geneNames=gene_names, \
                                                                    verbose=0)
            r2_before_unfreezing[cvfold, j, i] = r2_before_unfreezing_test
            r2_before_unfreezing_tr[cvfold, j, i] = r2_before_unfreezing_train
            r2_after_unfreezing[cvfold, j, i] = r2_after_unfreezing_test
            r2_after_unfreezing_tr[cvfold, j, i] = r2_after_unfreezing_train
            r2_after_unfreezing_ap[cvfold, j, i] = r2_after_unfreezing_test_ap
            r2_after_unfreezing_ap_tr[cvfold, j, i] = r2_after_unfreezing_train_ap
            r2_freeze_unfreeze_hist[cvfold, j, i] = test_hist
            r2_freeze_unfreeze_hist_tr[cvfold, j, i] = train_hist
            #print('Test R^2 score (before unfreezing): ', r2_before_unfreezing[cvfold, j, i])
            #print('Test R^2 score (after unfreezing): ', r2_after_unfreezing[cvfold, j, i])
            #print('Test R^2 score (after unfreezing and after pruning): ', r2_after_unfreezing_ap[cvfold, j, i])
            
t = time.time() - t
m,s = divmod(t, 60)
h,m = divmod(m, 60)
print('Time: {}h {:2.0f}m {:2.0f}s'.format(h,m,s))
# Out:
# CVFOLD:  0
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Kcnab1' 'Cntn4' 'Unc5d' 'Ak5' 'Galnt18' 'Nell1' 'Ptprt' 'Cplx3' 'Syt6'
#  'Brinp3' 'A830018L16Rik' 'Gabrb2' 'Cdh7' 'Ndst3' 'Pcp4l1' 'Cacna2d3'
#  'Zfp804a' 'Lrp1b' 'Sorcs1' 'Pvalb' 'Fxyd6' 'Mybpc1' 'Lamp5' 'Synpr' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.26550036668777466
# Test R^2 before unfreezing:  0.278472363948822
# Train R^2 after unfreezing:  0.26888471841812134
# Test R^2 after unfreezing:  0.27625423669815063
# Train R^2 after unfreezing and pruning:  0.2773968577384949
# Test R^2 after unfreezing and pruning:  0.281141459941864
#
# CVFOLD:  1
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Asic2' 'Alcam' 'Lrp1b' 'Npas3' 'Whrn' 'Lamp5' 'Tox' 'Tmem44' 'Srrm4'
#  'Cntnap5c' 'Kcnab1' 'Sema3a' 'Zfp804a' 'Kctd8' 'Cacna1e' 'Nkain3' 'Ano4'
#  'Npy' 'Pvalb' 'Nxph1' 'Zfp536' 'Mybpc1' 'Sst' 'Adarb2' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2630499601364136
# Test R^2 before unfreezing:  0.2632458209991455
# Train R^2 after unfreezing:  0.26765328645706177
# Test R^2 after unfreezing:  0.2604407072067261
# Train R^2 after unfreezing and pruning:  0.28346341848373413
# Test R^2 after unfreezing and pruning:  0.2719799876213074
#
# CVFOLD:  2
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Fstl5' 'Pde11a' 'Cdh12' 'Runx2' 'Pvalb' 'Grm7' 'Kctd8' 'Tmem132d'
#  'Ptprt' 'Sema3a' 'St6galnac5' 'Nell1' 'Mybpc1' 'Crtac1' 'Alcam' 'Lrp1b'
#  'Trhde' 'Kit' 'Npy' 'Fxyd6' 'Cacna2d3' 'Synpr' 'Adarb2' 'Sst' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2744513154029846
# Test R^2 before unfreezing:  0.2570904493331909
# Train R^2 after unfreezing:  0.28000324964523315
# Test R^2 after unfreezing:  0.2500011920928955
# Train R^2 after unfreezing and pruning:  0.28823989629745483
# Test R^2 after unfreezing and pruning:  0.25921326875686646
#
# CVFOLD:  3
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Man1c1' 'Pcp4l1' 'Gnaz' 'Trpc6' 'Mybpc1' 'Zmat4' 'Grm1' 'March1' 'Alcam'
#  'Galnt14' 'Lrp1b' 'Penk' 'Ptprt' 'Npy' 'Sema3a' 'Cacna2d3' 'Kctd8'
#  'Trhde' 'Kit' 'Pde11a' 'Fxyd6' 'Adarb2' 'Sst' 'Vip' 'Synpr']
# [INFO] training network...
# Train R^2 before unfreezing:  0.2718241810798645
# Test R^2 before unfreezing:  0.2686900496482849
# Train R^2 after unfreezing:  0.26798391342163086
# Test R^2 after unfreezing:  0.26548945903778076
# Train R^2 after unfreezing and pruning:  0.282373309135437
# Test R^2 after unfreezing and pruning:  0.26978063583374023
#
# CVFOLD:  4
# [INFO] training network...
# [INFO] training network...
# The 25 genes that make it:  ['Pnoc' 'Pde11a' 'Kctd8' 'Mybpc1' 'Trhde' 'Gabrb2' 'Sema3a' 'Trpc6'
#  'Kcnab1' 'Dab1' 'Pcdh7' 'Pcp4l1' 'Cdh8' 'Igf1' 'Alcam' 'Kit' 'Npy'
#  'Ptprt' 'Cacna2d3' 'Zmat4' 'Adarb2' 'Synpr' 'Sst' 'Fxyd6' 'Vip']
# [INFO] training network...
# Train R^2 before unfreezing:  0.26745015382766724
# Test R^2 before unfreezing:  0.25464940071105957
# Train R^2 after unfreezing:  0.2705081105232239
# Test R^2 after unfreezing:  0.25945937633514404
# Train R^2 after unfreezing and pruning:  0.280862033367157
# Test R^2 after unfreezing and pruning:  0.2672100067138672
# Time: 0.0h  9m 31s

# %%
# with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_freeze_butlastlayer_unfreeze_lasso.pickle', 'wb') as f:
#     pickle.dump([r2_before_unfreezing, r2_before_unfreezing_tr, \
#                  r2_after_unfreezing, r2_after_unfreezing_tr, \
#                  r2_after_unfreezing_ap, r2_after_unfreezing_ap_tr, \
#                  r2_freeze_unfreeze_hist, r2_freeze_unfreeze_hist_tr], f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_freeze_1stlayeronly_unfreeze_lasso.pickle', 'wb') as f:
    pickle.dump([r2_before_unfreezing, r2_before_unfreezing_tr, \
                 r2_after_unfreezing, r2_after_unfreezing_tr, \
                 r2_after_unfreezing_ap, r2_after_unfreezing_ap_tr, \
                 r2_freeze_unfreeze_hist, r2_freeze_unfreeze_hist_tr], f)

# %% [markdown]
# And loading all required files to plot

# %%
lambdas = np.arange(.5,3,.1)
alphas = np.array([1])

# %%
with open('KerasSavedModels/gouwens_2020/sRRR_vs_Bottleneck_rank2_CV_lasso.pickle', 'rb') as f:
    r2_sRRR_rank2, r2_sRRR_relaxed_rank2, r2_sRRR_rank2_tr, r2_sRRR_relaxed_rank2_tr, \
                nonzero_rank2, corrs_rank2, corrs_relaxed_rank2 = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/sRRR_vs_Bottleneck_rank16_CV_lasso.pickle', 'rb') as f:
    r2_sRRR_rank16, r2_sRRR_relaxed_rank16, r2_sRRR_rank16_tr, r2_sRRR_relaxed_rank16_tr, \
                nonzero_rank16, corrs_rank16, corrs_relaxed_rank16 = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_pre_tr_lasso.pickle', 'rb') as f:
    CE_loss, CE_loss_tr, pre_tr_hist, pre_tr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_straight_regr_lasso.pickle', 'rb') as f:
    r2_straight_regr, r2_straight_regr_tr, \
    r2_straight_regr_ap, r2_straight_regr_ap_tr, \
    r2_straight_regr_hist, r2_straight_regr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_straight_regr_lasso.pickle', 'rb') as f:
    r2_pretr_straight_regr, r2_pretr_straight_regr_tr, \
    r2_pretr_straight_regr_ap, r2_pretr_straight_regr_ap_tr, \
    r2_pretr_straight_regr_hist, r2_pretr_straight_regr_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_freeze_unfreeze_lasso.pickle', 'rb') as f:
    r2_before_unfreezing, r2_before_unfreezing_tr, \
    r2_after_unfreezing, r2_after_unfreezing_tr, \
    r2_after_unfreezing_ap, r2_after_unfreezing_ap_tr, \
    r2_freeze_unfreeze_hist, r2_freeze_unfreeze_hist_tr = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_freeze_butlastlayer_unfreeze_lasso.pickle', 'rb') as f:
    r2_before_unfreezing_butlast, r2_before_unfreezing_tr_butlast, \
    r2_after_unfreezing_butlast, r2_after_unfreezing_tr_butlast, \
    r2_after_unfreezing_ap_butlast, r2_after_unfreezing_ap_tr_butlast, \
    r2_freeze_unfreeze_hist_butlast, r2_freeze_unfreeze_hist_tr_butlast = pickle.load(f)

# %%
with open('KerasSavedModels/gouwens_2020/Bottleneck_r2_pre_tr_and_freeze_1stlayeronly_unfreeze_lasso.pickle', 'rb') as f:
    r2_before_unfreezing_1stonly, r2_before_unfreezing_tr_1stonly, \
    r2_after_unfreezing_1stonly, r2_after_unfreezing_tr_1stonly, \
    r2_after_unfreezing_ap_1stonly, r2_after_unfreezing_ap_tr_1stonly, \
    r2_freeze_unfreeze_hist_1stonly, r2_freeze_unfreeze_hist_tr_1stonly = pickle.load(f)

# %%
# All together in one plot
linewidth = 2
sns_styleset()

# suppressing "mean of empty slice" warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    n_2 = np.nanmean(nonzero_rank2, axis=0)[0, :]
    cr_2 = np.nanmean(r2_sRRR_relaxed_rank2, axis=0)[0, :]
    n_16 = np.nanmean(nonzero_rank16, axis=0)[0, :]
    cr_16= np.nanmean(r2_sRRR_relaxed_rank16, axis=0)[0, :]
    
    

# suppressing "mean of empty slice" warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    n_rank2 = np.nanmean(nonzero_rank2, axis=0)[0, :]
    r_rank2_r = np.nanmean(r2_sRRR_relaxed_rank2, axis=0)[0, :]
    n_rank16 = np.nanmean(nonzero_rank16, axis=0)[0, :]
    r_rank16_r = np.nanmean(r2_sRRR_relaxed_rank16, axis=0)[0, :]

# All together in one plot for the paper
fig = plt.figure(figsize=(19, 4.5))
widths = [1, 1, 2]
heights = [1]
spec = fig.add_gridspec(ncols=3, nrows=1, width_ratios=widths,
                          height_ratios=heights)
ax1 = fig.add_subplot(spec[0, 0])
ax1.plot(n_2, cr_2, '.-', c = np.array([0, 0, 0])/256, linewidth=2)
ax1.plot(n_16[1:], cr_16[1:], '.-', c = np.array([0, 0, 0]) / 256, linewidth=2)
ax1.set_ylim([0.1,0.32])
ax1.set_xlabel('Number of selected genes', fontsize = 17)
ax1.set_ylabel(r'Cross validated $R^2$', fontsize = 17)
ax1.set_title('Sparse reduced-rank regression', fontsize = 20, y=1.02)
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.tick_params(axis='both', which='minor', labelsize=15)
ax1.vlines(x=25, ymin=ax1.get_ylim()[0], ymax=ax1.get_ylim()[1], linestyles='dashed')
ax1.annotate('sRRR, r=16', (70, np.max(cr_16)+0.0003), fontsize=15)
ax1.annotate('sRRR, r=2', (55, np.max(cr_2)+0.0003), fontsize=15)


ax2 = fig.add_subplot(spec[0, 1])
ax2.plot(range(50), np.mean(pre_tr_hist_tr, axis=(0, 2))[2, :], \
         '--', c = 'k', linewidth=linewidth)
ax2.plot(range(50), np.mean(pre_tr_hist, axis=(0, 2))[2, :], \
         c = 'k', linewidth=linewidth)
ax2.set_title('Pretraining', fontsize = 19, y=1.02)
ax2.set_xlabel('Epoch', fontsize = 17)
ax2.set_ylabel('Cross entropy loss', fontsize = 17)
ax2.tick_params(axis='both', which='major', labelsize=15)
ax2.tick_params(axis='both', which='minor', labelsize=15)
ax2.set_ylim([1, ax2.get_ylim()[1]])
ax2.annotate('Training', (35, 1.65), fontsize=15)
ax2.annotate('Test', (35, 1.9), fontsize=15)
ax2.set_xticks(np.arange(0, 60, 10))

epochs_used=200
ax3 = fig.add_subplot(spec[0, 2])
ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist_tr, axis=(0))[2,1,:], \
         '--', c = '#1b9e77', linewidth=linewidth)
ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist, axis=(0))[2,1,:], \
         c = '#1b9e77', linewidth=linewidth, label='Pre-training + freezing + unfreezing')
ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist_tr_butlast, axis=(0))[0,0,:], \
         '--', c = 'olive', linewidth=linewidth)
ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist_butlast, axis=(0))[0,0,:], \
         c = 'olive', linewidth=linewidth, label='Pre-training + freezing but last layer + unfreezing')
ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist_tr_butlast, axis=(0))[0,0,:], \
         '--', c = 'black', linewidth=linewidth)
ax3.plot(range(epochs_used), np.mean(r2_freeze_unfreeze_hist_butlast, axis=(0))[0,0,:], \
         c = 'black', linewidth=linewidth, label='Pre-training + freezing 1st layer only + unfreezing')
ax3.plot(range(epochs_used), np.mean(r2_pretr_straight_regr_hist_tr, axis=(0))[0,1,:], \
         '--', c = '#d95f02', linewidth=linewidth)
ax3.plot(range(epochs_used), np.mean(r2_pretr_straight_regr_hist, axis=(0))[0,1,:], \
         c = '#d95f02', linewidth=linewidth, label='Pre-training + no freezing')
ax3.plot(range(epochs_used), np.mean(r2_straight_regr_hist_tr, axis=(0))[0,1,:], \
         '--', c = '#7570b3', linewidth=linewidth)
ax3.plot(range(epochs_used), np.mean(r2_straight_regr_hist, axis=(0))[0,1,:], \
         c = '#7570b3', linewidth=linewidth, label='No pre-training')
ax3.hlines(r_rank16_r[np.isclose(n_rank16, 25, atol=4)], xmin = 0, xmax = epochs_used, \
            colors = np.array([0, 0, 0])/256, linewidth=linewidth)
ax3.hlines(r_rank2_r[np.isclose(n_rank2, 25, atol=2)], xmin = 0, xmax = epochs_used, \
            colors = np.array([0, 0, 0])/256, linewidth=linewidth)
ax3.set_ylim([0.1,0.32])
ax3.set_xlim([0,200])
ax3.set_xticks(np.arange(0, 225, 25))
ax3.annotate('RRR, r=16', (178, r_rank16_r[np.isclose(n_rank16, 25, atol=4)][0]-0.02), fontsize=15)
ax3.annotate('RRR, r=2', (178, r_rank2_r[np.isclose(n_rank2, 25, atol=2)][0]+0.003), fontsize=15)
ax3.set_title('Bottleneck neural network', fontsize = 19, y=1.02)
ax3.set_xlabel('Epoch', fontsize = 17)
ax3.set_ylabel(r'$R^2$', fontsize = 17)
ax3.tick_params(axis='both', which='major', labelsize=15)
ax3.tick_params(axis='both', which='minor', labelsize=15)
ax3.legend(loc='lower right', fontsize=13)
ax3.vlines(x=50, ymin=ax3.get_ylim()[0], ymax=ax3.get_ylim()[1], linestyles='dashed')
ax3.vlines(x=100, ymin=ax3.get_ylim()[0], ymax=ax3.get_ylim()[1], linestyles='dashed')

plt.text(-0.25, 1.04, 'a', transform = ax1.transAxes, fontsize=25, fontweight='bold')
plt.text(-0.11, 1.04, 'b', transform = ax2.transAxes, fontsize=25, fontweight='bold')
plt.text(-0.13, 1.04, 'c', transform = ax3.transAxes, fontsize=25, fontweight='bold')
sns.despine()

plt.savefig('figures/Allen_Lasso_training_curves_plusfreezebutlastlayer.pdf', bbox_inches='tight',
    pad_inches=0)
plt.savefig('figures/Allen_Lasso_training_curves_plusfreezebutlastlayer.png', bbox_inches='tight',
    pad_inches=0)
